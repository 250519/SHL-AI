# %%
from pinecone import Pinecone
from langchain.vectorstores import Pinecone as PineconeStore
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from dotenv import load_dotenv
import os
from uuid import uuid4
import time

# %%
load_dotenv()
# Out:
# True

# %%
import pandas as pd
df = pd.read_csv('/Users/harshshivhare/SHL-AI/shl_enhanced_assessments.csv')

# %%
print(f"Original rows: {len(df)}")
duplicates = df.duplicated(subset=["Test Name", "Test Link"])
print(f"Duplicate rows: {duplicates.sum()}")

# Drop duplicates
df_clean = df.drop_duplicates(subset=["Test Name", "Test Link"])

# Optional: Also drop empty descriptions
df_clean = df_clean[df_clean["Description"].notna() & (df_clean["Description"].str.strip() != "")]

print(f"Cleaned rows: {len(df_clean)}")
# Out:
# Original rows: 794
# Duplicate rows: 276
# Cleaned rows: 518

# %%
df_clean.to_csv("shl_enhanced_assessments_clean.csv", index=False)
print("✅ Cleaned CSV saved as 'shl_enhanced_assessments_clean.csv'")
# Out:
# ✅ Cleaned CSV saved as 'shl_enhanced_assessments_clean.csv'

# %%
from langchain.schema import Document

# %%
import pandas as pd
df = pd.read_csv('/Users/harshshivhare/SHL-AI/shl_final.csv')

# %%
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key=os.environ.get("PINECONE_API_KEY"))

index_name = "shl"
existing_indexes = [index_info["name"] for index_info in pc.list_indexes()]

if index_name not in existing_indexes:
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1"),
        deletion_protection="enabled"
    )
    while not pc.describe_index(index_name).status["ready"]:
        time.sleep(1)

index = pc.Index(index_name)

# %%
documents = []
ids = []

for _, row in df.iterrows():
    doc = Document(
        page_content=f"{row['Test Name']}. {row['Description']}",
        metadata = {
        "Test Name": str(row['Test Name']),
        "Test Link": str(row['Test Link']),
        "Description": str(row['Description']), 
        "Assessment Length": str(row['Assessment Length']),
        "Job Levels": str(row['Job Levels']),
        "Remote Testing": str(row['Remote Testing']),
        "Adaptive/IRT": str(row['Adaptive/IRT']),
        "Test Type": str(row['Test Type'])
    }
    )
    documents.append(doc)
    ids.append(str(uuid4()))

# %%
documents
# Out:
# [Document(metadata={'Test Name': 'Account Manager Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/account-manager-solution/', 'Description': 'The Account Manager solution is an assessment used for job candidates applying to mid-level leadership positions that tend to manage the day-to-day operations and activities of client accounts. Sample tasks for these jobs include, but are not limited to: communicating with clients about project status, developing and maintaining project plans, coordinating internally with appropriate project personnel, and ensuring client expectations are being met. Potential job titles that use this solution are: Account Executive, Account Manager, and Senior Account Manager. There are multiple configurations of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 49', 'Job Levels': 'Mid-Professional,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'CPAB'}, page_content='Account Manager Solution. The Account Manager solution is an assessment used for job candidates applying to mid-level leadership positions that tend to manage the day-to-day operations and activities of client accounts. Sample tasks for these jobs include, but are not limited to: communicating with clients about project status, developing and maintaining project plans, coordinating internally with appropriate project personnel, and ensuring client expectations are being met. Potential job titles that use this solution are: Account Executive, Account Manager, and Senior Account Manager. There are multiple configurations of this solution available.'),
#  Document(metadata={'Test Name': 'Administrative Professional - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/administrative-professional-short-form/', 'Description': 'The Administrative Professional solution is for entry to mid-level positions that involve routine clerical and administrative functions in addition to office management functions and customer service. Sample tasks for this job include, but are not limited to: arranging conference calls; drafting correspondence; scheduling meetings; greeting visitors; coordinating office activities. Potential job titles that use this solution are: Administrative Assistant, Secretary, Office Manager, Administrative Aide, and Administrative Associate.', 'Assessment Length': 'Approximate Completion Time in minutes = 36', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'AKP'}, page_content='Administrative Professional - Short Form. The Administrative Professional solution is for entry to mid-level positions that involve routine clerical and administrative functions in addition to office management functions and customer service. Sample tasks for this job include, but are not limited to: arranging conference calls; drafting correspondence; scheduling meetings; greeting visitors; coordinating office activities. Potential job titles that use this solution are: Administrative Assistant, Secretary, Office Manager, Administrative Aide, and Administrative Associate.'),
#  Document(metadata={'Test Name': 'Agency Manager Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/agency-manager-solution/', 'Description': 'The Agency Manager solution is for mid-level sales management positions that include front line management and sales responsibilities. Sample tasks for this job include, but are not limited to: directing and coordinating financial activities of workers in a branch, office, or department of an establishment, such as branch bank, brokerage firm, risk and insurance department, or credit department.  Potential job titles that use this solution are: Agency Manager, Brokerage Manager. Multiple configurations of this solution are available.', 'Assessment Length': 'Approximate Completion Time in minutes = 51', 'Job Levels': 'Front Line Manager, Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABPS'}, page_content='Agency Manager Solution. The Agency Manager solution is for mid-level sales management positions that include front line management and sales responsibilities. Sample tasks for this job include, but are not limited to: directing and coordinating financial activities of workers in a branch, office, or department of an establishment, such as branch bank, brokerage firm, risk and insurance department, or credit department.  Potential job titles that use this solution are: Agency Manager, Brokerage Manager. Multiple configurations of this solution are available.'),
#  Document(metadata={'Test Name': 'Apprentice + 8.0 Job Focused Assessment', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/apprentice-8-0-job-focused-assessment-4261/', 'Description': 'The Apprentice + 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment which includes a short cognitive ability measure. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organisations whose business spans across regions.', 'Assessment Length': 'Approximate Completion Time in minutes = 30', 'Job Levels': 'General Population, Graduate, Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'BP'}, page_content='Apprentice + 8.0 Job Focused Assessment. The Apprentice + 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment which includes a short cognitive ability measure. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organisations whose business spans across regions.'),
#  Document(metadata={'Test Name': 'Apprentice 8.0 Job Focused Assessment', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/apprentice-8-0-job-focused-assessment/', 'Description': 'The Apprentice 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organizations whose business spans across regions.', 'Assessment Length': 'Approximate Completion Time in minutes = 20', 'Job Levels': 'Entry-Level, General Population, Graduate,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'BP'}, page_content='Apprentice 8.0 Job Focused Assessment. The Apprentice 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organizations whose business spans across regions.'),
#  Document(metadata={'Test Name': 'Bank Administrative Assistant - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bank-administrative-assistant-short-form/', 'Description': 'The Administrative Assistant solution is for entry-level clerical positions that interact with external or internal customers. Sample tasks for these jobs include, but are not limited to: answering telephones, managing files and records, sorting mail, greeting customers, and collaborating with co-workers on projects. Potential job titles that use this solution are: Receptionist and Administrative Assistant. There are multiple configurations of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 35', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABKP'}, page_content='Bank Administrative Assistant - Short Form. The Administrative Assistant solution is for entry-level clerical positions that interact with external or internal customers. Sample tasks for these jobs include, but are not limited to: answering telephones, managing files and records, sorting mail, greeting customers, and collaborating with co-workers on projects. Potential job titles that use this solution are: Receptionist and Administrative Assistant. There are multiple configurations of this solution available.'),
#  Document(metadata={'Test Name': 'Bank Collections Agent - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bank-collections-agent-short-form/', 'Description': 'This solution is for entry-level collections positions in an inbound or outbound call center environment in a financial setting. Candidates answer multiple choice questions to measure achievement orientation, dependability, collector numerical skills, revenue recovery, customer focus, and persistence and planfulness. There are multiple configurations and versions of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 45', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABP'}, page_content='Bank Collections Agent - Short Form. This solution is for entry-level collections positions in an inbound or outbound call center environment in a financial setting. Candidates answer multiple choice questions to measure achievement orientation, dependability, collector numerical skills, revenue recovery, customer focus, and persistence and planfulness. There are multiple configurations and versions of this solution available.'),
#  Document(metadata={'Test Name': 'Bank Operations Supervisor - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bank-operations-supervisor-short-form/', 'Description': "The Bank Operations Supervisor solution is for job candidates applying to entry-level leadership positions who tend to supervise hourly employees. Sample tasks for these jobs include, but are not limited to:  planning and preparing work schedules, assigning employees to specific duties; coaching  employees on attendance, conduct, schedule adherence, and work tasks, developing employees' skills ; training subordinates; prioritizing multiple tasks  and priorities; and making  day-to-day decisions with minimal guidance from others. Potential job titles that use this solution are: Team Leader, First Line Supervisor, Processing Supervisor, Call Center Supervisor, and Customer Service Supervisor. There are multiple configurations and versions of this solution available.", 'Assessment Length': 'Approximate Completion Time in minutes = 45', 'Job Levels': 'Front Line Manager, Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABPS'}, page_content="Bank Operations Supervisor - Short Form. The Bank Operations Supervisor solution is for job candidates applying to entry-level leadership positions who tend to supervise hourly employees. Sample tasks for these jobs include, but are not limited to:  planning and preparing work schedules, assigning employees to specific duties; coaching  employees on attendance, conduct, schedule adherence, and work tasks, developing employees' skills ; training subordinates; prioritizing multiple tasks  and priorities; and making  day-to-day decisions with minimal guidance from others. Potential job titles that use this solution are: Team Leader, First Line Supervisor, Processing Supervisor, Call Center Supervisor, and Customer Service Supervisor. There are multiple configurations and versions of this solution available."),
#  Document(metadata={'Test Name': 'Bilingual Spanish Reservation Agent Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bilingual-spanish-reservation-agent-solution/', 'Description': 'The Bilingual Reservation Agent solution is designed for customer centered entry-level positions within the hospitality industry. Sample tasks may include making, updating, or canceling hotel reservations made in English or Spanish; listening to customers speak Spanish and entering information into a computer in English; providing information on the hotel and the services offered. Potential job titles that use this solution are: Bilingual Reservation Agent, Customer Service Representative and Reservationist. Multiple configurations of this solution are available.', 'Assessment Length': 'Approximate Completion Time in minutes = 43', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'BPSA'}, page_content='Bilingual Spanish Reservation Agent Solution. The Bilingual Reservation Agent solution is designed for customer centered entry-level positions within the hospitality industry. Sample tasks may include making, updating, or canceling hotel reservations made in English or Spanish; listening to customers speak Spanish and entering information into a computer in English; providing information on the hotel and the services offered. Potential job titles that use this solution are: Bilingual Reservation Agent, Customer Service Representative and Reservationist. Multiple configurations of this solution are available.'),
#  Document(metadata={'Test Name': 'Bookkeeping, Accounting, Auditing Clerk Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bookkeeping-accounting-auditing-clerk-short-form/', 'Description': 'The Bookkeeping, Accounting, and Auditing Clerk solution is for entry-level positions that involve entering numerical data into computer systems and maintaining financial records. Sample tasks for this job include, but are not limited to: entering financial data into computers; checking financial records for accuracy; perform routine computations on financial data. Potential job titles that use this solution are: Accounting Clerk, Bookkeeper, Accounting Associate, Auditing Clerk and Accounts Receivable Clerk.', 'Assessment Length': 'Approximate Completion Time in minutes = 49', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'PSKBA'}, page_content='Bookkeeping, Accounting, Auditing Clerk Short Form. The Bookkeeping, Accounting, and Auditing Clerk solution is for entry-level positions that involve entering numerical data into computer systems and maintaining financial records. Sample tasks for this job include, but are not limited to: entering financial data into computers; checking financial records for accuracy; perform routine computations on financial data. Potential job titles that use this solution are: Accounting Clerk, Bookkeeper, Accounting Associate, Auditing Clerk and Accounts Receivable Clerk.'),
#  Document(metadata={'Test Name': 'Branch Manager - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/branch-manager-short-form/', 'Description': 'This solution is for mid to upper-level financial institution managerial positions. Candidates answer a series of multiple choice questions to measure management potential, management judgment, leadership potential, team management, branch manager problem solving, business leadership, leadership motivation, interpersonal leadership, self leadership, and branch manager judgment. There are multiple configurations and versions of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 50', 'Job Levels': 'Front Line Manager, Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABP'}, page_content='Branch Manager - Short Form. This solution is for mid to upper-level financial institution managerial positions. Candidates answer a series of multiple choice questions to measure management potential, management judgment, leadership potential, team management, branch manager problem solving, business leadership, leadership motivation, interpersonal leadership, self leadership, and branch manager judgment. There are multiple configurations and versions of this solution available.'),
#  Document(metadata={'Test Name': 'Cashier Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/cashier-solution/', 'Description': 'The Cashier solution is for entry-level retail positions in which employees receive payment in the form of cash, check, or credit cards for goods purchased. Sample tasks for these jobs include, but are not limited to: handling payments, offering customer service, and issuing receipts and refunds. Potential job titles that use this solution are: Cashier, Sales Associate, and Clerk. There are multiple configurations and versions of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 28', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'BAP'}, page_content='Cashier Solution. The Cashier solution is for entry-level retail positions in which employees receive payment in the form of cash, check, or credit cards for goods purchased. Sample tasks for these jobs include, but are not limited to: handling payments, offering customer service, and issuing receipts and refunds. Potential job titles that use this solution are: Cashier, Sales Associate, and Clerk. There are multiple configurations and versions of this solution available.'),
#  Document(metadata={'Test Name': 'Global Skills Development Report', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/global-skills-development-report/', 'Description': 'This report is designed to be given to individuals who have completed the Global Skills Assessment (GSA). With coverage across the Great 8 Domains, this measure of self-reported behaviors offers a complete overview of their current skills. Participants receive actionable tips on leveraging their top skill strengths and how they might develop their growth skills.', 'Assessment Length': 'nan', 'Job Levels': 'Director, Entry-Level, Executive, General Population, Graduate, Manager, Mid-Professional, Front Line Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'AEBCDP'}, page_content='Global Skills Development Report. This report is designed to be given to individuals who have completed the Global Skills Assessment (GSA). With coverage across the Great 8 Domains, this measure of self-reported behaviors offers a complete overview of their current skills. Participants receive actionable tips on leveraging their top skill strengths and how they might develop their growth skills.'),
#  Document(metadata={'Test Name': '.NET Framework 4.5', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-framework-4-5/', 'Description': 'The.NET Framework 4.5 test measures knowledge of .NET environment. Designed for experienced users, this test covers the following topics: Application Development, Application Foundation, Data Modeling, Deployment, Diagnostics, Performance, Portability, and Security.', 'Assessment Length': 'Approximate Completion Time in minutes = 30', 'Job Levels': 'Professional Individual Contributor, Mid-Professional,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K'}, page_content='.NET Framework 4.5. The.NET Framework 4.5 test measures knowledge of .NET environment. Designed for experienced users, this test covers the following topics: Application Development, Application Foundation, Data Modeling, Deployment, Diagnostics, Performance, Portability, and Security.'),
#  Document(metadata={'Test Name': '.NET MVC (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-mvc-new/', 'Description': 'Multi-choice test that measures the knowledge of Model-View-Controller (MVC) architecture, validation, security, routing, and areas.', 'Assessment Length': 'Approximate Completion Time in minutes = 17', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='.NET MVC (New). Multi-choice test that measures the knowledge of Model-View-Controller (MVC) architecture, validation, security, routing, and areas.'),
#  Document(metadata={'Test Name': '.NET MVVM (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-mvvm-new/', 'Description': 'Multi-choice test that measures the knowledge of MVVM pattern, scenarios, data validation, ViewModel communication and Quick-start.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='.NET MVVM (New). Multi-choice test that measures the knowledge of MVVM pattern, scenarios, data validation, ViewModel communication and Quick-start.'),
#  Document(metadata={'Test Name': '.NET WCF (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-wcf-new/', 'Description': 'Multi-choice test that measures the knowledge of .NET fundamentals, WCF architecture, programming model, SOA, managing and programming WCF.', 'Assessment Length': 'Approximate Completion Time in minutes = 11', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='.NET WCF (New). Multi-choice test that measures the knowledge of .NET fundamentals, WCF architecture, programming model, SOA, managing and programming WCF.'),
#  Document(metadata={'Test Name': '.NET WPF (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-wpf-new/', 'Description': 'Multi-choice test that measures the knowledge of .NET basics, WPF, XAML controls, events, layouts, working with WPF windows/menus and deploying WPF applications.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='.NET WPF (New). Multi-choice test that measures the knowledge of .NET basics, WPF, XAML controls, events, layouts, working with WPF windows/menus and deploying WPF applications.'),
#  Document(metadata={'Test Name': '.NET XAML (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-xaml-new/', 'Description': 'Multi-choice test that measures the knowledge of XAML triggers, data binding, custom controls and layouts.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='.NET XAML (New). Multi-choice test that measures the knowledge of XAML triggers, data binding, custom controls and layouts.'),
#  Document(metadata={'Test Name': 'Accounts Payable (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-payable-new/', 'Description': 'Multiple-choice test that measures the knowledge of processing payables and vendor invoices, and the posting of journal entries.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Accounts Payable (New). Multiple-choice test that measures the knowledge of processing payables and vendor invoices, and the posting of journal entries.'),
#  Document(metadata={'Test Name': 'Accounts Payable Simulation (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-payable-simulation-new/', 'Description': 'Simulated data entry test that measures the ability to process payables and vendor invoices.', 'Assessment Length': 'Approximate Completion Time in minutes = 8', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S'}, page_content='Accounts Payable Simulation (New). Simulated data entry test that measures the ability to process payables and vendor invoices.'),
#  Document(metadata={'Test Name': 'Accounts Receivable (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-receivable-new/', 'Description': 'Multiple-choice test that measures the knowledge of processing receivables and invoices.', 'Assessment Length': 'Approximate Completion Time in minutes = 13', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Accounts Receivable (New). Multiple-choice test that measures the knowledge of processing receivables and invoices.'),
#  Document(metadata={'Test Name': 'Accounts Receivable Simulation (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-receivable-simulation-new/', 'Description': 'Simulated data entry test that measures the ability to process receivables and invoices.', 'Assessment Length': 'Approximate Completion Time in minutes = 8', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S'}, page_content='Accounts Receivable Simulation (New). Simulated data entry test that measures the ability to process receivables and invoices.'),
#  Document(metadata={'Test Name': 'ADO.NET (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/ado-net-new/', 'Description': 'Multi-choice test that measures the knowledge on the concepts of ADO.NET architecture, components and data provider objects.', 'Assessment Length': 'Approximate Completion Time in minutes = 10', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='ADO.NET (New). Multi-choice test that measures the knowledge on the concepts of ADO.NET architecture, components and data provider objects.'),
#  Document(metadata={'Test Name': 'Adobe Experience Manager (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/adobe-experience-manager-new/', 'Description': 'Multi-choice test that measures the knowledge of AEM components, templates, workflows, AEM collections, OSGi services and troubleshooting of AEM projects.', 'Assessment Length': 'Approximate Completion Time in minutes = 17', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Adobe Experience Manager (New). Multi-choice test that measures the knowledge of AEM components, templates, workflows, AEM collections, OSGi services and troubleshooting of AEM projects.'),
#  Document(metadata={'Test Name': 'Adobe Photoshop CC', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/adobe-photoshop-cc/', 'Description': 'The Adobe Photoshop CC test measures knowledge of Adobe Photoshop CC. Designed for experienced users, this test covers the following topics: 3D, Color, File Management, Interface, Layers, Painting and Drawing, Retouch and Enhancements, Selection, Text, and Web.', 'Assessment Length': 'Approximate Completion Time in minutes = 20', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K'}, page_content='Adobe Photoshop CC. The Adobe Photoshop CC test measures knowledge of Adobe Photoshop CC. Designed for experienced users, this test covers the following topics: 3D, Color, File Management, Interface, Layers, Painting and Drawing, Retouch and Enhancements, Selection, Text, and Web.'),
#  Document(metadata={'Test Name': 'Aeronautical Engineering (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/aeronautical-engineering-new/', 'Description': 'Multi-choice test that measures the knowledge of flight mechanics, space dynamics, aerodynamics, structures and propulsion.', 'Assessment Length': 'Approximate Completion Time in minutes = 10', 'Job Levels': 'Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Aeronautical Engineering (New). Multi-choice test that measures the knowledge of flight mechanics, space dynamics, aerodynamics, structures and propulsion.'),
#  Document(metadata={'Test Name': 'Aerospace Engineering (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/aerospace-engineering-new/', 'Description': 'Multi-choice test that measures the conceptual knowledge of aerodynamics, aircraft systems and instrumentation, flight dynamics, space dynamics and avionics.', 'Assessment Length': 'Approximate Completion Time in minutes = 10', 'Job Levels': 'Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Aerospace Engineering (New). Multi-choice test that measures the conceptual knowledge of aerodynamics, aircraft systems and instrumentation, flight dynamics, space dynamics and avionics.'),
#  Document(metadata={'Test Name': 'Agile Software Development', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/agile-software-development/', 'Description': 'Multi-choice test that measures the knowledge of agile methodology, scrum, feature driven software development, incremental and iterative development and processes involved in agile software development.', 'Assessment Length': 'Approximate Completion Time in minutes = 7 minutes', 'Job Levels': 'Graduate,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Agile Software Development. Multi-choice test that measures the knowledge of agile methodology, scrum, feature driven software development, incremental and iterative development and processes involved in agile software development.'),
#  Document(metadata={'Test Name': 'Agile Testing (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/agile-testing-new/', 'Description': 'Multi-choice test that measures the knowledge of tools, techniques and processes involved in the Agile testing methodology.', 'Assessment Length': 'Approximate Completion Time in minutes = 13', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Agile Testing (New). Multi-choice test that measures the knowledge of tools, techniques and processes involved in the Agile testing methodology.'),
#  Document(metadata={'Test Name': 'AI Skills', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/ai-skills/', 'Description': 'The AI Skills assessment measures the skills that help candidates successfully leverage AI in their work.', 'Assessment Length': 'Approximate Completion Time in minutes = 16', 'Job Levels': 'General Population,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'P'}, page_content='AI Skills. The AI Skills assessment measures the skills that help candidates successfully leverage AI in their work.'),
#  Document(metadata={'Test Name': 'Amazon Web Services (AWS) Development (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/amazon-web-services-aws-development-new/', 'Description': 'Multi-choice test that measures the knowledge of AWS delivery process, monitoring, metrics, logging, security, validation and scalability.', 'Assessment Length': 'Approximate Completion Time in minutes = 6', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Amazon Web Services (AWS) Development (New). Multi-choice test that measures the knowledge of AWS delivery process, monitoring, metrics, logging, security, validation and scalability.'),
#  Document(metadata={'Test Name': 'Android Development (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/android-development-new/', 'Description': 'Multi-choice test that measures the knowledge of UI components for an Android device, services and alerts, animation and media apps, application components, security and testing.', 'Assessment Length': 'Approximate Completion Time in minutes = 7', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Android Development (New). Multi-choice test that measures the knowledge of UI components for an Android device, services and alerts, animation and media apps, application components, security and testing.'),
#  Document(metadata={'Test Name': 'Angular 6 (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/angular-6-new/', 'Description': 'Multi-choice test that measures the knowledge of the basic components and modules of Angular 6 and concepts like data binding, dependency injection, CRUD with HTTP, typescript, routing and navigation.', 'Assessment Length': 'Approximate Completion Time in minutes = 11', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Angular 6 (New). Multi-choice test that measures the knowledge of the basic components and modules of Angular 6 and concepts like data binding, dependency injection, CRUD with HTTP, typescript, routing and navigation.'),
#  Document(metadata={'Test Name': 'AngularJS (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/angularjs-new/', 'Description': 'Multi-choice test that measures the knowledge of AngularJS architecture, forms, directives, filters, controllers, routing and testing.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='AngularJS (New). Multi-choice test that measures the knowledge of AngularJS architecture, forms, directives, filters, controllers, routing and testing.'),
#  Document(metadata={'Test Name': 'Apache Hadoop (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/apache-hadoop-new/', 'Description': 'Multi-choice test that measures the knowledge of basic concepts of Hadoop, commands, HDFS and MapReduce.', 'Assessment Length': 'Approximate Completion Time in minutes = 7', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Apache Hadoop (New). Multi-choice test that measures the knowledge of basic concepts of Hadoop, commands, HDFS and MapReduce.'),
#  Document(metadata={'Test Name': 'Claims/Operations Supervisor Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/claimsoperations-supervisor-solution/', 'Description': "The Claims/Operations Supervisor solution is for entry-level management positions that involve supervising hourly employees.  Sample tasks for this job include, but are not limited to: planning and preapring work schedules; assigning employees to specific dutites; coaching employees on attendance, conduct, schedule adherence, and work tasks; developing employees' skills; training subordinates; prioritizing multiple tasks and priorities; making day-to-day decisions with minimal guidance from others.  Potential job titles that use this solution are: Team Leader, Coach, First Line Supervisor, Claims Supervisor, Operations Supervisor, and Customer Service Supervisor.  Multiple configurations of this solution are available.", 'Assessment Length': 'Approximate Completion Time in minutes = 48', 'Job Levels': 'Manager,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'PSAB'}, page_content="Claims/Operations Supervisor Solution. The Claims/Operations Supervisor solution is for entry-level management positions that involve supervising hourly employees.  Sample tasks for this job include, but are not limited to: planning and preapring work schedules; assigning employees to specific dutites; coaching employees on attendance, conduct, schedule adherence, and work tasks; developing employees' skills; training subordinates; prioritizing multiple tasks and priorities; making day-to-day decisions with minimal guidance from others.  Potential job titles that use this solution are: Team Leader, Coach, First Line Supervisor, Claims Supervisor, Operations Supervisor, and Customer Service Supervisor.  Multiple configurations of this solution are available."),
#  Document(metadata={'Test Name': 'Contact Center Customer Service + 8.0', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-customer-service-8-0/', 'Description': 'The Contact Center + 8.0 - Customer Service Job Focused Assessment is designed to measure the skills, competencies, and behaviors needed for success in contact center roles where the main focus is customer service. This JFA includes a mobile-optimized contact center simulation, a behavioral assessment, and a cognitive test. Together, these assessments capture the ability to provide exceptional customer service in entry-level contact center roles.', 'Assessment Length': 'Approximate Completion Time in minutes = 41', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABCPS'}, page_content='Contact Center Customer Service + 8.0. The Contact Center + 8.0 - Customer Service Job Focused Assessment is designed to measure the skills, competencies, and behaviors needed for success in contact center roles where the main focus is customer service. This JFA includes a mobile-optimized contact center simulation, a behavioral assessment, and a cognitive test. Together, these assessments capture the ability to provide exceptional customer service in entry-level contact center roles.'),
#  Document(metadata={'Test Name': 'Contact Center Customer Service 8.0', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-customer-service-8-0-4269/', 'Description': 'The Customer Service 8.0 JFA is designed for entry-level positions in a contact center environment where the main focus is customer service.', 'Assessment Length': 'Approximate Completion Time in minutes = 31', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'SBCP'}, page_content='Contact Center Customer Service 8.0. The Customer Service 8.0 JFA is designed for entry-level positions in a contact center environment where the main focus is customer service.'),
#  Document(metadata={'Test Name': 'Contact Center Manager - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-manager-short-form/', 'Description': 'The Contact Center - Manager solution is for mid to upper-level contact center managerial positions. Sample\r\ntasks for these jobs include, but are not limited to: supervising and coordinating the activities of subordinates;\r\ninteracting day-to-day with subordinates; and training employees. Potential job titles that use this solution are:\r\nContact Center Team Leader, First Line Supervisor, and Contact Center Manager.', 'Assessment Length': 'Approximate Completion Time in minutes = 50', 'Job Levels': 'Manager, Supervisor, Front Line Manager,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABPS'}, page_content='Contact Center Manager - Short Form. The Contact Center - Manager solution is for mid to upper-level contact center managerial positions. Sample\r\ntasks for these jobs include, but are not limited to: supervising and coordinating the activities of subordinates;\r\ninteracting day-to-day with subordinates; and training employees. Potential job titles that use this solution are:\r\nContact Center Team Leader, First Line Supervisor, and Contact Center Manager.'),
#  Document(metadata={'Test Name': 'Contact Center Sales & Service + 8.0', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-sales-and-service-8-0/', 'Description': 'The Contact Center + 8.0 - Sales & Service Job Focused Assessment is designed to measure the skills, competencies, and behaviors needed for success in contact center roles that involve sales-related behaviors such as recommending products or services and retaining customers. This JFA includes a mobile-optimized contact center simulation, a behavioral assessment, and a cognitive test. Together, these assessments capture the ability to provide exceptional customer service and drive sales in entry-level contact center roles.', 'Assessment Length': 'Approximate Completion Time in minutes = 41', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'PBCAS'}, page_content='Contact Center Sales & Service + 8.0. The Contact Center + 8.0 - Sales & Service Job Focused Assessment is designed to measure the skills, competencies, and behaviors needed for success in contact center roles that involve sales-related behaviors such as recommending products or services and retaining customers. This JFA includes a mobile-optimized contact center simulation, a behavioral assessment, and a cognitive test. Together, these assessments capture the ability to provide exceptional customer service and drive sales in entry-level contact center roles.'),
#  Document(metadata={'Test Name': 'Contact Center Sales & Service 8.0', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-sales-and-service-8-0-4268/', 'Description': 'The Sales & Service 8.0 JFA is designed for contact center roles that involve sales or sales-related behaviors such as recommending products or services and retaining customers.', 'Assessment Length': 'Approximate Completion Time in minutes = 31', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'SBCP'}, page_content='Contact Center Sales & Service 8.0. The Sales & Service 8.0 JFA is designed for contact center roles that involve sales or sales-related behaviors such as recommending products or services and retaining customers.'),
#  Document(metadata={'Test Name': 'Contact Center Team Lead/Coach - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-team-leadcoach-short-form/', 'Description': "The Contact Center - Team Lead/Coach solution is for job candidates applying to entry-level leadership\r\npositions who tend to supervise hourly employees. Sample tasks for these jobs include, but are not limited\r\nto: planning and preparing work schedules; assigning employees to specific duties; coaching employees on\r\nattendance, conduct, schedule adherence, and work tasks; developing employees' skills; training subordinates\r\nor less tenured peers; prioritizing multiple tasks and priorities; and making day-to-day decisions with minimal\r\nguidance from others. Potential job titles that use this solution are: Team Leader, Coach, First Line Supervisor,\r\nProcessing Supervisor, Call Center Supervisor, and Customer Service Supervisor.", 'Assessment Length': 'Approximate Completion Time in minutes = 45', 'Job Levels': 'Front Line Manager, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABPS'}, page_content="Contact Center Team Lead/Coach - Short Form. The Contact Center - Team Lead/Coach solution is for job candidates applying to entry-level leadership\r\npositions who tend to supervise hourly employees. Sample tasks for these jobs include, but are not limited\r\nto: planning and preparing work schedules; assigning employees to specific duties; coaching employees on\r\nattendance, conduct, schedule adherence, and work tasks; developing employees' skills; training subordinates\r\nor less tenured peers; prioritizing multiple tasks and priorities; and making day-to-day decisions with minimal\r\nguidance from others. Potential job titles that use this solution are: Team Leader, Coach, First Line Supervisor,\r\nProcessing Supervisor, Call Center Supervisor, and Customer Service Supervisor."),
#  Document(metadata={'Test Name': 'Contact Centre Agent Solution - UK', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-centre-agent-solution-uk/', 'Description': 'This solution is used for job candidates applying to entry-level positions in a contact centre environment where the main focus of the job is customer service. The candidate answers multiple choice questions as well as questions in a customer call simulation environment. The solution measures: working with information, customer focus, contact centre retention, navigation, service orientation, and tactful problem solving. In addition, the solution measures data entry speed and accuracy, multi-tasking preferences, achievement orientation and conscientiousness.', 'Assessment Length': 'Approximate Completion Time in minutes = 39', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABPS'}, page_content='Contact Centre Agent Solution - UK. This solution is used for job candidates applying to entry-level positions in a contact centre environment where the main focus of the job is customer service. The candidate answers multiple choice questions as well as questions in a customer call simulation environment. The solution measures: working with information, customer focus, contact centre retention, navigation, service orientation, and tactful problem solving. In addition, the solution measures data entry speed and accuracy, multi-tasking preferences, achievement orientation and conscientiousness.'),
#  Document(metadata={'Test Name': 'Customer Service - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/customer-service-short-form/', 'Description': 'The Customer Service Representative Solution is for entry-level positions that involve a high degree of interaction with customers in person or on the phone. Sample tasks for this job include, but are not limited to: taking orders; solving product or service issues; responding positively to difficult customers; referring unresolved issues to the appropriate individuals; providing information on products and/or services. Potential job titles that use this solution are: Account Service Representative, Account Representative, Customer Service Representative, and Customer Service Agent.', 'Assessment Length': 'Approximate Completion Time in minutes = 42', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABP'}, page_content='Customer Service - Short Form. The Customer Service Representative Solution is for entry-level positions that involve a high degree of interaction with customers in person or on the phone. Sample tasks for this job include, but are not limited to: taking orders; solving product or service issues; responding positively to difficult customers; referring unresolved issues to the appropriate individuals; providing information on products and/or services. Potential job titles that use this solution are: Account Service Representative, Account Representative, Customer Service Representative, and Customer Service Agent.'),
# ...
#  Document(metadata={'Test Name': 'Visual Comparison - UK', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/visual-comparison-uk/', 'Description': 'This assessment measures ability to efficiently compare information and detect errors. The test taker is required to examine four pairs of numbers and select the set of numbers that are notidentical.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Visual Comparison - UK. This assessment measures ability to efficiently compare information and detect errors. The test taker is required to examine four pairs of numbers and select the set of numbers that are notidentical.'),
#  Document(metadata={'Test Name': 'Visual Comparison - US', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/visual-comparison-us/', 'Description': 'This assessment measures ability to efficiently compare information and detect errors. The test taker is required to examine four pairs of numbers and select the set of numbers that are not identical.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Visual Comparison - US. This assessment measures ability to efficiently compare information and detect errors. The test taker is required to examine four pairs of numbers and select the set of numbers that are not identical.'),
#  Document(metadata={'Test Name': 'VLSI and Embedded Systems (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/vlsi-and-embedded-systems-new/', 'Description': 'Multi-choice test that measures the knowledge of VLSI and embedded systems basics.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='VLSI and Embedded Systems (New). Multi-choice test that measures the knowledge of VLSI and embedded systems basics.'),
#  Document(metadata={'Test Name': 'What Is The Value - US', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/what-is-the-value-us/', 'Description': 'The What is the Value –US test measures money handling ability. This test is designed for entry-level positions where handling money is required on a regular basis.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K'}, page_content='What Is The Value - US. The What is the Value –US test measures money handling ability. This test is designed for entry-level positions where handling money is required on a regular basis.'),
#  Document(metadata={'Test Name': 'Workplace Administration Skills (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/workplace-administration-skills-new/', 'Description': "Multi-choice test that measures the ability to organize one's workplace, properly maintain data, perform simple tasks on the computer and resolve administrative issues.", 'Assessment Length': 'Approximate Completion Time in minutes = 12', 'Job Levels': 'Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content="Workplace Administration Skills (New). Multi-choice test that measures the ability to organize one's workplace, properly maintain data, perform simple tasks on the computer and resolve administrative issues."),
#  Document(metadata={'Test Name': 'Workplace Health and Safety (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/workplace-health-and-safety-new/', 'Description': 'Multi-choice test that measures the knowledge of first aid, emergency safety measures, cleanliness and personal hygiene.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Entry-Level, Graduate, Manager, Supervisor, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Workplace Health and Safety (New). Multi-choice test that measures the knowledge of first aid, emergency safety measures, cleanliness and personal hygiene.'),
#  Document(metadata={'Test Name': 'WriteX - Email Writing (Customer Service) (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/writex-email-writing-customer-service-new/', 'Description': 'Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/', 'Assessment Length': 'Approximate Completion Time in minutes = 15', 'Job Levels': 'Entry-Level, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S'}, page_content='WriteX - Email Writing (Customer Service) (New). Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/'),
#  Document(metadata={'Test Name': 'WriteX - Email Writing (Managerial) (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/writex-email-writing-managerial-new/', 'Description': 'Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/', 'Assessment Length': 'Approximate Completion Time in minutes = 15', 'Job Levels': 'Entry-Level, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S'}, page_content='WriteX - Email Writing (Managerial) (New). Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/'),
#  Document(metadata={'Test Name': 'WriteX - Email Writing (Sales) (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/writex-email-writing-sales-new/', 'Description': 'Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/', 'Assessment Length': 'Approximate Completion Time in minutes = 15', 'Job Levels': 'Entry-Level, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'BS'}, page_content='WriteX - Email Writing (Sales) (New). Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/'),
#  Document(metadata={'Test Name': 'Written English v1', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/written-english-v1/', 'Description': 'The Written English test measures knowledge of US English grammar and English reading comprehension. It is designed for those with English as a second language and covers the following topics: Articles, Comparisons, Conjunctions, General Questions, Misused Words, Nouns, Parallel Structure, Prepositions, Pronouns, Specific Questions, and Verbs.', 'Assessment Length': 'Approximate Completion Time in minutes = 30', 'Job Levels': 'Entry-Level, Front Line Manager, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K'}, page_content='Written English v1. The Written English test measures knowledge of US English grammar and English reading comprehension. It is designed for those with English as a second language and covers the following topics: Articles, Comparisons, Conjunctions, General Questions, Misused Words, Nouns, Parallel Structure, Prepositions, Pronouns, Specific Questions, and Verbs.'),
#  Document(metadata={'Test Name': 'Written Spanish', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/written-spanish/', 'Description': 'This test measures knowledge of Spanish grammar and Spanish reading comprehension skills. Designed primarily for individuals where Spanish is their second language, this test covers the following topics: Adjectives, Adverbs, Conjunctions, Nouns, Prepositions, Pronouns, Verbs, and Reading Comprehension.', 'Assessment Length': 'Approximate Completion Time in minutes = 22', 'Job Levels': 'Entry-Level, Front Line Manager, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K'}, page_content='Written Spanish. This test measures knowledge of Spanish grammar and Spanish reading comprehension skills. Designed primarily for individuals where Spanish is their second language, this test covers the following topics: Adjectives, Adverbs, Conjunctions, Nouns, Prepositions, Pronouns, Verbs, and Reading Comprehension.'),
#  Document(metadata={'Test Name': 'Zabbix (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/zabbix-new/', 'Description': 'Multi-choice test that measures the knowledge of Zabbix architecture, data handling, monitoring and administration.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K'}, page_content='Zabbix (New). Multi-choice test that measures the knowledge of Zabbix architecture, data handling, monitoring and administration.'),
#  Document(metadata={'Test Name': '360 Digital Report', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/360-digital-report/', 'Description': "Introducing the new 360 Digital Report from SHL! Our latest offering revolutionizes the reporting experience for our 360 products, catering to the modern user's needs for enhanced usability and actionable insights. With a sleek, interactive interface, this report provides a exploration of feedback data, focusing on user development and comprehensive evaluation. Users can now enjoy a visually engaging experience, with the capability to download the report in PDF format for offline access. Upgrade your reporting experience today with SHL's innovative 360 Digital Report!", 'Assessment Length': 'nan', 'Job Levels': 'Director, Manager, Entry-Level, Executive, Front Line Manager, General Population, Graduate,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'D'}, page_content="360 Digital Report. Introducing the new 360 Digital Report from SHL! Our latest offering revolutionizes the reporting experience for our 360 products, catering to the modern user's needs for enhanced usability and actionable insights. With a sleek, interactive interface, this report provides a exploration of feedback data, focusing on user development and comprehensive evaluation. Users can now enjoy a visually engaging experience, with the capability to download the report in PDF format for offline access. Upgrade your reporting experience today with SHL's innovative 360 Digital Report!"),
#  Document(metadata={'Test Name': '360° Multi-Rater Feedback System (MFS)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/360-multi-rater-feedback-system-mfs/', 'Description': 'SHL 360, or the Multi-Rater Feedback System (‘MFS’), provides a holistic 360-degree view of an employee by gathering feedback from the employee’s manager, peers, direct reports, and/or other raters.  By offering a wide range of perspectives, 360 feedback gives employees a more thorough understanding of not only their strengths, weaknesses, and development opportunities, but also their impact on others.  360-degree multi-rater assessments are based on SHL’s Universal Competency Framework (“UCF”), using our proven library of research-driven competencies to provide opportunities for managers, peers, and direct reports to supply useful developmental feedback that they may not otherwise share.  SHL can also offer support and training throughout the entire process, from defining objectives through interpreting and delivering the feedback.  360 feedback serves all levels and industries and is a positive and powerful addition to your performance management system.', 'Assessment Length': 'Approximate Completion Time in minutes = Untimed', 'Job Levels': 'Director, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'DP'}, page_content='360° Multi-Rater Feedback System (MFS). SHL 360, or the Multi-Rater Feedback System (‘MFS’), provides a holistic 360-degree view of an employee by gathering feedback from the employee’s manager, peers, direct reports, and/or other raters.  By offering a wide range of perspectives, 360 feedback gives employees a more thorough understanding of not only their strengths, weaknesses, and development opportunities, but also their impact on others.  360-degree multi-rater assessments are based on SHL’s Universal Competency Framework (“UCF”), using our proven library of research-driven competencies to provide opportunities for managers, peers, and direct reports to supply useful developmental feedback that they may not otherwise share.  SHL can also offer support and training throughout the entire process, from defining objectives through interpreting and delivering the feedback.  360 feedback serves all levels and industries and is a positive and powerful addition to your performance management system.')]

# %%
len(documents)
# Out:
# 518

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

batch_size = 25
vectors_to_upsert = []

for i, row in df.iterrows():
    row = row.fillna("")
    text = f"{row['Test Name']}. {row['Description']}"
    embedding = model.encode(text).tolist()

    metadata = {
        "Test Name": str(row['Test Name']),
        "Test Link": str(row['Test Link']),
        "Description": str(row['Description']),
        "Assessment Length": str(row['Assessment Length']),
        "Job Levels": str(row['Job Levels']),
        "Remote Testing": str(row['Remote Testing']),
        "Adaptive/IRT": str(row['Adaptive/IRT']),
        "Test Type": str(row['Test Type'])
    }

    vector = (str(uuid4()), embedding, metadata)
    vectors_to_upsert.append(vector)

    if len(vectors_to_upsert) == batch_size or i == len(df) - 1:
        print(f"🔼 Upserting batch {i + 1 - batch_size + 1} to {i + 1}")
        try:
            index.upsert(vectors=vectors_to_upsert)
        except Exception as e:
            print(f"❌ Error during upsert: {e}")
            print("⏳ Retrying by refreshing Pinecone client...")
            try:
                pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
                index = pc.Index(index_name)
                index.upsert(vectors=vectors_to_upsert)
                print("✅ Retry succeeded.")
            except Exception as inner_e:
                print(f"❌ Retry failed again: {inner_e}")
                break
        vectors_to_upsert = []
# Out:
# 🔼 Upserting batch 1 to 25
# 🔼 Upserting batch 26 to 50
# ❌ Error during upsert: Failed to connect; did you specify the correct index name?
# ⏳ Retrying by refreshing Pinecone client...
# ✅ Retry succeeded.
# 🔼 Upserting batch 51 to 75
# 🔼 Upserting batch 76 to 100
# ❌ Error during upsert: Failed to connect; did you specify the correct index name?
# ⏳ Retrying by refreshing Pinecone client...
# ✅ Retry succeeded.
# 🔼 Upserting batch 101 to 125
# 🔼 Upserting batch 126 to 150
# 🔼 Upserting batch 151 to 175
# 🔼 Upserting batch 176 to 200
# 🔼 Upserting batch 201 to 225
# 🔼 Upserting batch 226 to 250
# 🔼 Upserting batch 251 to 275
# ❌ Error during upsert: Failed to connect; did you specify the correct index name?
# ⏳ Retrying by refreshing Pinecone client...
# ✅ Retry succeeded.
# 🔼 Upserting batch 276 to 300
# 🔼 Upserting batch 301 to 325
# 🔼 Upserting batch 326 to 350
# 🔼 Upserting batch 351 to 375
# 🔼 Upserting batch 376 to 400
# 🔼 Upserting batch 401 to 425
# 🔼 Upserting batch 426 to 450
# 🔼 Upserting batch 451 to 475
# 🔼 Upserting batch 476 to 500
# 🔼 Upserting batch 494 to 518

# %% [markdown]
# ## ReRanking using Pincone Library

# %%
query="Looking to hire mid-level professionals who are proficient in Python, SQL and Java Script. Need an assessment package that can test all skills with max duration of 60 minutes."
embedder = SentenceTransformer("all-MiniLM-L6-v2")
query_vector = embedder.encode(query).tolist()

# Step 1: Retrieve Top-K Candidates
retrieved = index.query(
    vector=query_vector,
    top_k=10,
    include_metadata=True
)

# Step 2: Prepare Documents for Reranking
transformed_documents = []
for i, match in enumerate(retrieved['matches']):
    metadata = match['metadata']
    transformed_documents.append({
        "id": str(i),
        "reranking_field": f"{metadata['Test Name']}. {metadata['Description']}",
        "metadata": metadata
    })

# Step 3: Call Pinecone Reranker
reranked_results_field = pc.inference.rerank(
    model="bge-reranker-v2-m3",
    query=query,
    documents=transformed_documents,
    rank_fields=["reranking_field"],
    top_n=5,
    return_documents=True
)

# Step 4: Show Reranked Results
def show_reranked_results(question, matches):
    print(f'\n🧠 Query: \'{question}\'')
    print('\n🔢 Reranked Results:\n')
    for i, match in enumerate(matches):
        doc = match.document
        metadata = doc.metadata
        print(f'{str(i+1).rjust(3)}. {metadata.get("Test Name")}')
        print(f'     🔢 Score: {match.score:.4f}')
        print(f'     🕒 Length: {metadata.get("Assessment Length")} | 🧑‍💼 Level: {metadata.get("Job Levels")}')
        print(f'     🔗 {metadata.get("Test Link")}\n')

show_reranked_results(query, reranked_results_field.data)
# Out:
# 🧠 Query: 'Looking to hire mid-level professionals who are proficient in Python, SQL and Java Script. Need an assessment package that can test all skills with max duration of 60 minutes.'
#
# 🔢 Reranked Results:
#
#   1. Python (New)
#      🔢 Score: 0.0595
#      🕒 Length: Approximate Completion Time in minutes = 11 | 🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/python-new/
#
#   2. Technology Professional 8.0 Job Focused Assessment
#      🔢 Score: 0.0148
#      🕒 Length: Approximate Completion Time in minutes = 16 | 🧑‍💼 Level: Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/technology-professional-8-0-job-focused-assessment/
#
#   3. Professional + 7.0 Solution
#      🔢 Score: 0.0088
#      🕒 Length: Approximate Completion Time in minutes = 51 | 🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/professional-7-0-solution-3958/
#
#   4. Graduate 7.1 Job Focused Assessment
#      🔢 Score: 0.0084
#      🕒 Length: Approximate Completion Time in minutes = 19 | 🧑‍💼 Level: Graduate,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/graduate-7-1-job-focused-assessment/
#
#   5. Job Control Language (New)
#      🔢 Score: 0.0070
#      🕒 Length: Approximate Completion Time in minutes = 10 | 🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/job-control-language-new/

# %% [markdown]
# ## Indexing Retrieval using BM25

# %%
import numpy as np
from typing import List
from langchain_core.documents import Document
from rank_bm25 import BM25Okapi

class FusionRetriever:
    def __init__(self, pinecone_index, sentence_model, documents: List[Document], alpha: float = 0.5):
        """
        Args:
        - pinecone_index: a Pinecone Index() object (not LangChain vectorstore)
        - sentence_model: SentenceTransformer embedding model
        - documents: List of Documents used for indexing
        - alpha: fusion weighting factor between vector and BM25 scores
        """
        self.index = pinecone_index
        self.model = sentence_model
        self.documents = documents
        self.alpha = alpha
        self.bm25 = self._create_bm25_index(documents)

    def _create_bm25_index(self, documents: List[Document]) -> BM25Okapi:
        tokenized_docs = [doc.page_content.split() for doc in documents if doc.page_content]
        return BM25Okapi(tokenized_docs)

    def retrieve(self, query: str, k: int = 5, fetch_k: int = 30) -> List[Document]:
        epsilon = 1e-8

        # Step 1: Encode query using the same SentenceTransformer used during indexing
        query_vector = self.model.encode(query).tolist()

        # Step 2: Query Pinecone directly
        response = self.index.query(
            vector=query_vector,
            top_k=fetch_k,
            include_metadata=True
        )

        if not response['matches']:
            print("⚠️ No results from vector store.")
            return []

        all_docs = []
        vector_scores = []

        for match in response['matches']:
            metadata = match['metadata']
            content = f"{metadata.get('Test Name', '')}. {metadata.get('Description', '')}"
            doc = Document(page_content=content, metadata=metadata)
            all_docs.append(doc)
            vector_scores.append(match['score'])

        # Normalize vector scores (inverted so higher = better)
        vector_scores = np.array(vector_scores)
        vector_scores = 1 - (vector_scores - np.min(vector_scores)) / (np.max(vector_scores) - np.min(vector_scores) + epsilon)

        # Step 3: BM25 scoring
        query_tokens = query.split()
        mini_bm25 = BM25Okapi([doc.page_content.split() for doc in all_docs])
        bm25_scores = mini_bm25.get_scores(query_tokens)

        bm25_scores = np.array(bm25_scores)
        if np.max(bm25_scores) > 0:
            bm25_scores = (bm25_scores - np.min(bm25_scores)) / (np.max(bm25_scores) - np.min(bm25_scores) + epsilon)
        else:
            bm25_scores = np.zeros_like(vector_scores)

        # Step 4: Combine scores
        combined_scores = self.alpha * vector_scores + (1 - self.alpha) * bm25_scores
        sorted_indices = np.argsort(combined_scores)[::-1]

        return [all_docs[i] for i in sorted_indices[:k]]

# %%
from langchain.embeddings import HuggingFaceEmbeddings
embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vectorstore = PineconeVectorStore(index=index, embedding=embedding)

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# Run retrieval
retriever = FusionRetriever(index, model, documents, alpha=0.5)
results = retriever.retrieve("Looking to hire mid-level professionals who are proficient in Python, SQL and Java Script. Need an assessment package that can test all skills with max duration of 60 minutes.", k=5)

# Display
for i, doc in enumerate(results):
    print(f"\n🔹 {i+1}. {doc.metadata['Test Name']}")
    print(f"   🕒 {doc.metadata['Assessment Length']}")
    print(f"   🧑‍💼 {doc.metadata['Job Levels']}")
    print(f"   🔗 {doc.metadata['Test Link']}")
# Out:
# 🔹 1. PJM Selection Report
#    🕒
#    🧑‍💼 Mid-Professional, Manager,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/pjm-selection-report/
#
# 🔹 2. Global Skills Development Report
#    🕒
#    🧑‍💼 Director, Entry-Level, Executive, General Population, Graduate, Manager, Mid-Professional, Front Line Manager, Supervisor,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/global-skills-development-report/
#
# 🔹 3. Verify - Following Instructions
#    🕒 Approximate Completion Time in minutes = 8
#    🧑‍💼 Entry-Level,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/verify-following-instructions/
#
# 🔹 4. RemoteWorkQ
#    🕒 Approximate Completion Time in minutes = 10
#    🧑‍💼 Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Front Line Manager, General Population, Graduate, Director, Entry-Level, Executive,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/remoteworkq/
#
# 🔹 5. Verify - Numerical Ability
#    🕒 Approximate Completion Time in minutes = 20
#    🧑‍💼 Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/verify-numerical-ability/

# %%
retriever

# %%
import pandas as pd
import json
import os
import re
import google.generativeai as genai
from dotenv import load_dotenv
from tqdm import tqdm

# === Load env + CSV ===
load_dotenv()
df = pd.read_csv("shl_enhanced_assessments_clean.csv")

# === Gemini API Setup ===
api_key = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=api_key)
llm = genai.GenerativeModel(model_name="gemini-2.0-flash", generation_config={"temperature": 0.9})

# === Prompt template ===
def generate_prompt(title: str, description: str) -> str:
    return f"""
You are an intelligent assistant designed to improve AI-based search and recommendation of assessments.

Your task is to analyze the given assessment title and description, and extract a concise list of relevant tags. These tags will help match assessments to user queries like:
“I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment(s) that can be completed in 40 minutes.”

Extract tags that accurately reflect:

Hard skills (e.g., Java, SQL, REST APIs)

Soft skills (e.g., collaboration, communication)

Job roles or levels (e.g., backend developer, mid-level, team lead)

Business domain or context (e.g., cross-functional, agile)

Assessment traits (e.g., time limit, difficulty level, scenario-based)

Be specific and comprehensive. Avoid generic or vague tags like “test” or “assessment.” Use domain-relevant terminology.

Return output ONLY in this JSON format:
{{"tags": ["tag1", "tag2", "tag3"]}}

Title: "{title}"
Description: "{description}"
"""

tag_column = []

for _, row in tqdm(df.iterrows(), total=len(df)):
    title = str(row.get("Test Name", ""))
    description = str(row.get("Description", ""))

    prompt = generate_prompt(title, description)

    try:
        response = llm.generate_content(prompt)
        response_text = response.text.strip()

        # Remove code block markers
        response_text = re.sub(r"^```json", "", response_text)
        response_text = re.sub(r"```$", "", response_text)
        response_text = response_text.strip()

        parsed = json.loads(response_text)
        tags = parsed.get("tags", [])
    except Exception as e:
        tags = []
        print(f"Error on '{title}': {e}")

    tag_column.append(tags)
# Out:
# 100%|██████████| 518/518 [08:36<00:00,  1.00it/s]

# %%
tag_column
# Out:
# [['Account Management',
#   'Client Communication',
#   'Project Management',
#   'Coordination',
#   'Client Expectations',
#   'Leadership',
#   'Mid-Level',
#   'Account Executive',
#   'Account Manager',
#   'Senior Account Manager'],
#  ['Administrative Assistant',
#   'Secretary',
#   'Office Manager',
#   'Administrative Aide',
#   'Administrative Associate',
#   'Entry-Level',
#   'Mid-Level',
#   'Clerical Skills',
#   'Administrative Skills',
#   'Office Management',
#   'Customer Service',
#   'Communication Skills',
#   'Scheduling',
#   'Meeting Arrangement',
#   'Correspondence',
#   'Office Coordination',
#   'Greeting Visitors'],
#  ['sales management',
#   'mid-level',
#   'front line management',
#   'financial activities',
#   'branch management',
#   'brokerage management',
#   'risk management',
#   'insurance management',
#   'credit department',
#   'agency manager',
#   'brokerage manager'],
#  ['entry-level',
#   'apprenticeship',
#   'cognitive ability',
#   'global',
#   'multi-national',
#   'job-focused',
#   'short assessment'],
#  ['entry-level',
#   'apprenticeship',
#   'job-focused',
#   'global',
#   'multi-national',
#   'short',
#   'aptitude',
#   'skills assessment'],
#  ['Administrative Assistant',
#   'Bank',
#   'Entry-Level',
#   'Clerical',
#   'Customer Service',
#   'Receptionist',
#   'Communication Skills',
#   'Office Administration',
#   'File Management',
#   'Record Keeping',
#   'Telephone Skills',
#   'Collaboration',
#   'Short Form'],
#  ['Bank Collections Agent',
#   'Entry-Level',
#   'Call Center',
#   'Financial Services',
#   'Multiple Choice Questions',
#   'Achievement Orientation',
#   'Dependability',
#   'Collector Numerical Skills',
#   'Revenue Recovery',
#   'Customer Focus',
#   'Persistence',
#   'Planfulness',
#   'Inbound',
#   'Outbound'],
#  ['Bank Operations',
#   'Supervisor',
#   'Entry-Level Leadership',
#   'Team Leader',
#   'First Line Supervisor',
#   'Processing Supervisor',
#   'Call Center Supervisor',
#   'Customer Service Supervisor',
#   'Supervising Hourly Employees',
#   'Work Schedule Planning',
#   'Employee Assignment',
#   'Coaching',
#   'Attendance',
#   'Conduct',
#   'Schedule Adherence',
#   'Employee Training',
#   'Prioritization',
#   'Decision-Making',
#   'Short Form'],
#  ['Bilingual Spanish',
#   'Reservation Agent',
#   'Customer Service',
#   'Hospitality Industry',
#   'Entry-Level',
#   'Customer Interaction',
#   'Spanish Language Proficiency',
#   'English Language Proficiency',
#   'Reservation Management',
#   'Communication Skills',
#   'Customer Service Representative',
#   'Reservationist',
#   'Call Center',
#   'Data Entry',
#   'Hotel Services',
#   'Information Provision'],
#  ['Bookkeeping',
#   'Accounting',
#   'Auditing',
#   'Clerk',
#   'Entry-Level',
#   'Data Entry',
#   'Financial Records',
#   'Numerical Data',
#   'Accounting Clerk',
#   'Bookkeeper',
#   'Accounting Associate',
#   'Auditing Clerk',
#   'Accounts Receivable Clerk',
#   'Financial Data Accuracy',
#   'Routine Computations'],
#  ['branch manager',
#   'financial institution',
#   'management potential',
#   'management judgment',
#   'leadership potential',
#   'team management',
#   'branch manager problem solving',
#   'business leadership',
#   'leadership motivation',
#   'interpersonal leadership',
#   'self leadership',
#   'branch manager judgment',
#   'multiple choice',
#   'mid-level',
#   'upper-level',
#   'banking'],
#  ['cashier',
#   'sales associate',
#   'clerk',
#   'retail',
#   'entry-level',
#   'customer service',
#   'payment processing',
#   'cash handling',
#   'credit card processing',
#   'check processing',
#   'receipts',
#   'refunds'],
#  ['self-assessment',
#   'skills development',
#   'Great 8 Domains',
#   'self-reported behaviors',
#   'actionable tips',
#   'skill strengths',
#   'growth skills',
#   'report',
#   'individual feedback',
#   'self-awareness'],
#  ['.NET Framework 4.5',
#   '.NET',
#   'Application Development',
#   'Application Foundation',
#   'Data Modeling',
#   'Deployment',
#   'Diagnostics',
#   'Performance',
#   'Portability',
#   'Security',
#   'Experienced Users'],
#  ['.NET',
#   'MVC',
#   'Model-View-Controller',
#   'Architecture',
#   'Validation',
#   'Security',
#   'Routing',
#   'Areas',
#   'C#',
#   'Multi-choice question',
#   'Software Development'],
#  ['.NET',
#   'MVVM',
#   'Model-View-ViewModel',
#   'Data Validation',
#   'ViewModel Communication',
#   'C#',
#   'Software Architecture',
#   'Design Patterns',
#   'Multi-Choice Questions'],
#  ['.NET',
#   'WCF',
#   'Windows Communication Foundation',
#   'SOA',
#   'Service-Oriented Architecture',
#   'Multi-choice',
#   'Fundamentals',
#   'Architecture',
#   'Programming Model',
#   'WCF Programming',
#   'WCF Management'],
#  ['.NET',
#   'WPF',
#   'XAML',
#   'C#',
#   'Desktop application development',
#   'Windows Forms',
#   'UI development',
#   'Multi-choice',
#   'Fundamentals',
#   'Deployment'],
#  ['.NET',
#   'XAML',
#   'Multi-choice',
#   'Triggers',
#   'Data Binding',
#   'Custom Controls',
#   'Layouts',
#   'Software Development'],
#  ['accounts payable',
#   'vendor invoices',
#   'journal entries',
#   'multiple-choice',
#   'accounting',
#   'finance',
#   'bookkeeping'],
#  ['Accounts Payable',
#   'Data Entry',
#   'Invoice Processing',
#   'Vendor Invoices',
#   'Simulation',
#   'Accounting',
#   'Finance',
#   'Accuracy',
#   'Efficiency'],
#  ['accounts receivable',
#   'invoice processing',
#   'financial accounting',
#   'multiple-choice',
#   'accounting',
#   'finance'],
#  ['Accounts Receivable',
#   'Data Entry',
#   'Invoice Processing',
#   'Simulation',
#   'Accounting',
#   'Finance'],
#  ['ADO.NET',
#   'Data Access',
#   'Microsoft Technologies',
#   'Multi-choice',
#   'Software Development',
#   'Database Connectivity',
#   'Data Provider',
#   'Architecture',
#   'Components'],
#  ['Adobe Experience Manager',
#   'AEM',
#   'AEM Components',
#   'AEM Templates',
#   'AEM Workflows',
#   'AEM Collections',
#   'OSGi Services',
#   'AEM Troubleshooting',
#   'Multi-choice',
#   'Software Engineer',
#   'Web Development',
#   'Content Management System'],
#  ['Adobe Photoshop CC',
#   'Image Editing',
#   'Graphic Design',
#   '3D',
#   'Color Correction',
#   'File Management',
#   'User Interface',
#   'Layers',
#   'Painting',
#   'Drawing',
#   'Retouching',
#   'Image Enhancement',
#   'Selection Tools',
#   'Text Tools',
#   'Web Design',
#   'Experienced Users'],
#  ['Aeronautical Engineering',
#   'Flight Mechanics',
#   'Space Dynamics',
#   'Aerodynamics',
#   'Structures',
#   'Propulsion',
#   'Multiple Choice',
#   'Engineering'],
#  ['Aerospace Engineering',
#   'Aerodynamics',
#   'Aircraft Systems',
#   'Instrumentation',
#   'Flight Dynamics',
#   'Space Dynamics',
#   'Avionics',
#   'Conceptual Knowledge',
#   'Multiple Choice',
#   'Engineering'],
#  ['Agile Methodology',
#   'Scrum',
#   'Feature Driven Development',
#   'Incremental Development',
#   'Iterative Development',
#   'Agile Processes',
#   'Software Development',
#   'Multi-choice',
#   'Knowledge Assessment'],
#  ['Agile Testing',
#   'Agile Methodology',
#   'Testing Techniques',
#   'Testing Tools',
#   'Testing Processes',
#   'Multi-choice',
#   'Knowledge Assessment'],
#  ['Artificial Intelligence',
#   'AI Skills',
#   'AI Literacy',
#   'AI Proficiency',
#   'AI Application',
#   'Technology Adoption',
#   'Digital Skills',
#   'Emerging Technologies'],
#  ['AWS',
#   'Amazon Web Services',
#   'Cloud Computing',
#   'Delivery Process',
#   'Monitoring',
#   'Metrics',
#   'Logging',
#   'Security',
#   'Scalability',
#   'Validation',
#   'Multi-choice',
#   'Technical Knowledge',
#   'Cloud Development'],
#  ['Android Development',
#   'UI Components',
#   'Services and Alerts',
#   'Animation',
#   'Media Apps',
#   'Application Components',
#   'Security',
#   'Testing',
#   'Mobile Development',
#   'Multi-Choice',
#   'Beginner'],
#  ['Angular 6',
#   'Angular',
#   'front-end development',
#   'TypeScript',
#   'data binding',
#   'dependency injection',
#   'CRUD',
#   'HTTP',
#   'routing',
#   'navigation',
#   'multi-choice',
#   'software engineering'],
#  ['AngularJS',
#   'JavaScript',
#   'Frontend Development',
#   'Multi-choice Questions',
#   'Architecture',
#   'Forms',
#   'Directives',
#   'Filters',
#   'Controllers',
#   'Routing',
#   'Testing',
#   'Software Engineer',
#   'Junior Developer',
#   'Mid-level Developer'],
#  ['Apache Hadoop',
#   'Hadoop',
#   'HDFS',
#   'MapReduce',
#   'Big Data',
#   'Data Engineering',
#   'Multi-choice',
#   'Basic Concepts'],
#  ['entry-level management',
#   'supervisory skills',
#   'team leadership',
#   'employee coaching',
#   'workforce management',
#   'scheduling',
#   'task prioritization',
#   'decision-making',
#   'training',
#   'first line supervisor',
#   'claims supervisor',
#   'operations supervisor',
#   'customer service supervisor',
#   'team leader',
#   'coach',
#   'hourly employees'],
#  ['Customer Service',
#   'Contact Center',
#   'Entry-Level',
#   'Mobile-Optimized',
#   'Simulation',
#   'Behavioral Assessment',
#   'Cognitive Test',
#   'Customer Service Skills',
#   'Customer Service Competencies',
#   'Customer Service Behaviors'],
#  ['Customer Service',
#   'Contact Center',
#   'Entry-Level',
#   'Customer Support',
#   'Help Desk',
#   'Call Center'],
#  ['Contact Center Management',
#   'Team Leadership',
#   'Supervision',
#   'Employee Training',
#   'Performance Management',
#   'Mid-Level',
#   'Upper-Level',
#   'Short Form'],
#  ['Contact Center',
#   'Customer Service',
#   'Sales',
#   'Sales & Service',
#   'Entry-Level',
#   'Mobile-Optimized',
#   'Simulation',
#   'Behavioral Assessment',
#   'Cognitive Test',
#   'Product Recommendation',
#   'Customer Retention',
#   'Job Focused Assessment'],
#  ['Contact Center',
#   'Sales',
#   'Service',
#   'Customer Retention',
#   'Product Recommendation',
#   'Service Recommendation',
#   'Sales-related Behaviors',
#   'Customer Service',
#   'Customer Support'],
#  ['Team Lead',
#   'Coach',
#   'Contact Center',
#   'Customer Service',
#   'First Line Supervisor',
#   'Supervisory Skills',
#   'Employee Coaching',
#   'Employee Training',
#   'Work Scheduling',
#   'Task Prioritization',
#   'Decision Making',
#   'Leadership',
#   'Entry-Level',
#   'Hourly Employees',
#   'Schedule Adherence',
#   'Conduct',
#   'Short Form'],
#  ['contact centre',
#   'customer service',
#   'entry-level',
#   'multiple choice questions',
#   'customer call simulation',
#   'working with information',
#   'customer focus',
#   'contact centre retention',
#   'navigation',
#   'service orientation',
#   'tactful problem solving',
#   'data entry speed',
#   'data entry accuracy',
#   'multi-tasking',
#   'achievement orientation',
#   'conscientiousness',
#   'UK',
#   'job simulation'],
#  ['Customer Service',
#   'Customer Service Representative',
#   'Entry-Level',
#   'Communication Skills',
#   'Problem Solving',
#   'Customer Interaction',
#   'Phone Support',
#   'In-Person Support',
#   'Order Taking',
#   'Issue Resolution',
#   'Complaint Handling',
#   'Account Service Representative',
#   'Customer Service Agent',
#   'Short Form'],
#  ['Customer Service',
#   'Customer Interaction',
#   'Entry-Level',
#   'Communication Skills',
#   'Problem Solving',
#   'Issue Resolution',
#   'Phone Support',
#   'In-Person Support',
#   'Order Taking',
#   'Product Information',
#   'Service Information',
#   'Account Service Representative',
#   'Account Representative',
#   'Customer Service Representative',
#   'Customer Service Agent',
#   'UK Context'],
#  ['Customer Service',
#   'Sales',
#   'Entry-Level',
#   'Order Taking',
#   'Problem Solving',
#   'Product Support',
#   'Service Support',
#   'Up-selling',
#   'Cross-selling',
#   'Customer Communication',
#   'Account Management',
#   'Account Service Representative',
#   'Customer Service Representative',
#   'Sales Representative',
#   'Customer Issue Resolution',
#   'Product Information',
#   'Service Information'],
#  ['Director',
#   'Senior Level',
#   'Management',
#   'Leadership',
#   'Strategic Planning',
#   'Operations Management',
#   'Policy Formulation',
#   'Resource Management',
#   'Human Resources',
#   'Business Operations',
#   'Planning',
#   'Directing',
#   'Coordinating',
#   'Short Form'],
#  ['Apache Hadoop',
#   'Pig',
#   'Hive',
#   'HBase',
#   'Data Engineering',
#   'Big Data',
#   'Conceptual Knowledge',
#   'Multi-choice Questions'],
#  ['Apache HBase',
#   'HBase',
#   'NoSQL',
#   'Big Data',
#   'CAP Theorem',
#   'ACID Properties',
#   'HBase Client API',
#   'MapReduce',
#   'Configuration',
#   'Administration',
#   'Multi-choice',
#   'Data Engineering',
#   'Backend'],
#  ['Apache Hive',
#   'Hive architecture',
#   'HiveQL',
#   'Data warehousing',
#   'Big data',
#   'Data engineer',
#   'Data analyst',
#   'Multi-choice',
#   'Technical skills'],
#  ['Apache Kafka',
#   'Kafka Architecture',
#   'Kafka Components',
#   'Kafka Clusters',
#   'Kafka Performance Tuning',
#   'Kafka Operations',
#   'Multiple Choice Questions',
#   'Data Streaming',
#   'Message Queues',
#   'Backend'],
#  ['Apache Pig',
#   'PigLatin',
#   'Data Engineering',
#   'Big Data',
#   'Hadoop',
#   'Multi-choice',
#   'Technical Knowledge'],
#  ['Apache Spark',
#   'RDD',
#   'actions',
#   'transformations',
#   'lineage graphs',
#   'lazy evaluation',
#   'data engineering',
#   'big data',
#   'multi-choice',
#   'intermediate'],
#  ['.NET Framework',
#   'ASP.NET',
#   'C#',
#   'Object-Oriented Programming (OOP)',
#   'Data Access',
#   'State Management',
#   'Security Services',
#   'Multi-Choice',
#   'Fundamentals',
#   'Advanced Topics'],
#  ['ASP.NET 4.5',
#   '.NET Framework',
#   'C#',
#   'Web Applications',
#   'Web Forms',
#   'Client-Side Programming',
#   'Data Access',
#   'Security',
#   'Troubleshooting',
#   'Optimization',
#   'Services',
#   'Mobile',
#   'Mid-Level Developer',
#   'Backend Developer',
#   'Experienced Developer'],
#  ['assessment center',
#   'development center',
#   'group exercise',
#   'role play',
#   'analysis presentation',
#   'written exercise',
#   'virtual assessment',
#   'remote assessment',
#   'job levels',
#   'industry contexts',
#   'SHL'],
#  ['C',
#   'C++',
#   'Java',
#   'debugging skills',
#   'code reuse',
#   'compiler',
#   'logical errors',
#   'syntactical errors',
#   'coding',
#   'software engineering',
#   'problem solving',
#   'code comprehension',
#   'simulated environment',
#   'New York City Law 144',
#   'automated employment decision tools'],
#  ['SQL',
#   'DDL',
#   'DML',
#   'DCL',
#   'Query Writing',
#   'Database',
#   'Data Definition Language',
#   'Data Manipulation Language',
#   'Data Control Language',
#   'Simulated Assessment'],
#  ['coding simulation',
#   'programming ability',
#   'IDE environment',
#   '40+ programming languages',
#   'real-world coding problems',
#   'AI-powered',
#   'New York City Law 144 compliance'],
#  ['District Manager',
#   'Regional Manager',
#   'General Manager',
#   'Store Manager',
#   'Area Manager',
#   'Mid-Level',
#   'Senior-Level',
#   'Managerial Positions',
#   'Profit and Loss Responsibility',
#   'Directing Supervisors',
#   'Directing Managers',
#   'Company Goals Alignment',
#   'Multiple Stores Oversight',
#   'Retail',
#   'Management'],
#  ['Cashier',
#   'Entry Level',
#   'Retail',
#   'Customer Service',
#   'Payment Handling',
#   'Cash Handling',
#   'Credit Card Processing',
#   'Sales Associate',
#   'Clerk',
#   'Receipt Issuance',
#   'Refund Processing'],
#  ['Cashier',
#   'Entry-Level',
#   'Retail',
#   'Customer Service',
#   'Payment Handling',
#   'Sales Associate',
#   'Clerk',
#   'Receipts',
#   'Refunds',
#   'Cash Handling',
#   'Credit Card Processing',
#   'Check Processing',
#   'International'],
#  ['customer service',
#   'entry-level',
#   'retail',
#   'contact center',
#   'communication skills',
#   'problem-solving',
#   'customer interaction',
#   'order taking',
#   'issue resolution',
#   'handling difficult customers',
#   'phone interaction',
#   'in-person interaction',
#   'Americas region'],
#  ['Customer Service',
#   'Entry Level',
#   'Customer Interaction',
#   'Phone Support',
#   'In-Person Support',
#   'Order Taking',
#   'Problem Solving',
#   'Complaint Resolution',
#   'Retail',
#   'Contact Center',
#   'International Norms',
#   'Service Issues',
#   'Customer Requests'],
#  ['Customer Service',
#   'Entry-Level',
#   'Retail',
#   'Contact Center',
#   'Customer Interaction',
#   'Order Taking',
#   'Problem Solving',
#   'Customer Support',
#   'Communication Skills',
#   'South Africa',
#   'International',
#   'Americas',
#   'Norm Referenced',
#   'Product Support',
#   'Service Support',
#   'Phone Support',
#   'In-Person Support',
#   'Difficult Customers',
#   'Irate Customers'],
#  ['Sales',
#   'Entry-level',
#   'Americas',
#   'Customer service',
#   'Sales revenue',
#   'Product promotion',
#   'Persuasion',
#   'Transaction completion',
#   'Customer interaction',
#   'Sales positions',
#   'Sales skills'],
#  ['Sales',
#   'Entry-Level',
#   'Customer Interaction',
#   'Sales Revenue',
#   'Persuasion',
#   'Product Promotion',
#   'Transaction Completion',
#   'International',
#   'English (USA)',
#   'English International',
#   'Portuguese',
#   'French Canadian',
#   'German',
#   'French',
#   'Chinese Simplified',
#   'Spanish',
#   'North American Spanish'],
#  ['Entry-Level',
#   'Sales',
#   'Customer Service',
#   'Sales Revenue',
#   'Persuasion',
#   'Transaction Completion',
#   'Product Promotion',
#   'Sift Out',
#   'Customer Interaction'],
#  ['Event Sales Manager',
#   'Events Manager',
#   'Special Events Manager',
#   'Hospitality Industry',
#   'Management Level',
#   'Sales',
#   'Problem Solving',
#   'Decision Making',
#   'Facility Sales',
#   'Staff Management'],
#  ['executive',
#   'leadership',
#   'strategic planning',
#   'policy formulation',
#   'executive vice president',
#   'president',
#   'executive director',
#   'senior management',
#   'governance',
#   'decision-making'],
#  ['Financial Professional',
#   'Mid-Level',
#   'Series 6 Certification',
#   'Series 7 Certification',
#   'Multiple Choice Questions',
#   'Financial Aptitude',
#   'Learning Potential',
#   'Achievement Orientation',
#   'Conscientiousness',
#   'Persistence',
#   'Planfulness',
#   'Self Leadership',
#   'Interpersonal Leadership',
#   'Sales Focus',
#   'Customer Focus',
#   'Financial Institution'],
#  ['Data Science',
#   'Machine Learning',
#   'Algorithms',
#   'Data Analysis',
#   'Data Modification',
#   'Simulated Test',
#   'Predictive Modeling',
#   'Statistical Analysis'],
#  ['Data Science',
#   'Machine Learning',
#   'Algorithms',
#   'Data Analysis',
#   'Data Modification',
#   'Simulation',
#   'Pro Level'],
#  ['front-end development',
#   'HTML',
#   'CSS',
#   'JavaScript',
#   'simulation-based',
#   'coding',
#   'manual scoring'],
#  ['coding simulation',
#   'AI-powered',
#   'programming ability',
#   'IDE environment',
#   '40+ programming languages',
#   'real-world coding problems',
#   'New York City Law 144 compliance',
#   'Automated Employment Decision Tools'],
#  ['Selenium',
#   'Automation Testing',
#   'Coding Simulation',
#   'Software Testing',
#   'QA Engineer',
#   'Test Automation Engineer',
#   'Scripting',
#   'Practical Assessment',
#   'Hands-on'],
#  ['Automation Anywhere',
#   'RPA',
#   'Robotic Process Automation',
#   'RPA Development',
#   'Automation Anywhere Dashboard',
#   'Automation Anywhere Task Editor',
#   'Automation Anywhere Control Room',
#   'Bots',
#   'Automation Anywhere Client',
#   'Multi-choice',
#   'Technical Skills'],
#  ['Automotive Engineering',
#   'Engine Classification',
#   'Engine Fuel System',
#   'Auto-Vehicle Technology',
#   'Maintenance',
#   'Inspection',
#   'Troubleshooting',
#   'Multi-choice',
#   'Mechanical Engineering',
#   'Automotive Technician'],
#  ['Biology',
#   'Basic Biology',
#   'Life Sciences',
#   'Multiple Choice',
#   'Entry-Level',
#   'Fundamental Concepts'],
#  ['Computer Literacy',
#   'Windows 10',
#   'Application Software',
#   'Computer Terms',
#   'Internet and Email',
#   'Managing Files',
#   'Operating System',
#   'Parts of the Computer',
#   'Multiple Choice Questions',
#   'Simulation-based Questions',
#   'Basic Level',
#   'Beginner Level',
#   'General Computer Knowledge'],
#  ['Statistics',
#   'Statistical Methods',
#   'Exploratory Analysis',
#   'Probability',
#   'Distributions',
#   'Statistical Testing',
#   'Multi-choice',
#   'Quantitative Analysis',
#   'Data Analysis',
#   'Basic Statistics'],
#  ['biochemistry',
#   'bio-molecules',
#   'amino acids',
#   'proteins',
#   'enzymes',
#   'carbohydrates',
#   'vitamins',
#   'nucleic acids',
#   'bioenergetics',
#   'metabolism',
#   'multiple-choice',
#   'knowledge assessment'],
#  ['biotech',
#   'biotechnology',
#   'biophysical techniques',
#   'bio-processing',
#   'separation techniques',
#   'chromatography',
#   'electrophoresis',
#   'multiple-choice',
#   'knowledge assessment',
#   'lab techniques'],
#  ['Financial Services Representative',
#   'Insurance',
#   'Life Insurance',
#   'Sales',
#   'Policy Management',
#   'Client Relations',
#   'Premium Calculation',
#   'Networking',
#   'Senior-Level',
#   'Insurance Sales Agent',
#   'Life Insurance Sales Professional'],
#  ['front desk associate',
#   'customer service',
#   'hospitality industry',
#   'entry-level',
#   'front desk clerk',
#   'guest desk attendant',
#   'guest check-in associate',
#   'front office agent',
#   'guest relations',
#   'check-in',
#   'payment processing',
#   'communication skills',
#   'interpersonal skills'],
#  ['Gaming',
#   'Casino',
#   'Table Games',
#   'Dealer',
#   'Blackjack Dealer',
#   'Card Dealer',
#   'Gaming Dealer',
#   'Customer Service',
#   'Money Handling',
#   'Entry-Level',
#   'Mid-Level',
#   'Accuracy',
#   'Attention to Detail',
#   'Cash Handling',
#   'Chip Handling',
#   'Patron Interaction'],
#  ['Gaming Management',
#   'Hospitality Industry',
#   'Management Level',
#   'Operations Management',
#   'Supervisory Skills',
#   'Team Management',
#   'Security',
#   'Integrity',
#   'Sales Management',
#   'Gaming Floor Manager',
#   'Gaming Manager'],
#  ['entry-level',
#   'all industries',
#   'general aptitude',
#   'dependability',
#   'rule following',
#   'respectfulness',
#   'quality work',
#   'goal achievement',
#   'teamwork',
#   'on-time arrival',
#   'policy adherence',
#   'interpersonal skills',
#   'foundational skills',
#   'administrator',
#   'clerk',
#   'veterinary assistant',
#   'stocker',
#   'dish washer',
#   'office coordinator',
#   'tour guide',
#   'cook',
#   'assistant',
#   'housekeeper',
#   'waste collector'],
#  ['entry-level',
#   'all industries',
#   'general aptitude',
#   'dependability',
#   'rule following',
#   'respectfulness',
#   'work quality',
#   'goal achievement',
#   'teamwork',
#   'behavioral assessment',
#   'administrator',
#   'clerk',
#   'veterinary assistant',
#   'stocker',
#   'dish washer',
#   'office coordinator',
#   'tour guide',
#   'cook',
#   'assistant',
#   'housekeeper',
#   'waste collector',
#   'Americas norm',
#   'international norm'],
#  ['entry-level',
#   'all industries',
#   'on-time arrival',
#   'policy adherence',
#   'respectful behavior',
#   'work quality',
#   'goal achievement',
#   'teamwork',
#   'foundational skills',
#   'administrator',
#   'clerk',
#   'veterinary assistant',
#   'stocker',
#   'dish washer',
#   'office coordinator',
#   'tour guide',
#   'cook',
#   'assistant',
#   'housekeeper',
#   'waste collector'],
#  ['Data Entry',
#   'Entry-Level',
#   'Typing Speed',
#   'Typing Accuracy',
#   'Data Management Systems',
#   'On-time Attendance',
#   'Policy Adherence',
#   'Respectful Behavior',
#   'Work Quality',
#   'Goal Achievement',
#   'Thoroughness',
#   'Precision',
#   'Administrative Clerk',
#   'Accounts Receivable Clerk',
#   'Administrative Clerk',
#   'Clerical Aide',
#   'Clerical Assistant',
#   'Office Assistant',
#   'Office Services Specialist',
#   'Staff Assistant',
#   'General Skills',
#   'Clerical Skills'],
#  ['graduate',
#   'entry-level',
#   'cognitive ability',
#   'potential',
#   'onboarding',
#   'professional level',
#   'SHL Graduate Solution',
#   'globally applicable',
#   'short assessment',
#   'job focused'],
#  ['entry-level', 'recent graduate', 'professional level', 'job-focused'],
#  ['graduate',
#   'entry-level',
#   'potential',
#   'onboarding',
#   'new hires',
#   'job-focused',
#   'SHL Graduate Solution',
#   'professional level',
#   'recent college graduates'],
#  ['customer service',
#   'teamwork',
#   'communication',
#   'entry-level',
#   'guest services',
#   'interpersonal skills',
#   'responsibility',
#   'policy adherence',
#   'order fulfillment',
#   'server',
#   'hostess',
#   'team member',
#   'customer service champion',
#   'english (USA)',
#   'latin american spanish'],
#  ['BizTalk',
#   'Integration',
#   'Middleware',
#   'Business Process Management',
#   'BPM',
#   'Enterprise Service Bus',
#   'ESB',
#   'BizTalk Architecture',
#   'BizTalk Pipelines',
#   'BizTalk Adapters',
#   'BizTalk Administration',
#   'Multi-Choice',
#   'Technical Knowledge'],
#  ['business communication',
#   'adaptive assessment',
#   'workplace communication',
#   'interpersonal communication',
#   'electronic communication',
#   'employment communication',
#   'listening skills',
#   'meeting skills',
#   'nonverbal communication',
#   'verbal communication',
#   'written communication',
#   'communication skills',
#   'professional communication'],
#  ['business communication',
#   'workplace communication',
#   'electronic communication',
#   'employment communication',
#   'listening skills',
#   'meeting skills',
#   'nonverbal communication',
#   'verbal communication',
#   'written communication',
#   'communication skills',
#   'interpersonal skills',
#   'professional communication',
#   'non-adaptive'],
#  ['C Programming',
#   'Basics',
#   'Functions',
#   'Arrays',
#   'Data Types',
#   'Structures',
#   'File Handling',
#   'Dynamic Memory',
#   'Multiple Choice',
#   'Technical Skills'],
#  ['C#',
#   'C# Programming',
#   'Object-Oriented Programming',
#   'OOP',
#   'Data Structures',
#   'Collections',
#   'Enumeration',
#   'Exception Handling',
#   'Inheritance',
#   'Event Handling',
#   'Operator Overloading',
#   'Multi-choice',
#   'Programming Fundamentals',
#   'Software Development'],
#  ['C++',
#   'C++ Programming',
#   'C++ Standard Library',
#   'Data Structures',
#   'Algorithms',
#   'Object-Oriented Programming',
#   'Multi-Choice',
#   'Programming Fundamentals',
#   'Software Development',
#   'Junior Developer'],
#  ['Cardiology',
#   'Diabetes Management',
#   'Cardiovascular Diseases',
#   'Diabetes',
#   'Diagnostic Tests',
#   'Medical Knowledge',
#   'Healthcare',
#   'Multi-choice',
#   'Clinical Knowledge'],
#  ['Ceramic Engineering',
#   'Ceramics',
#   'Materials Science',
#   'Thermodynamics',
#   'Materials Classification',
#   'Ceramics Production',
#   'Multiple Choice',
#   'Engineering',
#   'Knowledge Assessment'],
#  ['Chemical Engineering',
#   'Transport Phenomena',
#   'Chemical Process Engineering',
#   'Chemical Process Principles',
#   'Stoichiometry',
#   'Process Calculations',
#   'Conceptual Knowledge',
#   'Multiple Choice Questions'],
#  ['Cisco AppDynamics',
#   'Application Analytics',
#   'Performance Management',
#   'Controller UI',
#   'Custom Dashboard',
#   'Reports',
#   'Monitoring',
#   'Multi-choice',
#   'Application Performance Monitoring',
#   'APM'],
#  ['Civil Engineering',
#   'Structural Engineering',
#   'Transportation Engineering',
#   'Surveying',
#   'Geotechnical Engineering',
#   'Water Resources Engineering',
#   'Multi-choice',
#   'Knowledge Assessment'],
#  ['Cloud Computing',
#   'Cloud Service Models',
#   'Virtualization',
#   'Private Clouds',
#   'Multiple Choice',
#   'Knowledge Assessment'],
#  ['customer service',
#   'hospitality',
#   'guest services',
#   'concierge',
#   'front office',
#   'entry-level',
#   'mid-level',
#   'communication skills',
#   'recommendation skills',
#   'problem-solving',
#   'reservations',
#   'information provision',
#   'guest relations',
#   'service orientation'],
#  ['Healthcare Aide',
#   'Personal Care Aide',
#   'Home Health Aide',
#   'Dental Assistant',
#   'Entry-Level',
#   'Patient Care',
#   'Following Instructions',
#   'Personal Care Administration',
#   'Respect',
#   'Tolerance',
#   'Record Keeping',
#   'Patient Progress',
#   'Meeting Patient Needs',
#   'English (USA)',
#   'Latin American Spanish'],
#  ['Healthcare',
#   'Call Center Agent',
#   'Entry-Level',
#   'Inbound Calls',
#   'Customer Service',
#   'Data Entry',
#   'Call Center Representative',
#   'Receptionist',
#   'Switchboard Operator',
#   'Communication Skills',
#   'Computer Skills'],
#  ['healthcare',
#   'service associate',
#   'entry-level',
#   'patient interaction',
#   'housekeeping',
#   'dietary aide',
#   'guest services',
#   'hospital',
#   'customer service',
#   'cleaning',
#   'food service'],
#  ['Healthcare Support Specialist',
#   'Entry-Level',
#   'Non-Patient Facing',
#   'Food Preparation',
#   'Hospital Linens',
#   'Cleaning',
#   'Janitor',
#   'Food Preparation Worker',
#   'Laundry Associate',
#   'Healthcare Facility'],
#  ['Home Health Aide',
#   'Personal Care Aide',
#   'Residential Assistant',
#   'Certified Nursing Assistant',
#   'Entry-level',
#   'In-home care',
#   'Group home',
#   'Vital signs monitoring',
#   'Medication intake monitoring',
#   'Bedside care',
#   'Personal hygiene',
#   'Ambulation assistance',
#   'Patient progress records',
#   'Services performed records'],
#  ['Hospitality Management',
#   'Property Management',
#   'Hotel Management',
#   'Staff Management',
#   'Guest Experience',
#   'Business Operations',
#   'Problem Solving',
#   'Decision Making',
#   'Customer Focus',
#   'Management Level',
#   'Property Manager',
#   'Property Director',
#   'Hotel Manager',
#   'Hospitality Manager'],
#  ['hospitality',
#   'entry level',
#   'host',
#   'hostess',
#   'greeter',
#   'customer service',
#   'work ethic',
#   'customer focus',
#   'guest relations',
#   'wait list management',
#   'greeting guests',
#   'showing guests to tables'],
#  ['Industrial',
#   'Entry Level',
#   'Laborer',
#   'Custodian',
#   'Building and Grounds Maintenance Worker',
#   'Handyman',
#   'Following Policies and Procedures',
#   'Facility Upkeep',
#   'Quality Work',
#   'Work Environment',
#   'Protective Equipment',
#   'Thoroughness',
#   'Safety',
#   'English (USA)',
#   'Latin American Spanish'],
#  ['entry-level',
#   'industrial',
#   'laborer',
#   'custodian',
#   'building and grounds maintenance workers',
#   'handyman',
#   'following policies and procedures',
#   'facility upkeep',
#   'quality work',
#   'work environment',
#   'protective equipment',
#   'thoroughness',
#   'safety',
#   'behavioral assessment',
#   'Americas norm'],
#  ['entry-level',
#   'industrial',
#   'general labor',
#   'light industrial',
#   'safety',
#   'following procedures',
#   'quality work',
#   'workplace organization',
#   'protective equipment',
#   'thoroughness',
#   'laborer',
#   'custodian',
#   'building maintenance',
#   'grounds maintenance',
#   'handyman',
#   'international',
#   'behavioral assessment',
#   'experience assessment'],
#  ['industrial',
#   'mechanical comprehension',
#   'safety',
#   'efficiency',
#   'equipment maintenance',
#   'machinery maintenance',
#   'mechanical decisions',
#   'workplace organization',
#   'quality',
#   'reliability',
#   'technical roles',
#   'professional roles',
#   'behavioral assessment',
#   'experience assessment',
#   'English (USA)',
#   'Latin American Spanish'],
#  ['COBOL',
#   'COBOL Programming',
#   'Fundamentals',
#   'Programming Structure',
#   'Application Processing',
#   'Multi-choice',
#   'Entry-level'],
#  ['Computer Science',
#   'Operating Systems',
#   'Computer Architecture',
#   'DBMS',
#   'Database Management Systems',
#   'Computer Networks',
#   'Communication',
#   'Multi-choice',
#   'Fundamentals',
#   'Entry-level'],
#  ['Contact Center',
#   'Call Simulation',
#   'Customer Service',
#   'Customer Support',
#   'Communication Skills',
#   'Problem Solving',
#   'Documentation',
#   'Typing Skills',
#   'Process Adherence',
#   'Scenario-Based',
#   'Call Handling',
#   'Customer Concerns',
#   'Standard Process',
#   'Simulation'],
#  ['customer service',
#   'chat simulation',
#   'communication skills',
#   'problem-solving',
#   'process adherence',
#   'time management',
#   'written communication',
#   'grammar',
#   'vocabulary',
#   'scenario-based',
#   'customer support',
#   'help desk',
#   'open-ended',
#   'real-job setting',
#   'customer query resolution'],
#  ['Java',
#   'Core Java',
#   'Advanced Level',
#   'Object-Oriented Programming',
#   'OOP',
#   'Generics',
#   'Collections',
#   'Threads',
#   'Strings',
#   'Concurrency',
#   'Exception Handling',
#   'File Handling',
#   'Multi-Choice',
#   'Technical Skills'],
#  ['Java',
#   'Core Java',
#   'Entry Level',
#   'Junior Developer',
#   'Object-Oriented Programming',
#   'OOP',
#   'File Handling',
#   'Exception Handling',
#   'Threads',
#   'Generics',
#   'Inner Classes',
#   'Multi-Choice'],
#  ['Money Handling',
#   'Cash Handling',
#   'Basic Math',
#   'Entry-Level',
#   'Retail',
#   'Customer Service',
#   'Accuracy',
#   'US Currency'],
#  ['CSS3',
#   'Cascading Style Sheets',
#   'Web Development',
#   'Front-end Development',
#   'Styling',
#   'Multi-choice',
#   'Beginner',
#   'HTML',
#   'Web Documents'],
#  ['culinary skills',
#   'cooking principles',
#   'cooking equipment',
#   'meal preparation',
#   'food presentation',
#   'kitchen safety',
#   'food service',
#   'multiple-choice',
#   'knowledge assessment'],
#  ['customer service',
#   'call center',
#   'contact center',
#   'phone simulation',
#   'entry-level',
#   'customer interaction',
#   'issue resolution',
#   'active listening',
#   'information retrieval',
#   'typing speed',
#   'customer service representative',
#   'call center representative',
#   'contact center agent',
#   'customer service agent',
#   'customer advocate',
#   'Mandarin',
#   'Cantonese'],
#  ['Customer Service',
#   'Contact Center',
#   'Simulation',
#   'Behavioral Assessment',
#   'Listening Skills',
#   'Problem Solving',
#   'Information Navigation',
#   'Data Entry',
#   'Learning Potential',
#   'Goal Orientation',
#   'Resilience',
#   'Entry-Level',
#   'Customer Interaction',
#   'Issue Resolution',
#   'Computer Skills',
#   'Mandarin',
#   'Cantonese'],
#  ['Cyber Risk Management',
#   'System Security',
#   'Application Security',
#   'Network Security',
#   'Security Management',
#   'Multiple Choice',
#   'Information Security',
#   'Risk Assessment'],
#  ['Industrial',
#   'Semi-skilled',
#   'Entry-level',
#   'Production Worker',
#   'Assembly Worker',
#   'Construction Worker',
#   'Extraction Technician',
#   'Following Procedures',
#   'Trade Skills',
#   'Protective Equipment',
#   'Equipment Monitoring',
#   'Quality Work',
#   'Teamwork',
#   'Work Environment',
#   'Safety',
#   'Americas Norm'],
#  ['Industrial',
#   'Semi-skilled',
#   'Entry-level',
#   'Production Worker',
#   'Assembly Worker',
#   'Construction Worker',
#   'Extraction Technician',
#   'Following procedures',
#   'Trade skills',
#   'Safety',
#   'Protective equipment',
#   'Equipment operation',
#   'Quality control',
#   'Teamwork',
#   'Work environment',
#   'International norm'],
#  ['industrial',
#   'professional',
#   'skilled',
#   'mechanical comprehension',
#   'safety',
#   'efficiency',
#   'equipment maintenance',
#   'machinery maintenance',
#   'mechanical decisions',
#   'workplace organization',
#   'quality work',
#   'reliability',
#   'technical roles',
#   'Americas'],
#  ['industrial',
#   'professional',
#   'skilled',
#   'mechanical comprehension',
#   'safety',
#   'efficiency',
#   'equipment maintenance',
#   'machinery maintenance',
#   'mechanical decisions',
#   'workplace organization',
#   'quality',
#   'reliability',
#   'technical roles',
#   'installation',
#   'repair',
#   'behavioral assessment',
#   'experience assessment'],
#  ['Telecommunications',
#   'Installation',
#   'Repair',
#   'Field Technician',
#   'Entry-level',
#   'Customer Interaction',
#   'Network Infrastructure',
#   'Service Technician',
#   'Customer Installation Technician',
#   'Equipment Maintenance'],
#  ['Insurance Account Manager',
#   'Account Executive',
#   'Account Manager',
#   'Senior Account Manager',
#   'Mid-level',
#   'Customer service',
#   'Sales',
#   'Customer interaction',
#   'Complaint resolution',
#   'Billing',
#   'Record keeping',
#   'Insurance',
#   'Financial services'],
#  ['Administrative Assistant',
#   'Receptionist',
#   'Entry-Level',
#   'Clerical',
#   'Customer Service',
#   'Communication Skills',
#   'File Management',
#   'Record Keeping',
#   'Telephone Etiquette',
#   'Mail Sorting',
#   'Information Handling',
#   'Collaboration',
#   'Insurance Domain'],
#  ['insurance',
#   'insurance agent',
#   'insurance sales',
#   'property insurance',
#   'casualty insurance',
#   'automotive insurance',
#   'insurance sales professional',
#   'producer',
#   'mid-level',
#   'policyholder communication',
#   'premium calculation',
#   'customer service',
#   'insurance claims',
#   'policy customization',
#   'sales'],
#  ['Insurance',
#   'Director',
#   'Regional Manager',
#   'Associate Director',
#   'Managing Director',
#   'Sales Management',
#   'Senior-Level',
#   'Profit and Loss Responsibility',
#   'Strategic Alignment',
#   'Multi-location Management',
#   'Brokerage Management',
#   'Agency Management'],
#  ['Insurance Sales Manager',
#   'Sales Manager',
#   'Assistant Sales Manager',
#   'Sales Supervisor',
#   'Entry-level',
#   'Mid-level',
#   'Management',
#   'Supervising',
#   'Sales',
#   'Sales statistics analysis',
#   'Customer relationships',
#   'Training',
#   'Work schedules',
#   'Decision-making',
#   'Insurance',
#   'Product promotion'],
#  ['leadership',
#   'management',
#   'entry-level',
#   'salaried employees',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'coordination',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'problem-solving',
#   'strategic decisions',
#   'day-to-day decisions',
#   'manager',
#   'store manager',
#   'branch manager'],
#  ['leadership',
#   'entry-level',
#   'manager',
#   'supervision',
#   'salaried employees',
#   'deductive reasoning',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'coordination',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'problem-solving',
#   'strategic decision-making',
#   'Verify Interactive',
#   'SHL',
#   'mobile-first',
#   'English (USA)'],
#  ['Data Entry',
#   'Transcription',
#   'Data Verification',
#   'Accuracy',
#   'Typing',
#   'Form Filling',
#   'Administrative Assistant',
#   'Entry-Level'],
#  ['Data Entry',
#   'Alphanumeric Data Entry',
#   'Typing Speed',
#   'Typing Accuracy',
#   'Forms Processing',
#   'Invoice Processing',
#   'Address Verification',
#   'Product Number Identification',
#   'Numerical Data Entry',
#   'Text Data Entry',
#   'US Specific',
#   'Data Processing',
#   'Entry Level'],
#  ['Data Entry',
#   'Numeric Data Entry',
#   'Split Screen',
#   'Typing Speed',
#   'Typing Accuracy',
#   'Data Entry Speed',
#   'Data Entry Accuracy',
#   'Numeric Keypad',
#   'Keyboard Skills',
#   'Business Records',
#   'Order Number',
#   'Customer Number',
#   'Item Number',
#   'Quantity',
#   'Attention to Detail'],
#  ['Data Entry',
#   'Ten Key',
#   'Numeric Keypad',
#   'Accuracy',
#   'Speed',
#   'Typing Skills',
#   'Data Processing'],
#  ['Data Science',
#   'Machine Learning',
#   'Data Analysis',
#   'Statistical Analysis',
#   'Decision Making',
#   'Conceptual Knowledge',
#   'Multi-choice',
#   'Information Extraction'],
#  ['Data Warehousing',
#   'Big Data',
#   'Data Warehouse Appliance',
#   'Business Considerations',
#   'Data Transformation',
#   'Data Marts',
#   'Dimensional Data Model',
#   'OLAP',
#   'Querying',
#   'Reporting',
#   'Data Extraction',
#   'Experienced Users'],
#  ['Dependability',
#   'Reliability',
#   'Counter-Productive Work Behaviors',
#   'Pre-screening',
#   'Entry-Level Roles',
#   'Employee Selection',
#   'Workplace Safety'],
#  ['Dermatology',
#   'Skin Diseases',
#   'Medical Knowledge',
#   'Multi-Choice Questions',
#   'Symptoms',
#   'Medical Terminology',
#   'Drug Knowledge',
#   'Clinical Knowledge'],
#  ['Desktop Support',
#   'Technical Support',
#   'Networking',
#   'Peripheral Components',
#   'Operating Systems',
#   'Troubleshooting',
#   'Multi-choice',
#   'Help Desk',
#   'IT Support'],
#  ['Digital Advertising',
#   'AdWords',
#   'Ad Performance Analysis',
#   'Digital Media',
#   'Multi-Choice',
#   'Marketing',
#   'Advertising',
#   'Campaign Analysis'],
#  ['digital readiness',
#   'individual contributor',
#   'non-managerial',
#   'self-assessment',
#   'behavioral assessment',
#   'work style',
#   'development report',
#   'SHL',
#   'digital skills',
#   'strengths',
#   'development activities',
#   'questionnaire',
#   'IC'],
#  ['digital readiness',
#   'management',
#   'leadership',
#   'self-assessment',
#   'development report',
#   'SHL Digital Readiness Framework',
#   'behavioral assessment',
#   'managerial skills',
#   'soft skills',
#   'development activities',
#   'questionnaire-based',
#   'employee development',
#   'work style',
#   'strengths identification',
#   'individual contributor comparison'],
#  ['leadership',
#   'entry-level',
#   'manager',
#   'deductive reasoning',
#   'problem-solving',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'strategic decisions',
#   'supervision',
#   'performance management',
#   'Americas',
#   'mobile-first',
#   'SHL Verify Interactive',
#   'salaried employees',
#   'department goals',
#   'organizational goals',
#   'English (USA)',
#   'Canadian French'],
#  ['leadership',
#   'entry-level',
#   'manager',
#   'supervision',
#   'salaried employees',
#   'deductive reasoning',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'coordination',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'problem-solving',
#   'strategic decisions',
#   'cross-functional',
#   'English (USA)',
#   'Canadian French',
#   'Brazilian Portuguese',
#   'Danish',
#   'Dutch',
#   'Finnish',
#   'Italian',
#   'Norwegian',
#   'Swedish',
#   'mobile-first assessment',
#   'SHL Verify Interactive'],
#  ['leadership',
#   'management',
#   'entry-level',
#   'supervisory',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'coordination',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'problem-solving',
#   'strategic decision making',
#   'employee management',
#   'customer service',
#   'English (USA)',
#   'Latin American Spanish'],
#  ['entry-level leadership',
#   'manager',
#   'supervisory role',
#   'salaried employees',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'coordination',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'problem-solving',
#   'strategic decisions',
#   'day-to-day decisions',
#   'leadership assessment',
#   'Americas region',
#   'English (USA)',
#   'Danish',
#   'Finnish',
#   'Canadian French',
#   'Italian',
#   'Norwegian',
#   'French',
#   'German',
#   'English International'],
#  ['leadership',
#   'entry-level',
#   'manager',
#   'supervision',
#   'project planning',
#   'collaboration',
#   'coaching',
#   'employee development',
#   'coordination',
#   'goal setting',
#   'prioritization',
#   'decision-making',
#   'problem-solving',
#   'international',
#   'salaried employees'],
#  ['first-line manager',
#   'leadership',
#   'management potential',
#   'reskilling potential',
#   'salaried employees',
#   'behavioral assessment',
#   'managerial skills',
#   'job-focused assessment',
#   'JFA',
#   'supervisory roles',
#   'entry-level management'],
#  ['first-line manager',
#   'leadership',
#   'management potential',
#   'reskilling potential',
#   'inductive reasoning',
#   'SHL Verify Interactive',
#   'mobile-first assessment',
#   'ability assessment',
#   'supervisory roles',
#   'salaried employees',
#   'behavioral assessment',
#   'job-focused assessment'],
#  ['Manufacturing',
#   'Production Worker',
#   'Material Handler',
#   'Driver',
#   'Forklift Operator',
#   'Crewman',
#   'Mechanic',
#   'Receiver',
#   'Entry-level',
#   'Error Checking',
#   'Situational Judgment',
#   'Safety',
#   'Efficiency',
#   'Personality Traits',
#   'Behavioral Assessment',
#   'Workplace Performance',
#   'Selection Assessment'],
#  ['Mechanical Comprehension',
#   'Situational Judgment',
#   'Personality Traits',
#   'Safety',
#   'Efficiency',
#   'Entry-Level',
#   'Industrial Machinery Mechanic',
#   'Automotive Service Technician',
#   'Small Engine Mechanic',
#   'Mobile Equipment Service Technician',
#   'Diesel Service Technician',
#   'Manufacturing',
#   'Maintenance'],
#  ['Network Engineer',
#   'Network Analyst',
#   'Communications Engineer',
#   'Telecommunications',
#   'Network Design',
#   'Network Monitoring',
#   'Network Troubleshooting',
#   'Reasoning Ability',
#   'Attention to Detail',
#   'Multitasking',
#   'Professional Level',
#   'Electronic Data Communication',
#   'Network Performance'],
#  ['Nurse Leader',
#   'Nurse Manager',
#   'Entry-Level',
#   'Leadership',
#   'Supervision',
#   'Healthcare',
#   'Work Scheduling',
#   'Task Assignment',
#   'Coaching',
#   'Employee Development',
#   'Training',
#   'Prioritization',
#   'Decision-Making',
#   'Hourly Employees',
#   'Nurse Leadership Positions'],
#  ['Nursing',
#   'Registered Nurse',
#   'Charge Nurse',
#   'Licensed Practical Nurse',
#   'Clinic Nurse',
#   'Healthcare',
#   'Patient Assessment',
#   'Medical Documentation',
#   'Care Planning',
#   'Patient Education',
#   'Professional Level',
#   'Licensing Required',
#   'Registration Required'],
#  ['Docker',
#   'Containerization',
#   'Data Management',
#   'Docker Performance',
#   'Docker Swarm',
#   'Multi-choice',
#   'Software Development',
#   'DevOps'],
#  ['Dojo',
#   'JavaScript Framework',
#   'Web Development',
#   'Frontend Development',
#   'Multi-choice',
#   'Architecture',
#   'Classes',
#   'Libraries',
#   'Styles',
#   'Animation',
#   'Dojo Queries'],
#  ['Drupal',
#   'Content Management System',
#   'CMS',
#   'Module Development',
#   'User Interface',
#   'UI',
#   'Security',
#   'Multi-choice',
#   'Web Development',
#   'Backend Development'],
#  ['DSI v1.1', 'Interpretation Report'],
#  ['Econometrics',
#   'Statistical Concepts',
#   'Exploratory Analysis',
#   'Statistical Testing',
#   'Economic Data Analysis',
#   'Multiple Choice Questions'],
#  ['economics',
#   'microeconomics',
#   'macroeconomics',
#   'international trade',
#   'conceptual knowledge',
#   'multiple-choice questions'],
#  ['electrical engineering',
#   'electronics engineering',
#   'instrumentation',
#   'control systems',
#   'fundamentals',
#   'multi-choice',
#   'knowledge assessment',
#   'engineering fundamentals'],
#  ['Electrical Engineering',
#   'Electrical Machines',
#   'Power Systems',
#   'Instrumentation',
#   'Control Systems',
#   'Electronics',
#   'Multiple Choice',
#   'Fundamentals',
#   'Engineering Fundamentals'],
#  ['Electronics Engineering',
#   'Telecommunications Engineering',
#   'Semiconductors',
#   'Semiconductor Devices',
#   'Analog Electronics',
#   'Digital Electronics',
#   'Communication Systems',
#   'Electromagnetism',
#   'Microwave Engineering',
#   'Multiple Choice Questions',
#   'Engineering Fundamentals'],
#  ['Electronics Engineering',
#   'Embedded Systems',
#   'Analog Electronics',
#   'Digital Electronics',
#   'Multi-choice',
#   'Engineering Fundamentals',
#   'Technical Knowledge'],
#  ['Electronics Engineering',
#   'Semiconductor Engineering',
#   'Semiconductors',
#   'Two Terminal Devices',
#   'Three Terminal Devices',
#   'Analog Electronics',
#   'Digital Electronics',
#   'VLSI Basics',
#   'Multi-choice Questions',
#   'Electronics Fundamentals'],
#  ['English Comprehension',
#   'Vocabulary',
#   'Grammar',
#   'Reading Comprehension',
#   'Multiple-choice',
#   'Language Skills'],
#  ['Nursing Assistant',
#   'Entry-level',
#   'Clinic',
#   'Hospital',
#   'Patient Care',
#   'Bedridden Patients',
#   'Feeding Patients',
#   'Patient Observation',
#   'Vital Signs',
#   'Certified Nursing Assistant',
#   'Nursing Aide',
#   'Patient Care Technician',
#   'Hospital Attendant'],
#  ['Personal Banker',
#   'Loan Officer',
#   'Entry-Level',
#   'Mid-Level',
#   'Financial Institution',
#   'Customer Relationship Management',
#   'Sales',
#   'Customer Needs Analysis',
#   'Recommendation Skills',
#   'Customer Acquisition',
#   'Customer Retention',
#   'Referral Generation',
#   'Banking'],
#  ['phone banker',
#   'entry-level',
#   'mid-level',
#   'financial institution',
#   'multiple choice questions',
#   'learning potential',
#   'dependability',
#   'persistence',
#   'planfulness',
#   'sales focus',
#   'customer focus',
#   'working with information'],
#  ['Prep Cook',
#   'Line Cook',
#   'Food Preparation',
#   'Hospitality Industry',
#   'Entry-Level',
#   'Work Ethic',
#   'Quality Work',
#   'Cook',
#   'Food Preparer',
#   'Chef'],
#  ['individual contributor',
#   'deductive reasoning',
#   'mobile-first assessment',
#   'SHL Verify Interactive',
#   'requirements gathering',
#   'data analysis',
#   'project management',
#   'product development',
#   'service delivery',
#   'non-managerial',
#   'English (USA)'],
#  ['individual contributor',
#   'non-managerial',
#   'deductive reasoning',
#   'SHL Verify Interactive',
#   'mobile-first assessment',
#   'requirements gathering',
#   'data analysis',
#   'project management',
#   'product development',
#   'service delivery',
#   'professional level'],
#  ['individual contributor',
#   'non-managerial',
#   'deductive reasoning',
#   'requirements gathering',
#   'data analysis',
#   'project management',
#   'SHL Verify Interactive',
#   'mobile-first assessment',
#   'professional level'],
#  ['individual contributor',
#   'requirements gathering',
#   'data analysis',
#   'project management',
#   'product development',
#   'service delivery',
#   'non-managerial',
#   'English (USA)',
#   'Latin American Spanish'],
#  ['individual contributor',
#   'non-managerial',
#   'requirements gathering',
#   'data analysis',
#   'project management',
#   'product development',
#   'service delivery',
#   'professional level'],
#  ['individual contributor',
#   'non-managerial',
#   'professional level',
#   'behavioral assessment',
#   'job-focused assessment',
#   'performance'],
#  ['individual contributor',
#   'mid-level',
#   'upper-level',
#   'non-managerial',
#   'client interaction',
#   'data analysis',
#   'collaboration',
#   'project completion',
#   'engineer',
#   'human resource consultant',
#   'IT analyst',
#   'short form'],
#  ['Project Manager',
#   'Project Management',
#   'Implementation Manager',
#   'Construction Project Manager',
#   'IT Project Manager',
#   'Team Leadership',
#   'Project Scoping',
#   'Resource Management',
#   'Timeline Management',
#   'Budget Management',
#   'Medium to Large Scale Projects',
# ...
#  ['SAP Materials Management',
#   'SAP MM',
#   'Materials Management',
#   'Purchasing',
#   'Pricing',
#   'Release Procedure',
#   'Contracts',
#   'Inventory Management',
#   'Invoice Verification',
#   'Split Valuation',
#   'Account Determination',
#   'SAP Integration',
#   'ERP',
#   'Multiple Choice',
#   'SAP ERP'],
#  ['SAP SD',
#   'Sales and Distribution',
#   'ERP',
#   'SAP architecture',
#   'Sales',
#   'Distribution',
#   'Master Data',
#   'Billing Process',
#   'Order Processing',
#   'Delivery Processing',
#   'Multiple Choice',
#   'Functional Consultant',
#   'SAP Consultant'],
#  ['Search Engine Optimization',
#   'SEO',
#   'SEO Planning',
#   'SEO Strategies',
#   'SEO Tools',
#   'Link Building',
#   'Digital Marketing',
#   'Marketing',
#   'Multi-choice',
#   'Knowledge Assessment'],
#  ['Selenium IDE',
#   'Selenium RC',
#   'Selenium Grid',
#   'WebDriver',
#   'Test Design',
#   'User Extensions',
#   'Testing Frameworks',
#   'Object Repository',
#   'Automation Testing',
#   'QA Engineer',
#   'Software Testing',
#   'Multi-choice'],
#  ['Shell Scripting',
#   'Linux',
#   'Bash',
#   'File Manipulation',
#   'Program Execution',
#   'Text Processing',
#   'Command Line Interface',
#   'System Administration',
#   'Multi-choice',
#   'Scripting',
#   'New'],
#  ['Inductive Reasoning',
#   'Pattern Recognition',
#   'Data Analysis',
#   'Abstract Reasoning',
#   'Logical Reasoning',
#   'Cognitive Ability',
#   'Problem Solving',
#   'Critical Thinking'],
#  ['Deductive Reasoning',
#   'Logical Reasoning',
#   'Critical Thinking',
#   'Problem Solving',
#   'Cognitive Ability',
#   'SHL Verify Interactive',
#   'Abstract Reasoning',
#   'Argument Analysis',
#   'Incomplete Information',
#   'Scenario-Based',
#   'Reasoning Skills'],
#  ['numerical reasoning',
#   'data interpretation',
#   'numerical comprehension',
#   'SHL Verify Interactive',
#   'cognitive ability',
#   'aptitude',
#   'numerical data analysis',
#   'quantitative reasoning'],
#  ['cognitive ability',
#   'deductive reasoning',
#   'inductive reasoning',
#   'numerical reasoning',
#   'general cognitive ability',
#   'aptitude',
#   'all job levels',
#   '36 minutes',
#   'timed assessment'],
#  ['Numerical Calculation',
#   'Numerical Reasoning',
#   'Mathematics',
#   'Error Identification',
#   'Adaptive Assessment',
#   'Entry-Level',
#   'Accuracy',
#   'Speed',
#   'SHL Verify',
#   'Interactive Assessment'],
#  ['Siebel',
#   'Siebel Development',
#   'Siebel Architecture',
#   'Siebel Server Administration',
#   'Siebel Access Control',
#   'Siebel Client',
#   'Siebel Web Applications',
#   'Siebel Data Mapping',
#   'Siebel Workflow',
#   'Siebel Deployment',
#   'Multi-choice',
#   'CRM'],
#  ['video interview',
#   'remote interview',
#   'recruiting',
#   'hiring',
#   'candidate assessment',
#   'real-time assessment',
#   'interview platform',
#   'digital interview',
#   'question bank',
#   'file sharing',
#   'whiteboard',
#   'language support',
#   'US English',
#   'Japanese',
#   'Simplified Chinese',
#   'Castilian Spanish',
#   'Portuguese',
#   'Brazilian Portuguese',
#   'French',
#   'Canadian French',
#   'Italian',
#   'Dutch',
#   'Latin American Spanish',
#   'Romanian',
#   'Indonesian',
#   'German',
#   'Arabic',
#   'Greek',
#   'remote hiring',
#   'line manager',
#   'recruiter'],
#  ['live coding interview',
#   'real-time coding assessment',
#   'compiler interface',
#   'technical skills assessment',
#   'coding talent',
#   'software engineering',
#   'one-to-one interview',
#   'panel interview',
#   'group interview',
#   'english (US)',
#   'simplified chinese',
#   'castilian spanish',
#   'japanese',
#   'online coding interview'],
#  ['video interview',
#   'asynchronous interview',
#   'recorded interview',
#   'candidate screening',
#   'talent acquisition',
#   'bias reduction',
#   'shortlisting',
#   'cultural fit',
#   'communication skills',
#   'multiple languages',
#   'English',
#   'Chinese',
#   'Arabic',
#   'Portuguese',
#   'French',
#   'German',
#   'Spanish',
#   'compliance',
#   'New York City Law 144',
#   'automated employment decision tools'],
#  ['Social Media',
#   'Social Media Platforms',
#   'Digital Marketing',
#   'Marketing',
#   'Multi-Choice Questions',
#   'Knowledge Assessment'],
#  ['business analysis',
#   'requirements gathering',
#   'system design',
#   'business process',
#   'diagramming',
#   'modeling',
#   'documentation',
#   'joint application development',
#   'methodologies',
#   'project development',
#   'user interface',
#   'IT project',
#   'technical assets',
#   'strategic execution',
#   'senior-level',
#   'business requirements',
#   'software'],
#  ['SonarQube',
#   'Code Quality',
#   'Static Analysis',
#   'Multi-choice',
#   'Software Development',
#   'Quality Cover',
#   'Sonar Architecture',
#   'Integration Tests',
#   'Sonar Symbols',
#   'Wildcards'],
#  ['spelling',
#   'U.S. English',
#   'grammar',
#   'writing skills',
#   'language proficiency',
#   'multiple-choice',
#   'error identification',
#   'written communication'],
#  ['typing speed',
#   'typing accuracy',
#   'split screen',
#   'keystrokes',
#   'errors',
#   'Net Words Per Minute (WPM)',
#   'data entry',
#   'clerical skills',
#   'administrative assistant',
#   'time limit',
#   'performance assessment'],
#  ['Spring Core',
#   'AOP',
#   'IOC Container',
#   'Transactions',
#   'Multi-choice',
#   'Java',
#   'Backend Developer',
#   'Mid-Level Developer',
#   'Senior Developer'],
#  ['SQL',
#   'SQL Queries',
#   'Data Manipulation',
#   'Transaction Processing',
#   'Multi-choice',
#   'Beginner',
#   'Intermediate'],
#  ['SQL Server',
#   'SQL',
#   'Relational Databases',
#   'Database Queries',
#   'Data Filtering',
#   'Data Aggregation',
#   'Table Creation',
#   'Table Alteration',
#   'Multi-Choice',
#   'Basic SQL'],
#  ['SQL Server Analysis Services (SSAS)',
#   'SSAS Database',
#   'Multidimensional Analysis',
#   'Cube Hierarchies',
#   'Measures',
#   'Dimensions',
#   'Power BI',
#   'DAX',
#   'MDX',
#   'Tabular Model',
#   'Data Access',
#   'Security',
#   'Multi-Choice Questions'],
#  ['SQL Server Integration Services (SSIS)',
#   'SSIS Architecture',
#   'SSIS Components',
#   'Control Flow',
#   'Data Flow',
#   'Transformation',
#   'SQL Server Tasks',
#   'SSIS Administration',
#   'Debugging',
#   'Logging',
#   'Security Deployment',
#   'Performance Tuning',
#   'Package Scheduling',
#   'Execution',
#   'Package Configuration',
#   'Multiple Choice Questions',
#   'Data Integration',
#   'ETL'],
#  ['SQL Server Reporting Services',
#   'SSRS',
#   'Reporting',
#   'Report Design',
#   'Report Development',
#   'Data Visualization',
#   'Data Analysis',
#   'Report Architecture',
#   'Report Formatting',
#   'Calculations',
#   'Matrix Reports',
#   'Charts',
#   'Grouping',
#   'Sorting',
#   'Report Parameters',
#   'Report Management',
#   'Report Security',
#   'Multi-choice'],
#  ['SAS',
#   'Statistical Analysis',
#   'Statistics',
#   'Multi-choice',
#   'Software Proficiency'],
#  ['Struts',
#   'Struts Framework',
#   'Configuration',
#   'Validations',
#   'Actions',
#   'Interceptors',
#   'Multi-choice',
#   'Backend Development',
#   'Java',
#   'Web Application Framework'],
#  ['Spoken English',
#   'Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'English Understanding',
#   'Automated Assessment',
#   'Communication Skills',
#   'Australia English'],
#  ['Spoken English',
#   'Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'Spoken English Understanding',
#   'Communication Skills',
#   'Indian Accent',
#   'Automated Assessment',
#   'Law 144 Compliance',
#   'Employment Assessment'],
#  ['Spoken English',
#   'Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'U.K. English',
#   'Automated Assessment',
#   'Communication Skills'],
#  ['Spoken English',
#   'Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'Spoken English Understanding',
#   'Automated Assessment',
#   'Communication Skills',
#   'US English',
#   'Compliance',
#   'Law 144',
#   'Employment Assessment'],
#  ['Spoken French',
#   'Canadian French',
#   'French Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'French Vocabulary',
#   'French Grammar',
#   'Listening Comprehension',
#   'Automated Assessment',
#   'Language Proficiency',
#   'French (Canadian)',
#   'SVAR',
#   'New York City Law 144'],
#  ['Spoken French',
#   'European French',
#   'French Language Proficiency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'Listening Comprehension',
#   'Automated Assessment',
#   'Language Assessment',
#   'Fluency',
#   'Communication Skills',
#   'French (Spoken)'],
#  ['Spanish',
#   'Spoken Spanish',
#   'Castilian Spanish',
#   'Oral Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'Oral Comprehension',
#   'Language Proficiency',
#   'Automated Assessment',
#   'Spanish Language Assessment'],
#  ['Spanish',
#   'Spoken Spanish',
#   'North American Spanish',
#   'Oral Proficiency',
#   'Fluency',
#   'Pronunciation',
#   'Active Listening',
#   'Vocabulary',
#   'Grammar',
#   'Oral Comprehension',
#   'Automated Assessment',
#   'Language Assessment'],
#  ['Swing',
#   'GUI',
#   'Java',
#   'Components',
#   'Containers',
#   'Layouts',
#   'Event Handling',
#   'Multi-choice',
#   'Software Development'],
#  ['Tableau',
#   'data visualization',
#   'data analysis',
#   'reporting',
#   'tables',
#   'visualizations',
#   'calculations',
#   'filters',
#   'forecasting',
#   'multi-choice',
#   'data skills'],
#  ['Telecommunications Engineering',
#   'Analog Communication',
#   'Digital Communication',
#   'Electromagnetism',
#   'Microwave Engineering',
#   'Multiple Choice Questions'],
#  ['Teradata',
#   'RDBMS',
#   'SQL',
#   'Database Development',
#   'Data Warehousing',
#   'Performance Tuning',
#   'Workload Management',
#   'SQL Optimization',
#   'Physical Database Design',
#   'Table Partitioning',
#   'Query Analysis',
#   'Indexes',
#   'Multi-choice',
#   'Data Engineer'],
#  ['time management',
#   'workplace skills',
#   'adaptive test',
#   'action plans',
#   'controlling',
#   'decision making',
#   'organizing',
#   'planning',
#   'scheduling',
#   'time usage',
#   'time wasters',
#   'business worker',
#   'U.S. specific'],
#  ['training development',
#   'instructional design',
#   'training delivery',
#   'analysis methods',
#   'audience analysis',
#   'design materials',
#   'design strategy',
#   'developing instructional materials',
#   'media',
#   'project management plan',
#   'writing instructional objectives',
#   'experienced trainers',
#   'general knowledge'],
#  ['typing speed', 'typing accuracy', 'typing test'],
#  ['UiPath',
#   'RPA Development',
#   'Robotic Process Automation',
#   'UiPath Architecture',
#   'Workflows Recording',
#   'UI Interaction',
#   'Automation',
#   'Orchestrator',
#   'Multi-choice',
#   'Technical Skills'],
#  ['interview guide',
#   'competency-based interview',
#   'behavioral assessment',
#   'structured interview',
#   'candidate assessment',
#   'competency framework',
#   'UCF dimensions',
#   'talent acquisition',
#   'human resources'],
#  ['competency framework',
#   'job profiling',
#   'behavioral assessment',
#   'workplace behavior',
#   'performance prediction',
#   'talent management',
#   'SHL'],
#  ['competency framework',
#   'behavioral assessment',
#   'performance management',
#   'universal application',
#   'job analysis',
#   'behavioral profiling'],
#  ['UNIX',
#   'UNIX commands',
#   'file system',
#   'file handling',
#   'regular expressions',
#   'awk programming',
#   'shell programming',
#   'multi-choice',
#   'knowledge assessment'],
#  ['VB.NET',
#   'assemblies',
#   'OOP',
#   'ADO.NET',
#   'multithreading',
#   'exception handling',
#   'GUI',
#   'multiple-choice questions',
#   'software developer'],
#  ['deductive reasoning',
#   'logical reasoning',
#   'critical thinking',
#   'problem-solving',
#   'analytical skills',
#   'ability assessment',
#   'pre-hire assessment',
#   'post-hire assessment',
#   'all levels',
#   'evaluate arguments',
#   'analyze scenarios',
#   'draw logical conclusions',
#   'decision-making',
#   '18 minutes',
#   '20 items',
#   'SHL Verify'],
#  ['Following Instructions',
#   'Attention to Detail',
#   'Rule-Based Reasoning',
#   'Decision Making',
#   'Situational Judgment',
#   'Cognitive Ability',
#   'Aptitude',
#   'Compliance',
#   'Accuracy'],
#  ['process monitoring',
#   'cognitive ability',
#   'vigilance',
#   'attention to detail',
#   'instrument feedback',
#   'production process',
#   'safe control limits',
#   'SHL Verify Range',
#   'entry-level jobs',
#   'manufacturing',
#   'operations',
#   'quality control',
#   'aptitude',
#   'mechanical aptitude'],
#  ['virtual assessment center',
#   'development center',
#   'new hires',
#   'existing employees',
#   'employee potential',
#   'candidate experience',
#   'assessor experience',
#   'administrator experience',
#   'inbox simulation',
#   'written analysis',
#   'coaching',
#   'role-play',
#   'group exercises',
#   'job levels',
#   'industry scenarios',
#   'SHL',
#   'Smart Interview Live',
#   'English US',
#   'Japanese',
#   'Simplified Chinese',
#   'Spanish',
#   'Portuguese',
#   'Brazilian Portuguese',
#   'French',
#   'Canadian French',
#   'Italian',
#   'Dutch',
#   'Latin American Spanish',
#   'Romanian',
#   'Indonesian',
#   'German',
#   'Greek'],
#  ['VBA',
#   'Visual Basic for Applications',
#   'Programming Constructs',
#   'Forms',
#   'Controls',
#   'VBA Security',
#   'Multi-choice',
#   'Entry-level'],
#  ['Visual Comparison',
#   'Error Detection',
#   'Attention to Detail',
#   'Data Accuracy',
#   'Numerical Reasoning',
#   'Cognitive Ability'],
#  ['visual comparison',
#   'error detection',
#   'information comparison',
#   'attention to detail',
#   'accuracy',
#   'numerical reasoning',
#   'pattern recognition'],
#  ['VLSI',
#   'Embedded Systems',
#   'Electronics Engineering',
#   'Computer Engineering',
#   'Multiple Choice Questions',
#   'Fundamentals',
#   'Semiconductor Devices',
#   'Digital Logic',
#   'Microcontrollers'],
#  ['money handling',
#   'numerical reasoning',
#   'cash handling',
#   'entry-level',
#   'retail',
#   'customer service',
#   'arithmetic',
#   'basic math',
#   'US currency'],
#  ['workplace administration',
#   'administrative skills',
#   'data maintenance',
#   'computer skills',
#   'problem-solving',
#   'organizational skills',
#   'task management',
#   'multi-choice',
#   'clerical',
#   'entry-level'],
#  ['Workplace Health and Safety',
#   'First Aid',
#   'Emergency Safety Measures',
#   'Cleanliness',
#   'Personal Hygiene',
#   'Multiple Choice',
#   'Knowledge Assessment'],
#  ['email writing',
#   'customer service',
#   'written communication',
#   'english language',
#   'content quality',
#   'grammar',
#   'email etiquette',
#   'open response',
#   'writing skills',
#   'communication skills',
#   'customer support',
#   'compliance',
#   'law 144',
#   'new york city law 144'],
#  ['email writing',
#   'business communication',
#   'written communication',
#   'grammar',
#   'content quality',
#   'email etiquette',
#   'managerial level',
#   'open response',
#   'English',
#   'New York City Law 144 compliance'],
#  ['email writing',
#   'business communication',
#   'sales',
#   'written communication',
#   'grammar',
#   'email etiquette',
#   'open response',
#   'english language proficiency',
#   'content quality',
#   'professional communication',
#   'new york city law 144',
#   'automated employment decision tools'],
#  ['Written English',
#   'English Grammar',
#   'Reading Comprehension',
#   'ESL',
#   'English as a Second Language',
#   'US English',
#   'Articles',
#   'Comparisons',
#   'Conjunctions',
#   'Nouns',
#   'Pronouns',
#   'Prepositions',
#   'Verbs',
#   'Parallel Structure',
#   'Misused Words'],
#  ['Spanish Language',
#   'Grammar',
#   'Reading Comprehension',
#   'Second Language Proficiency',
#   'Adjectives',
#   'Adverbs',
#   'Conjunctions',
#   'Nouns',
#   'Prepositions',
#   'Pronouns',
#   'Verbs'],
#  ['Zabbix',
#   'Monitoring',
#   'System Administration',
#   'Infrastructure Monitoring',
#   'Multi-choice',
#   'Architecture',
#   'Data Handling'],
#  ['360 feedback',
#   'digital report',
#   'performance evaluation',
#   'employee development',
#   'usability',
#   'actionable insights',
#   'interactive interface',
#   'feedback data',
#   'PDF report',
#   'SHL product'],
#  ['360-degree feedback',
#   'multi-rater feedback',
#   'performance management',
#   'employee development',
#   'competency assessment',
#   'SHL Universal Competency Framework (UCF)',
#   'manager feedback',
#   'peer feedback',
#   'direct report feedback',
#   'self-assessment',
#   'leadership assessment',
#   'communication skills',
#   'interpersonal skills',
#   'impact on others',
#   'strengths and weaknesses',
#   'development opportunities',
#   'all levels',
#   'all industries',
#   'holistic view',
#   'research-driven competencies',
#   'developmental feedback']]

# %%
df["Tags"] = tag_column
df.to_csv("shl_enhanced_assessments_with_tags.csv", index=False)
print("\n✅ Enrichment complete. Tags saved to 'shl_enhanced_assessments_with_tags.csv'")
# Out:
# ✅ Enrichment complete. Tags saved to 'shl_enhanced_assessments_with_tags.csv'

# %%
import pandas as pd
from langchain_core.documents import Document
from uuid import uuid4
import ast  # in case tags are stored as strings like "['python', 'sql']"

# Load enriched CSV
df = pd.read_csv('/Users/harshshivhare/SHL-AI/shl_enhanced_assessments_with_tags.csv')

documents = []
ids = []

for _, row in df.iterrows():
    # Safely parse the Tags column
    try:
        tags = ast.literal_eval(row["Tags"]) if isinstance(row["Tags"], str) else row["Tags"]
        if not isinstance(tags, list):
            tags = []
    except Exception:
        tags = []

    # Create document with all metadata including tags
    doc = Document(
        page_content=f"{row['Test Name']}. {row['Description']}",
        metadata={
            "Test Name": str(row['Test Name']),
            "Test Link": str(row['Test Link']),
            "Description": str(row['Description']), 
            "Assessment Length": str(row['Assessment Length']),
            "Job Levels": str(row['Job Levels']),
            "Remote Testing": str(row['Remote Testing']),
            "Adaptive/IRT": str(row['Adaptive/IRT']),
            "Test Type": str(row['Test Type']),
            "Tags": tags  # ✅ Include tags for retrieval & reranking
        }
    )
    documents.append(doc)
    ids.append(str(uuid4()))

# %%
documents
# Out:
# [Document(metadata={'Test Name': 'Account Manager Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/account-manager-solution/', 'Description': 'The Account Manager solution is an assessment used for job candidates applying to mid-level leadership positions that tend to manage the day-to-day operations and activities of client accounts. Sample tasks for these jobs include, but are not limited to: communicating with clients about project status, developing and maintaining project plans, coordinating internally with appropriate project personnel, and ensuring client expectations are being met. Potential job titles that use this solution are: Account Executive, Account Manager, and Senior Account Manager. There are multiple configurations of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 49', 'Job Levels': 'Mid-Professional,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'CPAB', 'Tags': ['Account Management', 'Client Communication', 'Project Management', 'Coordination', 'Client Expectations', 'Leadership', 'Mid-Level', 'Account Executive', 'Account Manager', 'Senior Account Manager']}, page_content='Account Manager Solution. The Account Manager solution is an assessment used for job candidates applying to mid-level leadership positions that tend to manage the day-to-day operations and activities of client accounts. Sample tasks for these jobs include, but are not limited to: communicating with clients about project status, developing and maintaining project plans, coordinating internally with appropriate project personnel, and ensuring client expectations are being met. Potential job titles that use this solution are: Account Executive, Account Manager, and Senior Account Manager. There are multiple configurations of this solution available.'),
#  Document(metadata={'Test Name': 'Administrative Professional - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/administrative-professional-short-form/', 'Description': 'The Administrative Professional solution is for entry to mid-level positions that involve routine clerical and administrative functions in addition to office management functions and customer service. Sample tasks for this job include, but are not limited to: arranging conference calls; drafting correspondence; scheduling meetings; greeting visitors; coordinating office activities. Potential job titles that use this solution are: Administrative Assistant, Secretary, Office Manager, Administrative Aide, and Administrative Associate.', 'Assessment Length': 'Approximate Completion Time in minutes = 36', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'AKP', 'Tags': ['Administrative Assistant', 'Secretary', 'Office Manager', 'Administrative Aide', 'Administrative Associate', 'Entry-Level', 'Mid-Level', 'Clerical Skills', 'Administrative Skills', 'Office Management', 'Customer Service', 'Communication Skills', 'Scheduling', 'Meeting Arrangement', 'Correspondence', 'Office Coordination', 'Greeting Visitors']}, page_content='Administrative Professional - Short Form. The Administrative Professional solution is for entry to mid-level positions that involve routine clerical and administrative functions in addition to office management functions and customer service. Sample tasks for this job include, but are not limited to: arranging conference calls; drafting correspondence; scheduling meetings; greeting visitors; coordinating office activities. Potential job titles that use this solution are: Administrative Assistant, Secretary, Office Manager, Administrative Aide, and Administrative Associate.'),
#  Document(metadata={'Test Name': 'Agency Manager Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/agency-manager-solution/', 'Description': 'The Agency Manager solution is for mid-level sales management positions that include front line management and sales responsibilities. Sample tasks for this job include, but are not limited to: directing and coordinating financial activities of workers in a branch, office, or department of an establishment, such as branch bank, brokerage firm, risk and insurance department, or credit department.  Potential job titles that use this solution are: Agency Manager, Brokerage Manager. Multiple configurations of this solution are available.', 'Assessment Length': 'Approximate Completion Time in minutes = 51', 'Job Levels': 'Front Line Manager, Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABPS', 'Tags': ['sales management', 'mid-level', 'front line management', 'financial activities', 'branch management', 'brokerage management', 'risk management', 'insurance management', 'credit department', 'agency manager', 'brokerage manager']}, page_content='Agency Manager Solution. The Agency Manager solution is for mid-level sales management positions that include front line management and sales responsibilities. Sample tasks for this job include, but are not limited to: directing and coordinating financial activities of workers in a branch, office, or department of an establishment, such as branch bank, brokerage firm, risk and insurance department, or credit department.  Potential job titles that use this solution are: Agency Manager, Brokerage Manager. Multiple configurations of this solution are available.'),
#  Document(metadata={'Test Name': 'Apprentice + 8.0 Job Focused Assessment', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/apprentice-8-0-job-focused-assessment-4261/', 'Description': 'The Apprentice + 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment which includes a short cognitive ability measure. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organisations whose business spans across regions.', 'Assessment Length': 'Approximate Completion Time in minutes = 30', 'Job Levels': 'General Population, Graduate, Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'BP', 'Tags': ['entry-level', 'apprenticeship', 'cognitive ability', 'global', 'multi-national', 'job-focused', 'short assessment']}, page_content='Apprentice + 8.0 Job Focused Assessment. The Apprentice + 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment which includes a short cognitive ability measure. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organisations whose business spans across regions.'),
#  Document(metadata={'Test Name': 'Apprentice 8.0 Job Focused Assessment', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/apprentice-8-0-job-focused-assessment/', 'Description': 'The Apprentice 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organizations whose business spans across regions.', 'Assessment Length': 'Approximate Completion Time in minutes = 20', 'Job Levels': 'Entry-Level, General Population, Graduate,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'BP', 'Tags': ['entry-level', 'apprenticeship', 'job-focused', 'global', 'multi-national', 'short', 'aptitude', 'skills assessment']}, page_content='Apprentice 8.0 Job Focused Assessment. The Apprentice 8.0 Job-Focused Assessment is a short, targeted, globally applicable assessment. This assessment is designed for entry-level positions appropriate for countries and industries that use an apprenticeship model. It is intended to be used multi-nationally for organizations whose business spans across regions.'),
#  Document(metadata={'Test Name': 'Bank Administrative Assistant - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bank-administrative-assistant-short-form/', 'Description': 'The Administrative Assistant solution is for entry-level clerical positions that interact with external or internal customers. Sample tasks for these jobs include, but are not limited to: answering telephones, managing files and records, sorting mail, greeting customers, and collaborating with co-workers on projects. Potential job titles that use this solution are: Receptionist and Administrative Assistant. There are multiple configurations of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 35', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABKP', 'Tags': ['Administrative Assistant', 'Bank', 'Entry-Level', 'Clerical', 'Customer Service', 'Receptionist', 'Communication Skills', 'Office Administration', 'File Management', 'Record Keeping', 'Telephone Skills', 'Collaboration', 'Short Form']}, page_content='Bank Administrative Assistant - Short Form. The Administrative Assistant solution is for entry-level clerical positions that interact with external or internal customers. Sample tasks for these jobs include, but are not limited to: answering telephones, managing files and records, sorting mail, greeting customers, and collaborating with co-workers on projects. Potential job titles that use this solution are: Receptionist and Administrative Assistant. There are multiple configurations of this solution available.'),
#  Document(metadata={'Test Name': 'Bank Collections Agent - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bank-collections-agent-short-form/', 'Description': 'This solution is for entry-level collections positions in an inbound or outbound call center environment in a financial setting. Candidates answer multiple choice questions to measure achievement orientation, dependability, collector numerical skills, revenue recovery, customer focus, and persistence and planfulness. There are multiple configurations and versions of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 45', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABP', 'Tags': ['Bank Collections Agent', 'Entry-Level', 'Call Center', 'Financial Services', 'Multiple Choice Questions', 'Achievement Orientation', 'Dependability', 'Collector Numerical Skills', 'Revenue Recovery', 'Customer Focus', 'Persistence', 'Planfulness', 'Inbound', 'Outbound']}, page_content='Bank Collections Agent - Short Form. This solution is for entry-level collections positions in an inbound or outbound call center environment in a financial setting. Candidates answer multiple choice questions to measure achievement orientation, dependability, collector numerical skills, revenue recovery, customer focus, and persistence and planfulness. There are multiple configurations and versions of this solution available.'),
#  Document(metadata={'Test Name': 'Bank Operations Supervisor - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bank-operations-supervisor-short-form/', 'Description': "The Bank Operations Supervisor solution is for job candidates applying to entry-level leadership positions who tend to supervise hourly employees. Sample tasks for these jobs include, but are not limited to:  planning and preparing work schedules, assigning employees to specific duties; coaching  employees on attendance, conduct, schedule adherence, and work tasks, developing employees' skills ; training subordinates; prioritizing multiple tasks  and priorities; and making  day-to-day decisions with minimal guidance from others. Potential job titles that use this solution are: Team Leader, First Line Supervisor, Processing Supervisor, Call Center Supervisor, and Customer Service Supervisor. There are multiple configurations and versions of this solution available.", 'Assessment Length': 'Approximate Completion Time in minutes = 45', 'Job Levels': 'Front Line Manager, Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'ABPS', 'Tags': ['Bank Operations', 'Supervisor', 'Entry-Level Leadership', 'Team Leader', 'First Line Supervisor', 'Processing Supervisor', 'Call Center Supervisor', 'Customer Service Supervisor', 'Supervising Hourly Employees', 'Work Schedule Planning', 'Employee Assignment', 'Coaching', 'Attendance', 'Conduct', 'Schedule Adherence', 'Employee Training', 'Prioritization', 'Decision-Making', 'Short Form']}, page_content="Bank Operations Supervisor - Short Form. The Bank Operations Supervisor solution is for job candidates applying to entry-level leadership positions who tend to supervise hourly employees. Sample tasks for these jobs include, but are not limited to:  planning and preparing work schedules, assigning employees to specific duties; coaching  employees on attendance, conduct, schedule adherence, and work tasks, developing employees' skills ; training subordinates; prioritizing multiple tasks  and priorities; and making  day-to-day decisions with minimal guidance from others. Potential job titles that use this solution are: Team Leader, First Line Supervisor, Processing Supervisor, Call Center Supervisor, and Customer Service Supervisor. There are multiple configurations and versions of this solution available."),
#  Document(metadata={'Test Name': 'Bilingual Spanish Reservation Agent Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bilingual-spanish-reservation-agent-solution/', 'Description': 'The Bilingual Reservation Agent solution is designed for customer centered entry-level positions within the hospitality industry. Sample tasks may include making, updating, or canceling hotel reservations made in English or Spanish; listening to customers speak Spanish and entering information into a computer in English; providing information on the hotel and the services offered. Potential job titles that use this solution are: Bilingual Reservation Agent, Customer Service Representative and Reservationist. Multiple configurations of this solution are available.', 'Assessment Length': 'Approximate Completion Time in minutes = 43', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'BPSA', 'Tags': ['Bilingual Spanish', 'Reservation Agent', 'Customer Service', 'Hospitality Industry', 'Entry-Level', 'Customer Interaction', 'Spanish Language Proficiency', 'English Language Proficiency', 'Reservation Management', 'Communication Skills', 'Customer Service Representative', 'Reservationist', 'Call Center', 'Data Entry', 'Hotel Services', 'Information Provision']}, page_content='Bilingual Spanish Reservation Agent Solution. The Bilingual Reservation Agent solution is designed for customer centered entry-level positions within the hospitality industry. Sample tasks may include making, updating, or canceling hotel reservations made in English or Spanish; listening to customers speak Spanish and entering information into a computer in English; providing information on the hotel and the services offered. Potential job titles that use this solution are: Bilingual Reservation Agent, Customer Service Representative and Reservationist. Multiple configurations of this solution are available.'),
#  Document(metadata={'Test Name': 'Bookkeeping, Accounting, Auditing Clerk Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/bookkeeping-accounting-auditing-clerk-short-form/', 'Description': 'The Bookkeeping, Accounting, and Auditing Clerk solution is for entry-level positions that involve entering numerical data into computer systems and maintaining financial records. Sample tasks for this job include, but are not limited to: entering financial data into computers; checking financial records for accuracy; perform routine computations on financial data. Potential job titles that use this solution are: Accounting Clerk, Bookkeeper, Accounting Associate, Auditing Clerk and Accounts Receivable Clerk.', 'Assessment Length': 'Approximate Completion Time in minutes = 49', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'PSKBA', 'Tags': ['Bookkeeping', 'Accounting', 'Auditing', 'Clerk', 'Entry-Level', 'Data Entry', 'Financial Records', 'Numerical Data', 'Accounting Clerk', 'Bookkeeper', 'Accounting Associate', 'Auditing Clerk', 'Accounts Receivable Clerk', 'Financial Data Accuracy', 'Routine Computations']}, page_content='Bookkeeping, Accounting, Auditing Clerk Short Form. The Bookkeeping, Accounting, and Auditing Clerk solution is for entry-level positions that involve entering numerical data into computer systems and maintaining financial records. Sample tasks for this job include, but are not limited to: entering financial data into computers; checking financial records for accuracy; perform routine computations on financial data. Potential job titles that use this solution are: Accounting Clerk, Bookkeeper, Accounting Associate, Auditing Clerk and Accounts Receivable Clerk.'),
#  Document(metadata={'Test Name': 'Branch Manager - Short Form', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/branch-manager-short-form/', 'Description': 'This solution is for mid to upper-level financial institution managerial positions. Candidates answer a series of multiple choice questions to measure management potential, management judgment, leadership potential, team management, branch manager problem solving, business leadership, leadership motivation, interpersonal leadership, self leadership, and branch manager judgment. There are multiple configurations and versions of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 50', 'Job Levels': 'Front Line Manager, Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABP', 'Tags': ['branch manager', 'financial institution', 'management potential', 'management judgment', 'leadership potential', 'team management', 'branch manager problem solving', 'business leadership', 'leadership motivation', 'interpersonal leadership', 'self leadership', 'branch manager judgment', 'multiple choice', 'mid-level', 'upper-level', 'banking']}, page_content='Branch Manager - Short Form. This solution is for mid to upper-level financial institution managerial positions. Candidates answer a series of multiple choice questions to measure management potential, management judgment, leadership potential, team management, branch manager problem solving, business leadership, leadership motivation, interpersonal leadership, self leadership, and branch manager judgment. There are multiple configurations and versions of this solution available.'),
#  Document(metadata={'Test Name': 'Cashier Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/cashier-solution/', 'Description': 'The Cashier solution is for entry-level retail positions in which employees receive payment in the form of cash, check, or credit cards for goods purchased. Sample tasks for these jobs include, but are not limited to: handling payments, offering customer service, and issuing receipts and refunds. Potential job titles that use this solution are: Cashier, Sales Associate, and Clerk. There are multiple configurations and versions of this solution available.', 'Assessment Length': 'Approximate Completion Time in minutes = 28', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'BAP', 'Tags': ['cashier', 'sales associate', 'clerk', 'retail', 'entry-level', 'customer service', 'payment processing', 'cash handling', 'credit card processing', 'check processing', 'receipts', 'refunds']}, page_content='Cashier Solution. The Cashier solution is for entry-level retail positions in which employees receive payment in the form of cash, check, or credit cards for goods purchased. Sample tasks for these jobs include, but are not limited to: handling payments, offering customer service, and issuing receipts and refunds. Potential job titles that use this solution are: Cashier, Sales Associate, and Clerk. There are multiple configurations and versions of this solution available.'),
#  Document(metadata={'Test Name': 'Global Skills Development Report', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/global-skills-development-report/', 'Description': 'This report is designed to be given to individuals who have completed the Global Skills Assessment (GSA). With coverage across the Great 8 Domains, this measure of self-reported behaviors offers a complete overview of their current skills. Participants receive actionable tips on leveraging their top skill strengths and how they might develop their growth skills.', 'Assessment Length': 'nan', 'Job Levels': 'Director, Entry-Level, Executive, General Population, Graduate, Manager, Mid-Professional, Front Line Manager, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'AEBCDP', 'Tags': ['self-assessment', 'skills development', 'Great 8 Domains', 'self-reported behaviors', 'actionable tips', 'skill strengths', 'growth skills', 'report', 'individual feedback', 'self-awareness']}, page_content='Global Skills Development Report. This report is designed to be given to individuals who have completed the Global Skills Assessment (GSA). With coverage across the Great 8 Domains, this measure of self-reported behaviors offers a complete overview of their current skills. Participants receive actionable tips on leveraging their top skill strengths and how they might develop their growth skills.'),
#  Document(metadata={'Test Name': '.NET Framework 4.5', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-framework-4-5/', 'Description': 'The.NET Framework 4.5 test measures knowledge of .NET environment. Designed for experienced users, this test covers the following topics: Application Development, Application Foundation, Data Modeling, Deployment, Diagnostics, Performance, Portability, and Security.', 'Assessment Length': 'Approximate Completion Time in minutes = 30', 'Job Levels': 'Professional Individual Contributor, Mid-Professional,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K', 'Tags': ['.NET Framework 4.5', '.NET', 'Application Development', 'Application Foundation', 'Data Modeling', 'Deployment', 'Diagnostics', 'Performance', 'Portability', 'Security', 'Experienced Users']}, page_content='.NET Framework 4.5. The.NET Framework 4.5 test measures knowledge of .NET environment. Designed for experienced users, this test covers the following topics: Application Development, Application Foundation, Data Modeling, Deployment, Diagnostics, Performance, Portability, and Security.'),
#  Document(metadata={'Test Name': '.NET MVC (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-mvc-new/', 'Description': 'Multi-choice test that measures the knowledge of Model-View-Controller (MVC) architecture, validation, security, routing, and areas.', 'Assessment Length': 'Approximate Completion Time in minutes = 17', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['.NET', 'MVC', 'Model-View-Controller', 'Architecture', 'Validation', 'Security', 'Routing', 'Areas', 'C#', 'Multi-choice question', 'Software Development']}, page_content='.NET MVC (New). Multi-choice test that measures the knowledge of Model-View-Controller (MVC) architecture, validation, security, routing, and areas.'),
#  Document(metadata={'Test Name': '.NET MVVM (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-mvvm-new/', 'Description': 'Multi-choice test that measures the knowledge of MVVM pattern, scenarios, data validation, ViewModel communication and Quick-start.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['.NET', 'MVVM', 'Model-View-ViewModel', 'Data Validation', 'ViewModel Communication', 'C#', 'Software Architecture', 'Design Patterns', 'Multi-Choice Questions']}, page_content='.NET MVVM (New). Multi-choice test that measures the knowledge of MVVM pattern, scenarios, data validation, ViewModel communication and Quick-start.'),
#  Document(metadata={'Test Name': '.NET WCF (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-wcf-new/', 'Description': 'Multi-choice test that measures the knowledge of .NET fundamentals, WCF architecture, programming model, SOA, managing and programming WCF.', 'Assessment Length': 'Approximate Completion Time in minutes = 11', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['.NET', 'WCF', 'Windows Communication Foundation', 'SOA', 'Service-Oriented Architecture', 'Multi-choice', 'Fundamentals', 'Architecture', 'Programming Model', 'WCF Programming', 'WCF Management']}, page_content='.NET WCF (New). Multi-choice test that measures the knowledge of .NET fundamentals, WCF architecture, programming model, SOA, managing and programming WCF.'),
#  Document(metadata={'Test Name': '.NET WPF (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-wpf-new/', 'Description': 'Multi-choice test that measures the knowledge of .NET basics, WPF, XAML controls, events, layouts, working with WPF windows/menus and deploying WPF applications.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['.NET', 'WPF', 'XAML', 'C#', 'Desktop application development', 'Windows Forms', 'UI development', 'Multi-choice', 'Fundamentals', 'Deployment']}, page_content='.NET WPF (New). Multi-choice test that measures the knowledge of .NET basics, WPF, XAML controls, events, layouts, working with WPF windows/menus and deploying WPF applications.'),
#  Document(metadata={'Test Name': '.NET XAML (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/net-xaml-new/', 'Description': 'Multi-choice test that measures the knowledge of XAML triggers, data binding, custom controls and layouts.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['.NET', 'XAML', 'Multi-choice', 'Triggers', 'Data Binding', 'Custom Controls', 'Layouts', 'Software Development']}, page_content='.NET XAML (New). Multi-choice test that measures the knowledge of XAML triggers, data binding, custom controls and layouts.'),
#  Document(metadata={'Test Name': 'Accounts Payable (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-payable-new/', 'Description': 'Multiple-choice test that measures the knowledge of processing payables and vendor invoices, and the posting of journal entries.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['accounts payable', 'vendor invoices', 'journal entries', 'multiple-choice', 'accounting', 'finance', 'bookkeeping']}, page_content='Accounts Payable (New). Multiple-choice test that measures the knowledge of processing payables and vendor invoices, and the posting of journal entries.'),
#  Document(metadata={'Test Name': 'Accounts Payable Simulation (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-payable-simulation-new/', 'Description': 'Simulated data entry test that measures the ability to process payables and vendor invoices.', 'Assessment Length': 'Approximate Completion Time in minutes = 8', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S', 'Tags': ['Accounts Payable', 'Data Entry', 'Invoice Processing', 'Vendor Invoices', 'Simulation', 'Accounting', 'Finance', 'Accuracy', 'Efficiency']}, page_content='Accounts Payable Simulation (New). Simulated data entry test that measures the ability to process payables and vendor invoices.'),
#  Document(metadata={'Test Name': 'Accounts Receivable (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-receivable-new/', 'Description': 'Multiple-choice test that measures the knowledge of processing receivables and invoices.', 'Assessment Length': 'Approximate Completion Time in minutes = 13', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['accounts receivable', 'invoice processing', 'financial accounting', 'multiple-choice', 'accounting', 'finance']}, page_content='Accounts Receivable (New). Multiple-choice test that measures the knowledge of processing receivables and invoices.'),
#  Document(metadata={'Test Name': 'Accounts Receivable Simulation (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/accounts-receivable-simulation-new/', 'Description': 'Simulated data entry test that measures the ability to process receivables and invoices.', 'Assessment Length': 'Approximate Completion Time in minutes = 8', 'Job Levels': 'Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S', 'Tags': ['Accounts Receivable', 'Data Entry', 'Invoice Processing', 'Simulation', 'Accounting', 'Finance']}, page_content='Accounts Receivable Simulation (New). Simulated data entry test that measures the ability to process receivables and invoices.'),
#  Document(metadata={'Test Name': 'ADO.NET (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/ado-net-new/', 'Description': 'Multi-choice test that measures the knowledge on the concepts of ADO.NET architecture, components and data provider objects.', 'Assessment Length': 'Approximate Completion Time in minutes = 10', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['ADO.NET', 'Data Access', 'Microsoft Technologies', 'Multi-choice', 'Software Development', 'Database Connectivity', 'Data Provider', 'Architecture', 'Components']}, page_content='ADO.NET (New). Multi-choice test that measures the knowledge on the concepts of ADO.NET architecture, components and data provider objects.'),
#  Document(metadata={'Test Name': 'Adobe Experience Manager (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/adobe-experience-manager-new/', 'Description': 'Multi-choice test that measures the knowledge of AEM components, templates, workflows, AEM collections, OSGi services and troubleshooting of AEM projects.', 'Assessment Length': 'Approximate Completion Time in minutes = 17', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Adobe Experience Manager', 'AEM', 'AEM Components', 'AEM Templates', 'AEM Workflows', 'AEM Collections', 'OSGi Services', 'AEM Troubleshooting', 'Multi-choice', 'Software Engineer', 'Web Development', 'Content Management System']}, page_content='Adobe Experience Manager (New). Multi-choice test that measures the knowledge of AEM components, templates, workflows, AEM collections, OSGi services and troubleshooting of AEM projects.'),
#  Document(metadata={'Test Name': 'Adobe Photoshop CC', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/adobe-photoshop-cc/', 'Description': 'The Adobe Photoshop CC test measures knowledge of Adobe Photoshop CC. Designed for experienced users, this test covers the following topics: 3D, Color, File Management, Interface, Layers, Painting and Drawing, Retouch and Enhancements, Selection, Text, and Web.', 'Assessment Length': 'Approximate Completion Time in minutes = 20', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K', 'Tags': ['Adobe Photoshop CC', 'Image Editing', 'Graphic Design', '3D', 'Color Correction', 'File Management', 'User Interface', 'Layers', 'Painting', 'Drawing', 'Retouching', 'Image Enhancement', 'Selection Tools', 'Text Tools', 'Web Design', 'Experienced Users']}, page_content='Adobe Photoshop CC. The Adobe Photoshop CC test measures knowledge of Adobe Photoshop CC. Designed for experienced users, this test covers the following topics: 3D, Color, File Management, Interface, Layers, Painting and Drawing, Retouch and Enhancements, Selection, Text, and Web.'),
#  Document(metadata={'Test Name': 'Aeronautical Engineering (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/aeronautical-engineering-new/', 'Description': 'Multi-choice test that measures the knowledge of flight mechanics, space dynamics, aerodynamics, structures and propulsion.', 'Assessment Length': 'Approximate Completion Time in minutes = 10', 'Job Levels': 'Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Aeronautical Engineering', 'Flight Mechanics', 'Space Dynamics', 'Aerodynamics', 'Structures', 'Propulsion', 'Multiple Choice', 'Engineering']}, page_content='Aeronautical Engineering (New). Multi-choice test that measures the knowledge of flight mechanics, space dynamics, aerodynamics, structures and propulsion.'),
#  Document(metadata={'Test Name': 'Aerospace Engineering (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/aerospace-engineering-new/', 'Description': 'Multi-choice test that measures the conceptual knowledge of aerodynamics, aircraft systems and instrumentation, flight dynamics, space dynamics and avionics.', 'Assessment Length': 'Approximate Completion Time in minutes = 10', 'Job Levels': 'Graduate, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Aerospace Engineering', 'Aerodynamics', 'Aircraft Systems', 'Instrumentation', 'Flight Dynamics', 'Space Dynamics', 'Avionics', 'Conceptual Knowledge', 'Multiple Choice', 'Engineering']}, page_content='Aerospace Engineering (New). Multi-choice test that measures the conceptual knowledge of aerodynamics, aircraft systems and instrumentation, flight dynamics, space dynamics and avionics.'),
#  Document(metadata={'Test Name': 'Agile Software Development', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/agile-software-development/', 'Description': 'Multi-choice test that measures the knowledge of agile methodology, scrum, feature driven software development, incremental and iterative development and processes involved in agile software development.', 'Assessment Length': 'Approximate Completion Time in minutes = 7 minutes', 'Job Levels': 'Graduate,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Agile Methodology', 'Scrum', 'Feature Driven Development', 'Incremental Development', 'Iterative Development', 'Agile Processes', 'Software Development', 'Multi-choice', 'Knowledge Assessment']}, page_content='Agile Software Development. Multi-choice test that measures the knowledge of agile methodology, scrum, feature driven software development, incremental and iterative development and processes involved in agile software development.'),
#  Document(metadata={'Test Name': 'Agile Testing (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/agile-testing-new/', 'Description': 'Multi-choice test that measures the knowledge of tools, techniques and processes involved in the Agile testing methodology.', 'Assessment Length': 'Approximate Completion Time in minutes = 13', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Agile Testing', 'Agile Methodology', 'Testing Techniques', 'Testing Tools', 'Testing Processes', 'Multi-choice', 'Knowledge Assessment']}, page_content='Agile Testing (New). Multi-choice test that measures the knowledge of tools, techniques and processes involved in the Agile testing methodology.'),
#  Document(metadata={'Test Name': 'AI Skills', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/ai-skills/', 'Description': 'The AI Skills assessment measures the skills that help candidates successfully leverage AI in their work.', 'Assessment Length': 'Approximate Completion Time in minutes = 16', 'Job Levels': 'General Population,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'P', 'Tags': ['Artificial Intelligence', 'AI Skills', 'AI Literacy', 'AI Proficiency', 'AI Application', 'Technology Adoption', 'Digital Skills', 'Emerging Technologies']}, page_content='AI Skills. The AI Skills assessment measures the skills that help candidates successfully leverage AI in their work.'),
#  Document(metadata={'Test Name': 'Amazon Web Services (AWS) Development (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/amazon-web-services-aws-development-new/', 'Description': 'Multi-choice test that measures the knowledge of AWS delivery process, monitoring, metrics, logging, security, validation and scalability.', 'Assessment Length': 'Approximate Completion Time in minutes = 6', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['AWS', 'Amazon Web Services', 'Cloud Computing', 'Delivery Process', 'Monitoring', 'Metrics', 'Logging', 'Security', 'Scalability', 'Validation', 'Multi-choice', 'Technical Knowledge', 'Cloud Development']}, page_content='Amazon Web Services (AWS) Development (New). Multi-choice test that measures the knowledge of AWS delivery process, monitoring, metrics, logging, security, validation and scalability.'),
#  Document(metadata={'Test Name': 'Android Development (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/android-development-new/', 'Description': 'Multi-choice test that measures the knowledge of UI components for an Android device, services and alerts, animation and media apps, application components, security and testing.', 'Assessment Length': 'Approximate Completion Time in minutes = 7', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Android Development', 'UI Components', 'Services and Alerts', 'Animation', 'Media Apps', 'Application Components', 'Security', 'Testing', 'Mobile Development', 'Multi-Choice', 'Beginner']}, page_content='Android Development (New). Multi-choice test that measures the knowledge of UI components for an Android device, services and alerts, animation and media apps, application components, security and testing.'),
#  Document(metadata={'Test Name': 'Angular 6 (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/angular-6-new/', 'Description': 'Multi-choice test that measures the knowledge of the basic components and modules of Angular 6 and concepts like data binding, dependency injection, CRUD with HTTP, typescript, routing and navigation.', 'Assessment Length': 'Approximate Completion Time in minutes = 11', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Angular 6', 'Angular', 'front-end development', 'TypeScript', 'data binding', 'dependency injection', 'CRUD', 'HTTP', 'routing', 'navigation', 'multi-choice', 'software engineering']}, page_content='Angular 6 (New). Multi-choice test that measures the knowledge of the basic components and modules of Angular 6 and concepts like data binding, dependency injection, CRUD with HTTP, typescript, routing and navigation.'),
#  Document(metadata={'Test Name': 'AngularJS (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/angularjs-new/', 'Description': 'Multi-choice test that measures the knowledge of AngularJS architecture, forms, directives, filters, controllers, routing and testing.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['AngularJS', 'JavaScript', 'Frontend Development', 'Multi-choice Questions', 'Architecture', 'Forms', 'Directives', 'Filters', 'Controllers', 'Routing', 'Testing', 'Software Engineer', 'Junior Developer', 'Mid-level Developer']}, page_content='AngularJS (New). Multi-choice test that measures the knowledge of AngularJS architecture, forms, directives, filters, controllers, routing and testing.'),
#  Document(metadata={'Test Name': 'Apache Hadoop (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/apache-hadoop-new/', 'Description': 'Multi-choice test that measures the knowledge of basic concepts of Hadoop, commands, HDFS and MapReduce.', 'Assessment Length': 'Approximate Completion Time in minutes = 7', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Apache Hadoop', 'Hadoop', 'HDFS', 'MapReduce', 'Big Data', 'Data Engineering', 'Multi-choice', 'Basic Concepts']}, page_content='Apache Hadoop (New). Multi-choice test that measures the knowledge of basic concepts of Hadoop, commands, HDFS and MapReduce.'),
#  Document(metadata={'Test Name': 'Claims/Operations Supervisor Solution', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/claimsoperations-supervisor-solution/', 'Description': "The Claims/Operations Supervisor solution is for entry-level management positions that involve supervising hourly employees.  Sample tasks for this job include, but are not limited to: planning and preapring work schedules; assigning employees to specific dutites; coaching employees on attendance, conduct, schedule adherence, and work tasks; developing employees' skills; training subordinates; prioritizing multiple tasks and priorities; making day-to-day decisions with minimal guidance from others.  Potential job titles that use this solution are: Team Leader, Coach, First Line Supervisor, Claims Supervisor, Operations Supervisor, and Customer Service Supervisor.  Multiple configurations of this solution are available.", 'Assessment Length': 'Approximate Completion Time in minutes = 48', 'Job Levels': 'Manager,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'PSAB', 'Tags': ['entry-level management', 'supervisory skills', 'team leadership', 'employee coaching', 'workforce management', 'scheduling', 'task prioritization', 'decision-making', 'training', 'first line supervisor', 'claims supervisor', 'operations supervisor', 'customer service supervisor', 'team leader', 'coach', 'hourly employees']}, page_content="Claims/Operations Supervisor Solution. The Claims/Operations Supervisor solution is for entry-level management positions that involve supervising hourly employees.  Sample tasks for this job include, but are not limited to: planning and preapring work schedules; assigning employees to specific dutites; coaching employees on attendance, conduct, schedule adherence, and work tasks; developing employees' skills; training subordinates; prioritizing multiple tasks and priorities; making day-to-day decisions with minimal guidance from others.  Potential job titles that use this solution are: Team Leader, Coach, First Line Supervisor, Claims Supervisor, Operations Supervisor, and Customer Service Supervisor.  Multiple configurations of this solution are available."),
#  Document(metadata={'Test Name': 'Contact Center Customer Service + 8.0', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-customer-service-8-0/', 'Description': 'The Contact Center + 8.0 - Customer Service Job Focused Assessment is designed to measure the skills, competencies, and behaviors needed for success in contact center roles where the main focus is customer service. This JFA includes a mobile-optimized contact center simulation, a behavioral assessment, and a cognitive test. Together, these assessments capture the ability to provide exceptional customer service in entry-level contact center roles.', 'Assessment Length': 'Approximate Completion Time in minutes = 41', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'ABCPS', 'Tags': ['Customer Service', 'Contact Center', 'Entry-Level', 'Mobile-Optimized', 'Simulation', 'Behavioral Assessment', 'Cognitive Test', 'Customer Service Skills', 'Customer Service Competencies', 'Customer Service Behaviors']}, page_content='Contact Center Customer Service + 8.0. The Contact Center + 8.0 - Customer Service Job Focused Assessment is designed to measure the skills, competencies, and behaviors needed for success in contact center roles where the main focus is customer service. This JFA includes a mobile-optimized contact center simulation, a behavioral assessment, and a cognitive test. Together, these assessments capture the ability to provide exceptional customer service in entry-level contact center roles.'),
#  Document(metadata={'Test Name': 'Contact Center Customer Service 8.0', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/contact-center-customer-service-8-0-4269/', 'Description': 'The Customer Service 8.0 JFA is designed for entry-level positions in a contact center environment where the main focus is customer service.', 'Assessment Length': 'Approximate Completion Time in minutes = 31', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'SBCP', 'Tags': ['Customer Service', 'Contact Center', 'Entry-Level', 'Customer Support', 'Help Desk', 'Call Center']}, page_content='Contact Center Customer Service 8.0. The Customer Service 8.0 JFA is designed for entry-level positions in a contact center environment where the main focus is customer service.'),
# ...
#  Document(metadata={'Test Name': 'What Is The Value - US', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/what-is-the-value-us/', 'Description': 'The What is the Value –US test measures money handling ability. This test is designed for entry-level positions where handling money is required on a regular basis.', 'Assessment Length': 'Approximate Completion Time in minutes = 5', 'Job Levels': 'Entry-Level,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K', 'Tags': ['money handling', 'numerical reasoning', 'cash handling', 'entry-level', 'retail', 'customer service', 'arithmetic', 'basic math', 'US currency']}, page_content='What Is The Value - US. The What is the Value –US test measures money handling ability. This test is designed for entry-level positions where handling money is required on a regular basis.'),
#  Document(metadata={'Test Name': 'Workplace Administration Skills (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/workplace-administration-skills-new/', 'Description': "Multi-choice test that measures the ability to organize one's workplace, properly maintain data, perform simple tasks on the computer and resolve administrative issues.", 'Assessment Length': 'Approximate Completion Time in minutes = 12', 'Job Levels': 'Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['workplace administration', 'administrative skills', 'data maintenance', 'computer skills', 'problem-solving', 'organizational skills', 'task management', 'multi-choice', 'clerical', 'entry-level']}, page_content="Workplace Administration Skills (New). Multi-choice test that measures the ability to organize one's workplace, properly maintain data, perform simple tasks on the computer and resolve administrative issues."),
#  Document(metadata={'Test Name': 'Workplace Health and Safety (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/workplace-health-and-safety-new/', 'Description': 'Multi-choice test that measures the knowledge of first aid, emergency safety measures, cleanliness and personal hygiene.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Entry-Level, Graduate, Manager, Supervisor, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Workplace Health and Safety', 'First Aid', 'Emergency Safety Measures', 'Cleanliness', 'Personal Hygiene', 'Multiple Choice', 'Knowledge Assessment']}, page_content='Workplace Health and Safety (New). Multi-choice test that measures the knowledge of first aid, emergency safety measures, cleanliness and personal hygiene.'),
#  Document(metadata={'Test Name': 'WriteX - Email Writing (Customer Service) (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/writex-email-writing-customer-service-new/', 'Description': 'Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/', 'Assessment Length': 'Approximate Completion Time in minutes = 15', 'Job Levels': 'Entry-Level, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S', 'Tags': ['email writing', 'customer service', 'written communication', 'english language', 'content quality', 'grammar', 'email etiquette', 'open response', 'writing skills', 'communication skills', 'customer support', 'compliance', 'law 144', 'new york city law 144']}, page_content='WriteX - Email Writing (Customer Service) (New). Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/'),
#  Document(metadata={'Test Name': 'WriteX - Email Writing (Managerial) (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/writex-email-writing-managerial-new/', 'Description': 'Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/', 'Assessment Length': 'Approximate Completion Time in minutes = 15', 'Job Levels': 'Entry-Level, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'S', 'Tags': ['email writing', 'business communication', 'written communication', 'grammar', 'content quality', 'email etiquette', 'managerial level', 'open response', 'English', 'New York City Law 144 compliance']}, page_content='WriteX - Email Writing (Managerial) (New). Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/'),
#  Document(metadata={'Test Name': 'WriteX - Email Writing (Sales) (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/writex-email-writing-sales-new/', 'Description': 'Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/', 'Assessment Length': 'Approximate Completion Time in minutes = 15', 'Job Levels': 'Entry-Level, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'BS', 'Tags': ['email writing', 'business communication', 'sales', 'written communication', 'grammar', 'email etiquette', 'open response', 'english language proficiency', 'content quality', 'professional communication', 'new york city law 144', 'automated employment decision tools']}, page_content='WriteX - Email Writing (Sales) (New). Open response test that evaluates the ability to write proper emails in English. The test provides scores on content, grammar and email etiquette.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/'),
#  Document(metadata={'Test Name': 'Written English v1', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/written-english-v1/', 'Description': 'The Written English test measures knowledge of US English grammar and English reading comprehension. It is designed for those with English as a second language and covers the following topics: Articles, Comparisons, Conjunctions, General Questions, Misused Words, Nouns, Parallel Structure, Prepositions, Pronouns, Specific Questions, and Verbs.', 'Assessment Length': 'Approximate Completion Time in minutes = 30', 'Job Levels': 'Entry-Level, Front Line Manager, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K', 'Tags': ['Written English', 'English Grammar', 'Reading Comprehension', 'ESL', 'English as a Second Language', 'US English', 'Articles', 'Comparisons', 'Conjunctions', 'Nouns', 'Pronouns', 'Prepositions', 'Verbs', 'Parallel Structure', 'Misused Words']}, page_content='Written English v1. The Written English test measures knowledge of US English grammar and English reading comprehension. It is designed for those with English as a second language and covers the following topics: Articles, Comparisons, Conjunctions, General Questions, Misused Words, Nouns, Parallel Structure, Prepositions, Pronouns, Specific Questions, and Verbs.'),
#  Document(metadata={'Test Name': 'Written Spanish', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/written-spanish/', 'Description': 'This test measures knowledge of Spanish grammar and Spanish reading comprehension skills. Designed primarily for individuals where Spanish is their second language, this test covers the following topics: Adjectives, Adverbs, Conjunctions, Nouns, Prepositions, Pronouns, Verbs, and Reading Comprehension.', 'Assessment Length': 'Approximate Completion Time in minutes = 22', 'Job Levels': 'Entry-Level, Front Line Manager, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'Yes', 'Test Type': 'K', 'Tags': ['Spanish Language', 'Grammar', 'Reading Comprehension', 'Second Language Proficiency', 'Adjectives', 'Adverbs', 'Conjunctions', 'Nouns', 'Prepositions', 'Pronouns', 'Verbs']}, page_content='Written Spanish. This test measures knowledge of Spanish grammar and Spanish reading comprehension skills. Designed primarily for individuals where Spanish is their second language, this test covers the following topics: Adjectives, Adverbs, Conjunctions, Nouns, Prepositions, Pronouns, Verbs, and Reading Comprehension.'),
#  Document(metadata={'Test Name': 'Zabbix (New)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/zabbix-new/', 'Description': 'Multi-choice test that measures the knowledge of Zabbix architecture, data handling, monitoring and administration.', 'Assessment Length': 'Approximate Completion Time in minutes = 9', 'Job Levels': 'Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'K', 'Tags': ['Zabbix', 'Monitoring', 'System Administration', 'Infrastructure Monitoring', 'Multi-choice', 'Architecture', 'Data Handling']}, page_content='Zabbix (New). Multi-choice test that measures the knowledge of Zabbix architecture, data handling, monitoring and administration.'),
#  Document(metadata={'Test Name': '360 Digital Report', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/360-digital-report/', 'Description': "Introducing the new 360 Digital Report from SHL! Our latest offering revolutionizes the reporting experience for our 360 products, catering to the modern user's needs for enhanced usability and actionable insights. With a sleek, interactive interface, this report provides a exploration of feedback data, focusing on user development and comprehensive evaluation. Users can now enjoy a visually engaging experience, with the capability to download the report in PDF format for offline access. Upgrade your reporting experience today with SHL's innovative 360 Digital Report!", 'Assessment Length': 'nan', 'Job Levels': 'Director, Manager, Entry-Level, Executive, Front Line Manager, General Population, Graduate,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'D', 'Tags': ['360 feedback', 'digital report', 'performance evaluation', 'employee development', 'usability', 'actionable insights', 'interactive interface', 'feedback data', 'PDF report', 'SHL product']}, page_content="360 Digital Report. Introducing the new 360 Digital Report from SHL! Our latest offering revolutionizes the reporting experience for our 360 products, catering to the modern user's needs for enhanced usability and actionable insights. With a sleek, interactive interface, this report provides a exploration of feedback data, focusing on user development and comprehensive evaluation. Users can now enjoy a visually engaging experience, with the capability to download the report in PDF format for offline access. Upgrade your reporting experience today with SHL's innovative 360 Digital Report!"),
#  Document(metadata={'Test Name': '360° Multi-Rater Feedback System (MFS)', 'Test Link': 'https://www.shl.com/solutions/products/product-catalog/view/360-multi-rater-feedback-system-mfs/', 'Description': 'SHL 360, or the Multi-Rater Feedback System (‘MFS’), provides a holistic 360-degree view of an employee by gathering feedback from the employee’s manager, peers, direct reports, and/or other raters.  By offering a wide range of perspectives, 360 feedback gives employees a more thorough understanding of not only their strengths, weaknesses, and development opportunities, but also their impact on others.  360-degree multi-rater assessments are based on SHL’s Universal Competency Framework (“UCF”), using our proven library of research-driven competencies to provide opportunities for managers, peers, and direct reports to supply useful developmental feedback that they may not otherwise share.  SHL can also offer support and training throughout the entire process, from defining objectives through interpreting and delivering the feedback.  360 feedback serves all levels and industries and is a positive and powerful addition to your performance management system.', 'Assessment Length': 'Approximate Completion Time in minutes = Untimed', 'Job Levels': 'Director, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,', 'Remote Testing': 'Yes', 'Adaptive/IRT': 'nan', 'Test Type': 'DP', 'Tags': ['360-degree feedback', 'multi-rater feedback', 'performance management', 'employee development', 'competency assessment', 'SHL Universal Competency Framework (UCF)', 'manager feedback', 'peer feedback', 'direct report feedback', 'self-assessment', 'leadership assessment', 'communication skills', 'interpersonal skills', 'impact on others', 'strengths and weaknesses', 'development opportunities', 'all levels', 'all industries', 'holistic view', 'research-driven competencies', 'developmental feedback']}, page_content='360° Multi-Rater Feedback System (MFS). SHL 360, or the Multi-Rater Feedback System (‘MFS’), provides a holistic 360-degree view of an employee by gathering feedback from the employee’s manager, peers, direct reports, and/or other raters.  By offering a wide range of perspectives, 360 feedback gives employees a more thorough understanding of not only their strengths, weaknesses, and development opportunities, but also their impact on others.  360-degree multi-rater assessments are based on SHL’s Universal Competency Framework (“UCF”), using our proven library of research-driven competencies to provide opportunities for managers, peers, and direct reports to supply useful developmental feedback that they may not otherwise share.  SHL can also offer support and training throughout the entire process, from defining objectives through interpreting and delivering the feedback.  360 feedback serves all levels and industries and is a positive and powerful addition to your performance management system.')]

# %%
from sentence_transformers import SentenceTransformer
from uuid import uuid4
import ast

model = SentenceTransformer("all-MiniLM-L6-v2")
batch_size = 25
vectors_to_upsert = []

for i, row in df.iterrows():
    row = row.fillna("")
    text = f"{row['Test Name']}. {row['Description']}"
    embedding = model.encode(text).tolist()

    # ✅ Parse tags from CSV
    tags_raw = row.get("Tags", "")
    try:
        tags = ast.literal_eval(tags_raw) if isinstance(tags_raw, str) else tags_raw
        if not isinstance(tags, list):
            tags = []
    except Exception:
        tags = []

    metadata = {
        "Test Name": str(row['Test Name']),
        "Test Link": str(row['Test Link']),
        "Description": str(row['Description']),
        "Assessment Length": str(row['Assessment Length']),
        "Job Levels": str(row['Job Levels']),
        "Remote Testing": str(row['Remote Testing']),
        "Adaptive/IRT": str(row['Adaptive/IRT']),
        "Test Type": str(row['Test Type']),
        "Tags": tags  # ✅ Correct, per row
    }

    vector = (str(uuid4()), embedding, metadata)
    vectors_to_upsert.append(vector)

    # ⏫ Batched upsert
    if len(vectors_to_upsert) == batch_size or i == len(df) - 1:
        print(f"🔼 Upserting batch {i + 1 - batch_size + 1} to {i + 1}")
        try:
            index.upsert(vectors=vectors_to_upsert)
        except Exception as e:
            print(f"❌ Error during upsert: {e}")
            print("⏳ Retrying by refreshing Pinecone client...")
            try:
                pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
                index = pc.Index(index_name)
                index.upsert(vectors=vectors_to_upsert)
                print("✅ Retry succeeded.")
            except Exception as inner_e:
                print(f"❌ Retry failed again: {inner_e}")
                break
        vectors_to_upsert = []
# Out:
# 🔼 Upserting batch 1 to 25
# 🔼 Upserting batch 26 to 50
# 🔼 Upserting batch 51 to 75
# 🔼 Upserting batch 76 to 100
# ❌ Error during upsert: Failed to connect; did you specify the correct index name?
# ⏳ Retrying by refreshing Pinecone client...
# ✅ Retry succeeded.
# 🔼 Upserting batch 101 to 125
# 🔼 Upserting batch 126 to 150
# 🔼 Upserting batch 151 to 175
# 🔼 Upserting batch 176 to 200
# 🔼 Upserting batch 201 to 225
# 🔼 Upserting batch 226 to 250
# ❌ Error during upsert: Failed to connect; did you specify the correct index name?
# ⏳ Retrying by refreshing Pinecone client...
# ✅ Retry succeeded.
# 🔼 Upserting batch 251 to 275
# 🔼 Upserting batch 276 to 300
# 🔼 Upserting batch 301 to 325
# 🔼 Upserting batch 326 to 350
# 🔼 Upserting batch 351 to 375
# ❌ Error during upsert: Failed to connect; did you specify the correct index name?
# ⏳ Retrying by refreshing Pinecone client...
# ✅ Retry succeeded.
# 🔼 Upserting batch 376 to 400
# 🔼 Upserting batch 401 to 425
# 🔼 Upserting batch 426 to 450
# 🔼 Upserting batch 451 to 475
# 🔼 Upserting batch 476 to 500
# 🔼 Upserting batch 494 to 518

# %% [markdown]
# ## ReRanking using Pincone Library

# %%
query="Looking to hire mid-level professionals who are proficient in Python, SQL and Java Script. Need an assessment package that can test all skills with max duration of 60 minutes."
embedder = SentenceTransformer("all-MiniLM-L6-v2")
query_vector = embedder.encode(query).tolist()

# Step 1: Retrieve Top-K Candidates
retrieved = index.query(
    vector=query_vector,
    top_k=10,
    include_metadata=True
)

# Step 2: Prepare Documents for Reranking
transformed_documents = []
for i, match in enumerate(retrieved['matches']):
    metadata = match['metadata']
    tags = metadata.get("Tags", [])
    tag_string = " ".join(tags) if isinstance(tags, list) else str(tags)
    
    transformed_documents.append({
        "id": str(i),
        "reranking_field": f"{metadata['Test Name']}. {metadata['Description']}. Tags: {tag_string}",
        "metadata": metadata
    })


# Step 3: Call Pinecone Reranker
reranked_results_field = pc.inference.rerank(
    model="bge-reranker-v2-m3",
    query=query,
    documents=transformed_documents,
    rank_fields=["reranking_field"],
    top_n=5,
    return_documents=True
)

# Step 4: Show Reranked Results
def show_reranked_results(question, matches):
    print(f'\n🧠 Query: \'{question}\'')
    print('\n🔢 Reranked Results:\n')
    for i, match in enumerate(matches):
        doc = match.document
        metadata = doc.metadata
        print(f'{str(i+1).rjust(3)}. {metadata.get("Test Name")}')
        print(f'     🔢 Score: {match.score:.4f}')
        print(f'     🕒 Length: {metadata.get("Assessment Length")} | 🧑‍💼 Level: {metadata.get("Job Levels")}')
        print(f'     🔗 {metadata.get("Test Link")}\n')

show_reranked_results(query, reranked_results_field.data)
# Out:
# 🧠 Query: 'Looking to hire mid-level professionals who are proficient in Python, SQL and Java Script. Need an assessment package that can test all skills with max duration of 60 minutes.'
#
# 🔢 Reranked Results:
#
#   1. Verify - Deductive Reasoning
#      🔢 Score: 0.0256
#      🕒 Length: Approximate Completion Time in minutes = 20 | 🧑‍💼 Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/verify-deductive-reasoning/
#
#   2. Python (New)
#      🔢 Score: 0.0228
#      🕒 Length: Approximate Completion Time in minutes = 11 | 🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/python-new/
#
#   3. Technology Professional 8.0 Job Focused Assessment
#      🔢 Score: 0.0056
#      🕒 Length: Approximate Completion Time in minutes = 16 | 🧑‍💼 Level: Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/technology-professional-8-0-job-focused-assessment/
#
#   4. Professional + 7.1 (International)
#      🔢 Score: 0.0043
#      🕒 Length: Approximate Completion Time in minutes = 56 | 🧑‍💼 Level: General Population, Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/professional-7-1-solution/
#
#   5. Professional + 7.1 (Americas)
#      🔢 Score: 0.0039
#      🕒 Length: Approximate Completion Time in minutes = 56 | 🧑‍💼 Level: General Population, Mid-Professional, Professional Individual Contributor,
#      🔗 https://www.shl.com/solutions/products/product-catalog/view/professional-7-1-%28americas%29/

# %% [markdown]
# ## Hybrid Retrieval(Indexing Retrieval using BM25)

# %%
import numpy as np
from typing import List
from langchain_core.documents import Document
from rank_bm25 import BM25Okapi

class FusionRetriever:
    def __init__(self, pinecone_index, sentence_model, documents: List[Document], alpha: float = 0.5):
        """
        Args:
        - pinecone_index: a Pinecone Index() object (not LangChain vectorstore)
        - sentence_model: SentenceTransformer embedding model
        - documents: List of Documents used for indexing
        - alpha: fusion weighting factor between vector and BM25 scores
        """
        self.index = pinecone_index
        self.model = sentence_model
        self.documents = documents
        self.alpha = alpha
        self.bm25 = self._create_bm25_index(documents)

    def _create_bm25_index(self, documents: List[Document]) -> BM25Okapi:
        tokenized_docs = []
        for doc in documents:
            base_tokens = doc.page_content.split() if doc.page_content else []
            tags = doc.metadata.get("Tags", [])
            tag_tokens = tags if isinstance(tags, list) else []
            combined_tokens = base_tokens + tag_tokens * 3  # Prefer tags
            tokenized_docs.append(combined_tokens)
        return BM25Okapi(tokenized_docs)

    def retrieve(self, query: str, k: int = 5, fetch_k: int = 30) -> List[Document]:
        epsilon = 1e-8

        # Step 1: Encode query using the same SentenceTransformer used during indexing
        query_vector = self.model.encode(query).tolist()

        # Step 2: Query Pinecone directly
        response = self.index.query(
            vector=query_vector,
            top_k=fetch_k,
            include_metadata=True
        )

        if not response['matches']:
            print("⚠️ No results from vector store.")
            return []

        all_docs = []
        vector_scores = []

        for match in response['matches']:
            metadata = match['metadata']
            content = f"{metadata.get('Test Name', '')}. {metadata.get('Description', '')}"
            doc = Document(page_content=content, metadata=metadata)
            all_docs.append(doc)
            vector_scores.append(match['score'])

        # Normalize vector scores (inverted so higher = better)
        vector_scores = np.array(vector_scores)
        vector_scores = 1 - (vector_scores - np.min(vector_scores)) / (np.max(vector_scores) - np.min(vector_scores) + epsilon)

        # Step 3: BM25 scoring
        query_tokens = query.split()
        mini_bm25 = BM25Okapi([doc.page_content.split() for doc in all_docs])
        bm25_scores = mini_bm25.get_scores(query_tokens)

        bm25_scores = np.array(bm25_scores)
        if np.max(bm25_scores) > 0:
            bm25_scores = (bm25_scores - np.min(bm25_scores)) / (np.max(bm25_scores) - np.min(bm25_scores) + epsilon)
        else:
            bm25_scores = np.zeros_like(vector_scores)

        # Step 4: Combine scores
        combined_scores = self.alpha * vector_scores + (1 - self.alpha) * bm25_scores
        sorted_indices = np.argsort(combined_scores)[::-1]

        return [all_docs[i] for i in sorted_indices[:k]]

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# Run retrieval
retriever = FusionRetriever(index, model, documents, alpha=0.5)
results = retriever.retrieve("I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment(s) that can be completed in 40 minutes.", k=5)

# Display
for i, doc in enumerate(results):
    print(f"\n🔹 {i+1}. {doc.metadata['Test Name']}")
    print(f"   🕒 {doc.metadata['Assessment Length']}")
    print(f"   🧑‍💼 {doc.metadata['Job Levels']}")
    print(f"   🔗 {doc.metadata['Test Link']}")
# Out:
# 🔹 1. Apprentice 8.0 Job Focused Assessment
#    🕒 Approximate Completion Time in minutes = 20
#    🧑‍💼 Entry-Level, General Population, Graduate,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/apprentice-8-0-job-focused-assessment/
#
# 🔹 2. Apprentice + 8.0 Job Focused Assessment
#    🕒 Approximate Completion Time in minutes = 30
#    🧑‍💼 General Population, Graduate, Entry-Level,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/apprentice-8-0-job-focused-assessment-4261/
#
# 🔹 3. PJM Selection Report
#    🕒
#    🧑‍💼 Mid-Professional, Manager,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/pjm-selection-report/
#
# 🔹 4. MFS 360 UCF Performance Potential Dev Tips Report
#    🕒
#    🧑‍💼
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/mfs-360-ucf-performance-potential-dev-tips-report/
#
# 🔹 5. 360° Multi-Rater Feedback System (MFS)
#    🕒 Approximate Completion Time in minutes = Untimed
#    🧑‍💼 Director, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/360-multi-rater-feedback-system-mfs/

# %% [markdown]
# ## Enhancing Reranking

# %%
from typing import List

# %%
query='''I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment(s) that can be completed in 40 minutes.
'''
model = SentenceTransformer("all-MiniLM-L6-v2")
query_vector = model.encode(query).tolist()

# === Step 1: Retrieve Top 30 from Pinecone ===
retrieved = index.query(
    vector=query_vector,
    top_k=30,
    include_metadata=True
)

# === Step 2: Format results for reranking ===
assessment_blocks = []
id_map = {}

for i, match in enumerate(retrieved['matches']):
    md = match['metadata']
    aid = str(i + 1)
    id_map[aid] = md
    tags = ", ".join(md.get("Tags", [])) if isinstance(md.get("Tags"), list) else md.get("Tags", "")
    block = f"""{aid}. Title: {md.get('Test Name', '')}
Description: {md.get('Description', '')}
Tags: {tags}
Job Level: {md.get('Job Levels', '')}
Duration: {md.get('Assessment Length', '')}
"""
    assessment_blocks.append(block)

# === Step 3: Create reranking prompt ===
def build_prompt(query, blocks):
    return f"""
You are an expert assistant helping HR teams and recruiters select the most relevant assessments for their hiring needs.

Given a natural language hiring query or Job description of a job and a list of available assessments, your task is to intelligently rank and recommend the top 10 most relevant assessments.

Assessments are described using their title, description, tags, target job level, and duration. The user query may include specific technical and soft skills, job roles, team collaboration needs, or constraints like duration (e.g., "within 40 minutes").

You must:

Match skills (technical and soft)

Understand job role and seniority

Respect duration constraints

Recognize contextual needs (e.g., cross-functional, remote-friendly, leadership focus)

Rank results based on semantic relevance, not just keyword overlap

Your job is to return the **top 10 most relevant assessments**, ranked by relevance to the query, in JSON format like this:

[
  {{"id": "3", "reason": "Matches Python, SQL and is under 60 mins"}},
  ...
]

Query:
"{query}"

Assessments:
{''.join(blocks)}
"""

prompt = build_prompt(query, assessment_blocks)

# === Step 4: Rerank using Gemini ===
response = llm.generate_content(prompt)
response_text = response.text.strip()

# Extract and clean JSON from Gemini response
response_text = re.sub(r"^```json", "", response_text)
response_text = re.sub(r"```$", "", response_text)
response_text = response_text.strip()

try:
    reranked = json.loads(response_text)
except Exception as e:
    print(f"❌ Failed to parse Gemini response: {e}")
    reranked = []

# === Step 5: Show Results ===
print(f"\n🧠 Query: {query}\n")
print("📊 Top Gemini-Reranked Assessments:\n")

for item in reranked:
    aid = item["id"]
    reason = item.get("reason", "No reason given")
    md = id_map.get(aid)

    if not md:
        continue

    print(f"🔹 {md.get('Test Name')}")
    print(f"   🧠 Reason: {reason}")
    print(f"   🕒 Length: {md.get('Assessment Length')}")
    print(f"   🧑‍💼 Level: {md.get('Job Levels')}")
    print(f"   🏷️ Tags: {', '.join(md.get('Tags', [])) if isinstance(md.get('Tags'), list) else md.get('Tags')}")
    print(f"   🔗 {md.get('Test Link')}\n")
# Out:
# 🧠 Query: I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment(s) that can be completed in 40 minutes.
#
#
# 📊 Top Gemini-Reranked Assessments:
#
# 🔹 Java 8 (New)
#    🧠 Reason: Directly assesses Java 8 knowledge and fits the time constraint.
#    🕒 Length: Approximate Completion Time in minutes = 18
#    🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#    🏷️ Tags: Java 8, Java, Class Design, Exceptions, Generics, Collections, Concurrency, JDBC, Java I/O, Multi-choice, Fundamentals, Backend Developer
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/java-8-new/
#
# 🔹 Java 2 Platform Enterprise Edition 1.4 Fundamental
#    🧠 Reason: Assesses Java EE 1.4 fundamentals, relevant for Java developers and under 40 minutes.
#    🕒 Length: Approximate Completion Time in minutes = 30
#    🧑‍💼 Level: Entry-Level, Mid-Professional, Professional Individual Contributor,
#    🏷️ Tags: Java 2 Platform Enterprise Edition 1.4, J2EE 1.4, J2EE Architecture, Business Component Development, JAX 1.2, JDBC 3.0, Web Component Development, Web Service Development, Entry-level, Java, Backend Development
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/java-2-platform-enterprise-edition-1-4-fundamental/
#
# 🔹 Java Platform Enterprise Edition 7 (Java EE 7)
#    🧠 Reason: Measures knowledge of Java EE 7 architecture, suitable for Java developers and within the time limit.
#    🕒 Length: Approximate Completion Time in minutes = 30
#    🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#    🏷️ Tags: Java EE 7, Java Platform Enterprise Edition 7, Java programmer, Java architect, Commonly-Used APIs, Component Technology, Database Access, JEE Application Architecture, JSP Extensions, Resource Management, Web Services, Webapp Control and View Technologies, Webapp Technology, backend developer, mid-level, senior developer
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/java-platform-enterprise-edition-7-java-ee-7/
#
# 🔹 Enterprise Java Beans (New)
#    🧠 Reason: Assesses knowledge of Enterprise Java Beans and concurrency concepts for Java developers, and takes only 4 minutes.
#    🕒 Length: Approximate Completion Time in minutes = 4
#    🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#    🏷️ Tags: Enterprise Java Beans, EJB, Java, JEE, Transactions, Concurrency, Multi-choice, Intermediate Level
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/enterprise-java-beans-new/
#
# 🔹 Software Business Analysis
#    🧠 Reason: Evaluates Software Business Analysis skills (requirements gathering, system design).
#    🕒 Length: Approximate Completion Time in minutes = 30
#    🧑‍💼 Level: Mid-Professional, Professional Individual Contributor,
#    🏷️ Tags: business analysis, requirements gathering, system design, business process, diagramming, modeling, documentation, joint application development, methodologies, project development, user interface, IT project, technical assets, strategic execution, senior-level, business requirements, software
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/software-business-analysis/
#
# 🔹 360° Multi-Rater Feedback System (MFS)
#    🧠 Reason: 360° feedback helps evaluate collaboration and communication skills.
#    🕒 Length: Approximate Completion Time in minutes = Untimed
#    🧑‍💼 Level: Director, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,
#    🏷️ Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/360-multi-rater-feedback-system-mfs/
#
# 🔹 PJM Selection Report
#    🧠 Reason: Matches candidate to a role based on essential/desirable competencies and behaviours at work. Useful to check for individual's overall fit as well as likely areas of strength and weakness
#    🕒 Length:
#    🧑‍💼 Level: Mid-Professional, Manager,
#    🏷️ Tags: candidate selection, candidate development, competency assessment, job fit, talent audit, behavioral assessment, interview questions, strengths and weaknesses, HR professionals, line managers, competency potential, job importance, action planning, prioritization, match score, ranking, sorting, talent management
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/pjm-selection-report/
#
# 🔹 Virtual Assessment and Development Centers
#    🧠 Reason: Virtual assessment center can be used to assess collaboration skills via group exercises and role-play.
#    🕒 Length: Approximate Completion Time in minutes = N/A
#    🧑‍💼 Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
#    🏷️ Tags: virtual assessment center, development center, new hires, existing employees, employee potential, candidate experience, assessor experience, administrator experience, inbox simulation, written analysis, coaching, role-play, group exercises, job levels, industry scenarios, SHL, Smart Interview Live, English US, Japanese, Simplified Chinese, Spanish, Portuguese, Brazilian Portuguese, French, Canadian French, Italian, Dutch, Latin American Spanish, Romanian, Indonesian, German, Greek
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/virtual-assessment-and-development-centers/
#
# 🔹 Verify - Deductive Reasoning
#    🧠 Reason: The deductive reasoning assessment can assess analytical skills.
#    🕒 Length: Approximate Completion Time in minutes = 20
#    🧑‍💼 Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
#    🏷️ Tags: deductive reasoning, logical reasoning, critical thinking, problem-solving, analytical skills, ability assessment, pre-hire assessment, post-hire assessment, all levels, evaluate arguments, analyze scenarios, draw logical conclusions, decision-making, 18 minutes, 20 items, SHL Verify
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/verify-deductive-reasoning/
#
# 🔹 Assessment and Development Center Exercises
#    🧠 Reason: Assessment and Development Center Exercises includes group exercises and role plays which would be helpful to assess the candidate's ability to collaborate
#    🕒 Length: Approximate Completion Time in minutes = Variable
#    🧑‍💼 Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
#    🏷️ Tags: assessment center, development center, group exercise, role play, analysis presentation, written exercise, virtual assessment, remote assessment, job levels, industry contexts, SHL
#    🔗 https://www.shl.com/solutions/products/product-catalog/view/assessment-and-development-center-exercises/

# %%
assessment_blocks
# Out:
# ['1. Title: Verify - General Ability Screen\nDescription: The General Ability Screen is a first for us – a measure of general mental ability or ‘g’ .\r\nTargeted at ‘entry-level’ roles, General Ability Screen is intended to precede other measures to provide process efficiency, and to ensure candidates experience the most positive possible assessment process, by being quick, fair and available as an online test 24/7/365. \r\nAs the name suggests, the test is designed to be used in screening or sifting processes\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level,\nDuration: Approximate Completion Time in minutes = 10\n',
#  '2. Title: Verify - Technical Checking - Next Generation\nDescription: The Technical Checking assessment is part of the Verify suite of cognitive ability assessments. Technical Checking measures perceptual speed and accuracy. This assessment requires examinees to quickly and accurately match symbols and switches based on a given set of rules. The Technical Checking assessment is mostly non-verbal and features shapes and figures. As with all assessments included in the Verify suite, the Technical Checking assessment allows organizations to assess this aspect of cognitive ability in an unproctored setting. This assessment is appropriate for all job levels and job titles, but is especially relevant for jobs that require the ability to quickly assess the accuracy of information against a set of rules.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level,\nDuration: Approximate Completion Time in minutes = 5\n',
#  '3. Title: OPQ Manager Plus Report\nDescription: This concise OPQ (Occupational Personality Questionnaire) report is designed for use with and by managers.  It uses clear succinct bullets and tables for ease of interpretation.  It provide simple comments on each of the personality traits.Please note this report is currently being updated on Talent Central as part of a reporting refresh project, and there may be visual differences when comparing Talent Central reports to ones generated on other assessment platforms. Differences are regarding the layout and display of the reports only and do not affect the underlying scoring. When viewing sample reports, please ensure you select the appropriate language and platform example.Where a sample report has no platform indicated, it is available on both the Talent Central and SODA platforms.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Entry-Level, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,\nDuration: \n',
#  '4. Title: Verify - Deductive Reasoning\nDescription: The Verify Deductive Reasoning Test is an online ability assessment that can be used to support both pre- and post-hire assessment processes. It enables organisations to recruit and develop candidates applying for jobs at all levels that require deductive reasoning ability.\r\n\r\nThe Deductive Reasoning Test is a new test in the SHL Verify range of ability tests, and measures the ability to:\r\n•\tdraw logical conclusions based on information provided\r\n•\tidentify strengths and weaknesses of arguments\r\n•\tcomplete scenarios using incomplete information\r\n\r\nThe test is 18 minutes long, has 20 items and is designed to provide an indication of how an individual will perform when asked to develop solutions when presented with information and draw sound conclusions from data.  \r\n\r\nThis form of reasoning is commonly required to support work and decision-making in many different types of jobs and at many levels. Sample tasks for jobs that may require deductive reasoning include, but are not limited to:\r\n•\tevaluate arguments\r\n•\tanalyse scenarios\r\n•\tdraw logical conclusions\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,\nDuration: Approximate Completion Time in minutes = 20\n',
#  '5. Title: Verify - G+\nDescription: The G+ test is part of the Verify suite of cognitive ability tests. The test is designed to measure three types of ability: Numerical, Deductive, and Inductive. There are 30 questions in the test, with 10 questions for each of the three abilities measured. Sample tasks for jobs that may require these abilities include, but are not limited to: evaluating arguments, analyzing scenarios, working with data, doing mathematical computations, interpreting graphs and tables, and drawing logical conclusions. The G+ test, due to its adaptive nature, is appropriate for all job levels and roles.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Director, Entry-Level, Executive, Front Line Manager,\nDuration: Approximate Completion Time in minutes = 36\n',
#  '6. Title: Executive Scenarios\nDescription: Executive Scenarios is a unique test of Managerial Judgement - an individual’s ability to decide on effective ways of handling real life situations. It is specifically designed to assess judgement in Executives; a group who typically has significant work experience to draw on. It consists of hypothetical scenarios, each followed by several possible responses. Candidates rate the effectiveness of each response, using a 6-point scale, from highly undesirable to highly desirable. It can be used for recruitment, selection, training and development, performance management and coaching in a variety of functions and industries.\r\n\r\nReports available: \r\n\r\nExecutive Scenarios Narrative Report:  A participant focused report that contains;  \r\n - Executive Scenarios profile\r\n - VERY detailed narrative feedback of each of the 4 scales;  Managerial Judgement, Managing Objectives, People Management and Reputation Management.\r\n - Development tips for each of the 6 style scales;  Leading and Managing the work, Using external help, One-to-one, Workforce, Organisational support, Commercial support.\r\n\r\nExecutive Scenarios Profile: Displays all scores on these scales in terms of four types of norm system; T-scores, Percentiles, Stens and Grades.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Executive, Manager,\nDuration: Approximate Completion Time in minutes = Untimed\n',
#  "7. Title: OPQ Universal Competency Report 1.0\nDescription: This OPQ (Occupational Personality Questionnaire) report is based on the Universal Competency framework.  It graphically outlines how an individual's typical way of behaving is likely to impact on competencies.  It provides a graphical scale for each competency and summarises aspects of personality which contribute (positively or negatively) to each competency.Please note this report is currently being updated on Talent Central as part of a reporting refresh project, and there may be visual differences when comparing Talent Central reports to ones generated on other assessment platforms. Differences are regarding the layout and display of the reports only and do not affect the underlying scoring. When viewing sample reports, please ensure you select the appropriate language and platform example.Where a sample report has no platform indicated, it is available on both the Talent Central and SODA platforms.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Graduate, Director, Executive, Front Line Manager, General Population, Supervisor, Manager, Mid-Professional, Professional Individual Contributor,\nDuration: \n",
#  "8. Title: OPQ UCF Development Action Planner Report 1.0\nDescription: This OPQ (Occupational Personality Questionnaire) report provides clear and relevant information about an individual's strengths and areas for development, for use in staff development and on-boarding situations.Please note this report is currently being updated on Talent Central as part of a reporting refresh project, and there may be visual differences when comparing Talent Central reports to ones generated on other assessment platforms. Differences are regarding the layout and display of the reports only and do not affect the underlying scoring. When viewing sample reports, please ensure you select the appropriate language and platform example.Where a sample report has no platform indicated, it is available on both the Talent Central and SODA platforms.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,\nDuration: \n",
#  '9. Title: Executive Scenarios Profile Report\nDescription: Executive Scenarios is a unique test of Managerial Judgement - an individual’s ability to decide on effective ways of handling real life situations. It is specifically designed to assess judgement in Executives; a group who typically has significant work experience to draw on. It consists of hypothetical scenarios, each followed by several possible responses. Candidates rate the effectiveness of each response, using a 6-point scale, from highly undesirable to highly desirable. It can be used for recruitment, selection, training and development, performance management and coaching in a variety of functions and industries.\r\n\r\nReports available: \r\n\r\nExecutive Scenarios Narrative Report:  A participant focused report that contains;  \r\n - Executive Scenarios profile\r\n - VERY detailed narrative feedback of each of the 4 scales;  Managerial Judgement, Managing Objectives, People Management and Reputation Management.\r\n - Development tips for each of the 6 style scales;  Leading and Managing the work, Using external help, One-to-one, Workforce, Organisational support, Commercial support.\r\n\r\nExecutive Scenarios Profile: Displays all scores on these scales in terms of four types of norm system; T-scores, Percentiles, Stens and Grades.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Executive, Manager,\nDuration: \n',
#  '10. Title: Executive Scenarios Narrative Report\nDescription: Executive Scenarios is a unique test of Managerial Judgement - an individual’s ability to decide on effective ways of handling real life situations. It is specifically designed to assess judgement in Executives; a group who typically has significant work experience to draw on. It consists of hypothetical scenarios, each followed by several possible responses. Candidates rate the effectiveness of each response, using a 6-point scale, from highly undesirable to highly desirable. It can be used for recruitment, selection, training and development, performance management and coaching in a variety of functions and industries.\r\n\r\nReports available: \r\n\r\nExecutive Scenarios Narrative Report:  A participant focused report that contains;  \r\n - Executive Scenarios profile\r\n - VERY detailed narrative feedback of each of the 4 scales;  Managerial Judgement, Managing Objectives, People Management and Reputation Management.\r\n - Development tips for each of the 6 style scales;  Leading and Managing the work, Using external help, One-to-one, Workforce, Organisational support, Commercial support.\r\n\r\nExecutive Scenarios Profile: Displays all scores on these scales in terms of four types of norm system; T-scores, Percentiles, Stens and Grades.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Executive, Manager,\nDuration: \n',
#  '11. Title: Occupational Personality Questionnaire OPQ32r\nDescription: The SHL Occupational Personality Questionnaire, the OPQ32, is one of the most widely used and respected measures of workplace behavioural style in the world. It sets a high standard of measurement excellence, providing HR professionals and business managers with relevant and accurate information to make fast and well-informed people decisions. The OPQ32 provides a clear framework for understanding the impact of personality on job performance. It is internationally recognised for its accuracy of assessment. Over 90 independent validation studies have been conducted on the OPQ over a period of 25 years, across 20 countries and 40 industries, providing concrete evidence of its power to predict performance in the workplace.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Professional Individual Contributor, Supervisor, Mid-Professional, Front Line Manager, General Population, Graduate, Manager, Director, Executive,\nDuration: Approximate Completion Time in minutes = Untimed, approx. 25\n',
#  '12. Title: Technology Professional 8.0 Job Focused Assessment\nDescription: The Technology Job Focused Assessment assesseskey behavioral attributesrequired for success in fast-paced, rapidly evolvingtechnology environments, providing an indication of the candidate’s longer termpotential. \r\n\r\nIt is available as part of SHL’s Technology Hiring Solution.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,\nDuration: Approximate Completion Time in minutes = 16\n',
#  '13. Title: Verify - Numerical Ability\nDescription: The next-generation Verify Numerical Ability Test provides a replacement for the existing Numerical Reasoning test in our Verify range of ability tests and the Global Cognitive Index – Adaptive Quantitative test, and measures the ability to:\r\n•\tDerive the numerical problem from a written problem\r\n•\tCalculate the answer to numerical equations\r\n•\tWork with numerical data in a realistic workplace context\r\n\r\nThe test is 20 minutes long, has 16 items and is designed to provide an indication of how an individual will perform when asked to work with numerical information or statistical details.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,\nDuration: Approximate Completion Time in minutes = 20\n',
#  '14. Title: Smart Interview Live\nDescription: SHL Live Video Interview is areal-timevideo interview tool. It allows recruiters and line managers to remotely engage with candidates and reach hiring decisions faster. \r\nDelight shortlisted candidates with a face2face digital interview that goes way beyond a conference call. Interact with whiteboards, instant file-sharing, draw from an expertly-curated question bank and provide a remote end-to-end interview experience that increases your chance of conversion.Language AvailabilityThe Candidate and Assessor interface is available in US English, Japanese, Simplified Chinese, Castilian Spanish, Portuguese, Brazilian Portuguese, French, Canadian French, Italian, Dutch, Latin American Spanish, Romanian, Indonesian, German, Arabic, Greek. \r\nThe Admin interface is available in US English and Simplified Chinese (CN server).\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,\nDuration: Approximate Completion Time in minutes = Variable\n',
#  '15. Title: Multitasking Ability\nDescription: The Multitasking Ability assessment is a measure of one’s ability to adeptly work on more than one task simultaneously, while maintaining efficiency and effectiveness when interrupted or switching between tasks.  This test is a face-valid, split-screen simulation that is designed to assess multitasking ability. It captures the dynamic nature of the working environment by presenting the candidate with multiple types of items in a timed format. Candidates will be required to complete problem-solving items that are presented on one side of the screen, while at the same time attending to emails that are presented within an email inbox on the other side of the screen.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Entry-Level, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,\nDuration: Approximate Completion Time in minutes = 20\n',
#  '16. Title: OPQ Candidate Report 2.0\nDescription: A brief narrative OPQ (Occupational Personality Questionnaire) report structure around 3 OPQ profile sections which can be given to candidates to keep after a feedback session\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: \nDuration: \n',
#  "17. Title: Verify Interactive Process Monitoring\nDescription: The SHL Verify Range of Ability Tests is a suite of cognitive ability assessments appropriate for candidates at a wide range of job levels. The SHL Process Monitoring assessment is designed for candidates in a wide range of industries where following processes, ensuring vigilance and maintaining machinery are important aspects of the job role. It measures candidates' ability to respond in a timely manner to instrument feedback and monitor variations in a production process in order to maintain the process within specified safe control limits.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Graduate, Manager, Mid-Professional, Professional Individual Contributor,\nDuration: Approximate Completion Time in minutes = 18\n",
#  '18. Title: Smart Interview On Demand\nDescription: Smart Interview On Demand is arecorded(asynchronous) video interview tool, that introduces you to each person behind the resume with a short-recorded video of them explaining why they would be an awesome addition to your team. A streamlined, minimum bias screening to ensure you shortlist top talent faster and find those hidden gems you may have otherwise missed.   \r\nAvailability Theadministrator and evaluator interfaceis available in US English and Simplified Chinese only, as are the standard question banks.  However, custom questions can be added or recorded in any language. \r\n\r\nTheparticipant interfaceis available in: Arabic, Brazilian Portuguese, Bulgarian, Canadian French, Chinese, Croatian, Czech, Danish, Dutch, Dutch (Belgium), Estonian, Finnish, French, German, Greek, Hindi, Hungarian, Italian, Indonesian, Japanese, Korean, Latvian, Lithuanian, Malaysian, Mexican Spanish, Norwegian, Polish, Portuguese, Romanian, Russian, Serbian, Slovak, Slovenian, Spanish, Swedish, Taiwanese Chinese, Thai, Turkish, UK English, Ukrainian, US English, Vietnamese.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.\r\nRead more on https://www.shl.com/legal/shl-us-regulatory-compliance/\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level, Supervisor, Manager, Front Line Manager, General Population, Graduate, Mid-Professional, Professional Individual Contributor,\nDuration: Approximate Completion Time in minutes = Variable\n',
#  '19. Title: Customer Service Phone Solution\nDescription: As part of Contact Center Simulations, the Customer Service Phone Solution includes a contact center simulation and two behavioral tests designed to measure a wide range of skills, competencies, and behavioral tendencies relevant for contact center jobs. The Contact Center Simulation provides an opportunity for candidates to interact with simulated customers in a contact center environment. Designed to measure a candidate’s ability to listen attentively to the customer, take ownership of customer issues, resolve issues, navigate to find information, and enter information accurately, the Contact Center Simulation is intended to measure how a candidate will respond in a variety of customer situations and assess the candidate’s computer skills in a contact center setting. The behavioral tests in this solution are intended to measure the candidate’s learning potential and the tendency to meet goals and work hard, even when faced with obstacles. Collectively, the assessments in this solution measure a wide range of important skills, abilities, and behaviors for entry-level contact center roles."Please note that for Simplified Chinese version the audio is available in both Mandarin and Cantonese."\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level,\nDuration: Approximate Completion Time in minutes = 30\n',
#  '20. Title: Virtual Assessment and Development Centers\nDescription: SHL’s innovative virtual assessment centers wow new hires or existing employees and show how you invest in your people. They are a highly engaging experience, inclusive and packed with predictive power to undercover potential.\r\n\r\nSHL’s virtual assessment and development center platform is packaged with features to support your candidates, assessors and center administrators.\r\n\r\nDeliver a full range of assessment center exercises, from inbox simulations and written analysis, through coaching and role-play with preparation materials and one to one live virtual interactions, to assigned or unassigned role group exercises. Exercises are available across a range of job levels and industry scenarios\r\n\r\nWant to find out more or book a demo? Visit https://www.shl.com/en/solutions/virtual/virtual-assessment-development-center/Language Availabilityfor the candidate and assessor simulation interface is shown in the list below.Language Availabilityfor the live interactions interface (Smart Interview Live) is currently:  English US, Japanese, Simplified Chinese, Spanish, Portuguese, Brazilian Portuguese, French, Canadian French, Italian, Dutch, Latin American Spanish, Romanian, Indonesian, German, Greek.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,\nDuration: Approximate Completion Time in minutes = N/A\n',
#  '21. Title: Verify - Verbal Ability - Next Generation\nDescription: The Verbal Ability test measures the ability to read written passages and comprehend the text, interpret tone and author intent, identify main ideas, and predict author responses. Sample tasks for jobs that may require verbal ability include, but are not limited to: working with reports, correspondence, instructions, and research information. The Verbal Ability test, due to its adaptive nature, is appropriate for all job levels and roles.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: General Population, Graduate, Executive, Director, Entry-Level, Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Front Line Manager,\nDuration: Approximate Completion Time in minutes = 15 minutes\n',
#  "22. Title: OPQ Universal Competency Report 2.0\nDescription: This OPQ (Occupational Personality Questionnaire) report is based on the Universal Competency framework.  It graphically outlines how an individual's typical way of behaving is likely to impact on competencies.  It provides a graphical scale for each competency and summarises aspects of personality which contribute (positively or negatively) to each competency.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Director, Executive, Front Line Manager, General Population,\nDuration: \n",
#  '23. Title: Graduate + 8.0 Job Focused Assessment\nDescription: The Graduate + 8.0 Job Focused Assessment is a short, targeted, globally applicable assessment which includes a short cognitive ability measure. It helps you identify graduates with the highest potential to contribute and succeed, as well as providing actionable feedback to help you onboard new hires.It is designed for professional level positions appropriate for recent college graduates and is available as part of SHL’s Graduate Solution.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Graduate,\nDuration: Approximate Completion Time in minutes = 30 minutes\n',
#  '24. Title: Split Screen Typing Test - Form 1\nDescription: This test measures speed and accuracy in typing text presented on the computer screen. In this assessment, the text original is displayed directly above the area in which the test taker must enter the response. The test taker will not need a printed original for the evaluation. This test calculates a score based on the total number of keystrokes, time taken, and number of errors made when typing six passages. This Split Screen Typing Test uses the following method to determine the Net Words Per Minute score: Net Words Per Minute = ((Gross Words Per Minute * Time Taken) - Total Errors) / Time Taken.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level,\nDuration: Approximate Completion Time in minutes = 6\n',
#  "25. Title: Time Management (U.S.)\nDescription: This is an adaptive test that measures the candidate's knowledge of how to use time wisely in the workplace. It is designed for the average business worker and covers the following topics: Action Plans, Controlling, Decision Making, Organizing, Planning, Scheduling, Time Usage, and Time Wasters.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Entry-Level, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,\nDuration: Approximate Completion Time in minutes = 15 to 35\n",
#  '26. Title: Interviewing and Hiring Concepts (U.S.)\nDescription: The Interviewing and Hiring Concepts (U.S.) test measures knowledge of the interviewing  and hiring process. Designed for all employees and hiring managers, this test covers the following topics: Behavior Traits, Behavioral Interviewing, Candidate Fit, Interview Quality Control, Job Analysis, Legal Compliance, Probing Skills, Screening, Situational Interviews, and Types of Interviews.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Front Line Manager, Manager,\nDuration: Approximate Completion Time in minutes = 15 to 35\n',
#  '27. Title: Professional + 7.0 Solution\nDescription: Our Professional + 7.0 solution is designed for all non-managerial professional individual contributor positions, and includes SHL’s new innovative mobile-first ability assessment, Verify Interactive – Deductive Reasoning. Sample tasks for these jobs include, but are not limited to: gathering requirements, analyzing data, managing projects, producing products or services.Report Language Availability:English (USA).\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Mid-Professional, Professional Individual Contributor,\nDuration: Approximate Completion Time in minutes = 51\n',
#  '28. Title: Graduate 7.1 Job Focused Assessment\nDescription: The Graduate 7.1 Job Focused Assessment is designed for professional level positions appropriate for recent college graduates.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: Graduate,\nDuration: Approximate Completion Time in minutes = 19\n',
#  '29. Title: AI Skills\nDescription: The AI Skills assessment measures the skills that help candidates successfully leverage AI in their work.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: General Population,\nDuration: Approximate Completion Time in minutes = 16\n',
#  "30. Title: Business Communications\nDescription: This test measures the candidate's knowledge of communicating in the workplace.  It measures the skills necessary to communicate effectively with coworkers at all levels and with external business contacts. Designed for the average business worker, this test includes the following topics: Electronic Communication, Employment Communication, Listening, Meetings, Nonverbal Communication, Verbal Communication, and Written Communication. This version of the test is not adaptive.\nTags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback\nJob Level: \nDuration: Approximate Completion Time in minutes = 35\n"]

# %%
def recall_at_k(predicted_ids, relevant_ids, k):
    top_k = predicted_ids[:k]
    return len(set(top_k) & set(relevant_ids)) / len(relevant_ids)

def average_precision_at_k(predicted_ids, relevant_ids, k):
    hits = 0
    sum_precisions = 0
    for i, pid in enumerate(predicted_ids[:k]):
        if pid in relevant_ids:
            hits += 1
            sum_precisions += hits / (i + 1)
    return sum_precisions / min(k, len(relevant_ids))

# Loop over all test queries
mean_recall = np.mean([recall_at_k(pred[i], true[i], k=10) for i in range(len(queries))])
mean_ap = np.mean([average_precision_at_k(pred[i], true[i], k=10) for i in range(len(queries))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 15
#      12     return sum_precisions / min(k, len(relevant_ids))
#      14 # Loop over all test queries
# ---> 15 mean_recall = np.mean([recall_at_k(pred[i], true[i], k=10) for i in range(len(queries))])
#      16 mean_ap = np.mean([average_precision_at_k(pred[i], true[i], k=10) for i in range(len(queries))])
#
# NameError: name 'queries' is not defined

# %%
df["Tags"].value_counts().head(5)
# Out:
# Tags
# ['Account Management', 'Client Communication', 'Project Management', 'Coordination', 'Client Expectations', 'Leadership', 'Mid-Level', 'Account Executive', 'Account Manager', 'Senior Account Manager']                                                                                                                                                                            1
# ['Manufacturing', 'Industrial', 'Safety', 'Domain Expertise', 'Practical Solutions', 'Multitasking', 'Machining and Equipment Operators', 'Laborer/Warehouse', 'Assemblers and Fitters', 'Maintenance/Repair Workers', 'Dispatchers', 'Surveillance', 'Quality Assurance Workers', 'Material Handlers', 'Truck/Ship Loaders', 'Job-Focused Assessment', 'Behavioral Assessment']    1
# ['motivation', 'employee motivation', 'candidate assessment', 'feedback report', 'individual assessment', 'work motivators', 'work demotivators', 'personality assessment', 'behavioral assessment', 'employee engagement']                                                                                                                                                         1
# ['motivation', 'employee motivation', 'managerial skills', 'performance management', 'employee engagement', 'workplace psychology', 'human resources', 'talent management', 'individual differences', 'psychometric assessment', 'personality assessment', 'organizational behavior']                                                                                               1
# ['MongoDB', 'NoSQL', 'Database', 'Data Modeling', 'Sharding', 'Replication', 'Indexing', 'Security', 'Storage', 'MongoDB Queries', 'Multi-choice', 'Conceptual Knowledge']                                                                                                                                                                                                          1
# Name: count, dtype: int64

# %%
assessment_blocks = []
id_map = {}

for i, match in enumerate(retrieved['matches']):
    md = match['metadata']
    aid = str(i + 1)
    id_map[aid] = md
    tags = ", ".join(md.get("Tags", [])) if isinstance(md.get("Tags"), list) else md.get("Tags", "")
    # print("tags",tags)
    block = f"""{aid}. Title: {md.get('Test Name', '')}
    
Description: {md.get('Description', '')}
Tags: {tags}
Job Level: {md.get('Job Levels', '')}
Duration: {md.get('Assessment Length', '')}
"""
    print("block",block)
    assessment_blocks.append(block)
# Out:
# block 1. Title: Verify - General Ability Screen
#
# Description: The General Ability Screen is a first for us – a measure of general mental ability or ‘g’ .
# Targeted at ‘entry-level’ roles, General Ability Screen is intended to precede other measures to provide process efficiency, and to ensure candidates experience the most positive possible assessment process, by being quick, fair and available as an online test 24/7/365.
# As the name suggests, the test is designed to be used in screening or sifting processes
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level,
# Duration: Approximate Completion Time in minutes = 10
#
# block 2. Title: Verify - Technical Checking - Next Generation
#
# Description: The Technical Checking assessment is part of the Verify suite of cognitive ability assessments. Technical Checking measures perceptual speed and accuracy. This assessment requires examinees to quickly and accurately match symbols and switches based on a given set of rules. The Technical Checking assessment is mostly non-verbal and features shapes and figures. As with all assessments included in the Verify suite, the Technical Checking assessment allows organizations to assess this aspect of cognitive ability in an unproctored setting. This assessment is appropriate for all job levels and job titles, but is especially relevant for jobs that require the ability to quickly assess the accuracy of information against a set of rules.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level,
# Duration: Approximate Completion Time in minutes = 5
#
# block 3. Title: OPQ Manager Plus Report
#
# Description: This concise OPQ (Occupational Personality Questionnaire) report is designed for use with and by managers.  It uses clear succinct bullets and tables for ease of interpretation.  It provide simple comments on each of the personality traits.Please note this report is currently being updated on Talent Central as part of a reporting refresh project, and there may be visual differences when comparing Talent Central reports to ones generated on other assessment platforms. Differences are regarding the layout and display of the reports only and do not affect the underlying scoring. When viewing sample reports, please ensure you select the appropriate language and platform example.Where a sample report has no platform indicated, it is available on both the Talent Central and SODA platforms.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Entry-Level, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,
# Duration:
#
# block 4. Title: Verify - Deductive Reasoning
#
# Description: The Verify Deductive Reasoning Test is an online ability assessment that can be used to support both pre- and post-hire assessment processes. It enables organisations to recruit and develop candidates applying for jobs at all levels that require deductive reasoning ability.
#
# The Deductive Reasoning Test is a new test in the SHL Verify range of ability tests, and measures the ability to:
# •	draw logical conclusions based on information provided
# •	identify strengths and weaknesses of arguments
# •	complete scenarios using incomplete information
#
# The test is 18 minutes long, has 20 items and is designed to provide an indication of how an individual will perform when asked to develop solutions when presented with information and draw sound conclusions from data.
#
# This form of reasoning is commonly required to support work and decision-making in many different types of jobs and at many levels. Sample tasks for jobs that may require deductive reasoning include, but are not limited to:
# •	evaluate arguments
# •	analyse scenarios
# •	draw logical conclusions
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
# Duration: Approximate Completion Time in minutes = 20
#
# block 5. Title: Verify - G+
#
# Description: The G+ test is part of the Verify suite of cognitive ability tests. The test is designed to measure three types of ability: Numerical, Deductive, and Inductive. There are 30 questions in the test, with 10 questions for each of the three abilities measured. Sample tasks for jobs that may require these abilities include, but are not limited to: evaluating arguments, analyzing scenarios, working with data, doing mathematical computations, interpreting graphs and tables, and drawing logical conclusions. The G+ test, due to its adaptive nature, is appropriate for all job levels and roles.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Director, Entry-Level, Executive, Front Line Manager,
# Duration: Approximate Completion Time in minutes = 36
#
# block 6. Title: Executive Scenarios
#
# Description: Executive Scenarios is a unique test of Managerial Judgement - an individual’s ability to decide on effective ways of handling real life situations. It is specifically designed to assess judgement in Executives; a group who typically has significant work experience to draw on. It consists of hypothetical scenarios, each followed by several possible responses. Candidates rate the effectiveness of each response, using a 6-point scale, from highly undesirable to highly desirable. It can be used for recruitment, selection, training and development, performance management and coaching in a variety of functions and industries.
#
# Reports available:
#
# Executive Scenarios Narrative Report:  A participant focused report that contains;
#  - Executive Scenarios profile
#  - VERY detailed narrative feedback of each of the 4 scales;  Managerial Judgement, Managing Objectives, People Management and Reputation Management.
#  - Development tips for each of the 6 style scales;  Leading and Managing the work, Using external help, One-to-one, Workforce, Organisational support, Commercial support.
#
# Executive Scenarios Profile: Displays all scores on these scales in terms of four types of norm system; T-scores, Percentiles, Stens and Grades.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Executive, Manager,
# Duration: Approximate Completion Time in minutes = Untimed
#
# block 7. Title: OPQ Universal Competency Report 1.0
#
# Description: This OPQ (Occupational Personality Questionnaire) report is based on the Universal Competency framework.  It graphically outlines how an individual's typical way of behaving is likely to impact on competencies.  It provides a graphical scale for each competency and summarises aspects of personality which contribute (positively or negatively) to each competency.Please note this report is currently being updated on Talent Central as part of a reporting refresh project, and there may be visual differences when comparing Talent Central reports to ones generated on other assessment platforms. Differences are regarding the layout and display of the reports only and do not affect the underlying scoring. When viewing sample reports, please ensure you select the appropriate language and platform example.Where a sample report has no platform indicated, it is available on both the Talent Central and SODA platforms.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Graduate, Director, Executive, Front Line Manager, General Population, Supervisor, Manager, Mid-Professional, Professional Individual Contributor,
# Duration:
#
# block 8. Title: OPQ UCF Development Action Planner Report 1.0
#
# Description: This OPQ (Occupational Personality Questionnaire) report provides clear and relevant information about an individual's strengths and areas for development, for use in staff development and on-boarding situations.Please note this report is currently being updated on Talent Central as part of a reporting refresh project, and there may be visual differences when comparing Talent Central reports to ones generated on other assessment platforms. Differences are regarding the layout and display of the reports only and do not affect the underlying scoring. When viewing sample reports, please ensure you select the appropriate language and platform example.Where a sample report has no platform indicated, it is available on both the Talent Central and SODA platforms.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
# Duration:
#
# block 9. Title: Executive Scenarios Profile Report
#
# Description: Executive Scenarios is a unique test of Managerial Judgement - an individual’s ability to decide on effective ways of handling real life situations. It is specifically designed to assess judgement in Executives; a group who typically has significant work experience to draw on. It consists of hypothetical scenarios, each followed by several possible responses. Candidates rate the effectiveness of each response, using a 6-point scale, from highly undesirable to highly desirable. It can be used for recruitment, selection, training and development, performance management and coaching in a variety of functions and industries.
#
# Reports available:
#
# Executive Scenarios Narrative Report:  A participant focused report that contains;
#  - Executive Scenarios profile
#  - VERY detailed narrative feedback of each of the 4 scales;  Managerial Judgement, Managing Objectives, People Management and Reputation Management.
#  - Development tips for each of the 6 style scales;  Leading and Managing the work, Using external help, One-to-one, Workforce, Organisational support, Commercial support.
#
# Executive Scenarios Profile: Displays all scores on these scales in terms of four types of norm system; T-scores, Percentiles, Stens and Grades.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Executive, Manager,
# Duration:
#
# block 10. Title: Executive Scenarios Narrative Report
#
# Description: Executive Scenarios is a unique test of Managerial Judgement - an individual’s ability to decide on effective ways of handling real life situations. It is specifically designed to assess judgement in Executives; a group who typically has significant work experience to draw on. It consists of hypothetical scenarios, each followed by several possible responses. Candidates rate the effectiveness of each response, using a 6-point scale, from highly undesirable to highly desirable. It can be used for recruitment, selection, training and development, performance management and coaching in a variety of functions and industries.
#
# Reports available:
#
# Executive Scenarios Narrative Report:  A participant focused report that contains;
#  - Executive Scenarios profile
#  - VERY detailed narrative feedback of each of the 4 scales;  Managerial Judgement, Managing Objectives, People Management and Reputation Management.
#  - Development tips for each of the 6 style scales;  Leading and Managing the work, Using external help, One-to-one, Workforce, Organisational support, Commercial support.
#
# Executive Scenarios Profile: Displays all scores on these scales in terms of four types of norm system; T-scores, Percentiles, Stens and Grades.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Executive, Manager,
# Duration:
#
# block 11. Title: Occupational Personality Questionnaire OPQ32r
#
# Description: The SHL Occupational Personality Questionnaire, the OPQ32, is one of the most widely used and respected measures of workplace behavioural style in the world. It sets a high standard of measurement excellence, providing HR professionals and business managers with relevant and accurate information to make fast and well-informed people decisions. The OPQ32 provides a clear framework for understanding the impact of personality on job performance. It is internationally recognised for its accuracy of assessment. Over 90 independent validation studies have been conducted on the OPQ over a period of 25 years, across 20 countries and 40 industries, providing concrete evidence of its power to predict performance in the workplace.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Professional Individual Contributor, Supervisor, Mid-Professional, Front Line Manager, General Population, Graduate, Manager, Director, Executive,
# Duration: Approximate Completion Time in minutes = Untimed, approx. 25
#
# block 12. Title: Technology Professional 8.0 Job Focused Assessment
#
# Description: The Technology Job Focused Assessment assesseskey behavioral attributesrequired for success in fast-paced, rapidly evolvingtechnology environments, providing an indication of the candidate’s longer termpotential.
#
# It is available as part of SHL’s Technology Hiring Solution.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level, Graduate, Mid-Professional, Professional Individual Contributor,
# Duration: Approximate Completion Time in minutes = 16
#
# block 13. Title: Verify - Numerical Ability
#
# Description: The next-generation Verify Numerical Ability Test provides a replacement for the existing Numerical Reasoning test in our Verify range of ability tests and the Global Cognitive Index – Adaptive Quantitative test, and measures the ability to:
# •	Derive the numerical problem from a written problem
# •	Calculate the answer to numerical equations
# •	Work with numerical data in a realistic workplace context
#
# The test is 20 minutes long, has 16 items and is designed to provide an indication of how an individual will perform when asked to work with numerical information or statistical details.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
# Duration: Approximate Completion Time in minutes = 20
#
# block 14. Title: Smart Interview Live
#
# Description: SHL Live Video Interview is areal-timevideo interview tool. It allows recruiters and line managers to remotely engage with candidates and reach hiring decisions faster.
# Delight shortlisted candidates with a face2face digital interview that goes way beyond a conference call. Interact with whiteboards, instant file-sharing, draw from an expertly-curated question bank and provide a remote end-to-end interview experience that increases your chance of conversion.Language AvailabilityThe Candidate and Assessor interface is available in US English, Japanese, Simplified Chinese, Castilian Spanish, Portuguese, Brazilian Portuguese, French, Canadian French, Italian, Dutch, Latin American Spanish, Romanian, Indonesian, German, Arabic, Greek.
# The Admin interface is available in US English and Simplified Chinese (CN server).
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
# Duration: Approximate Completion Time in minutes = Variable
#
# block 15. Title: Multitasking Ability
#
# Description: The Multitasking Ability assessment is a measure of one’s ability to adeptly work on more than one task simultaneously, while maintaining efficiency and effectiveness when interrupted or switching between tasks.  This test is a face-valid, split-screen simulation that is designed to assess multitasking ability. It captures the dynamic nature of the working environment by presenting the candidate with multiple types of items in a timed format. Candidates will be required to complete problem-solving items that are presented on one side of the screen, while at the same time attending to emails that are presented within an email inbox on the other side of the screen.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Entry-Level, Executive, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,
# Duration: Approximate Completion Time in minutes = 20
#
# block 16. Title: OPQ Candidate Report 2.0
#
# Description: A brief narrative OPQ (Occupational Personality Questionnaire) report structure around 3 OPQ profile sections which can be given to candidates to keep after a feedback session
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level:
# Duration:
#
# block 17. Title: Verify Interactive Process Monitoring
#
# Description: The SHL Verify Range of Ability Tests is a suite of cognitive ability assessments appropriate for candidates at a wide range of job levels. The SHL Process Monitoring assessment is designed for candidates in a wide range of industries where following processes, ensuring vigilance and maintaining machinery are important aspects of the job role. It measures candidates' ability to respond in a timely manner to instrument feedback and monitor variations in a production process in order to maintain the process within specified safe control limits.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Graduate, Manager, Mid-Professional, Professional Individual Contributor,
# Duration: Approximate Completion Time in minutes = 18
#
# block 18. Title: Smart Interview On Demand
#
# Description: Smart Interview On Demand is arecorded(asynchronous) video interview tool, that introduces you to each person behind the resume with a short-recorded video of them explaining why they would be an awesome addition to your team. A streamlined, minimum bias screening to ensure you shortlist top talent faster and find those hidden gems you may have otherwise missed.
# Availability Theadministrator and evaluator interfaceis available in US English and Simplified Chinese only, as are the standard question banks.  However, custom questions can be added or recorded in any language.
#
# Theparticipant interfaceis available in: Arabic, Brazilian Portuguese, Bulgarian, Canadian French, Chinese, Croatian, Czech, Danish, Dutch, Dutch (Belgium), Estonian, Finnish, French, German, Greek, Hindi, Hungarian, Italian, Indonesian, Japanese, Korean, Latvian, Lithuanian, Malaysian, Mexican Spanish, Norwegian, Polish, Portuguese, Romanian, Russian, Serbian, Slovak, Slovenian, Spanish, Swedish, Taiwanese Chinese, Thai, Turkish, UK English, Ukrainian, US English, Vietnamese.Your use of this assessment product may be subject to New York City Law 144 (Regulation of the Use of Automated Employment Decision Tools) (dated July 5, 2023). Compliance with Law 144 is your responsibility.
# Read more on https://www.shl.com/legal/shl-us-regulatory-compliance/
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level, Supervisor, Manager, Front Line Manager, General Population, Graduate, Mid-Professional, Professional Individual Contributor,
# Duration: Approximate Completion Time in minutes = Variable
#
# block 19. Title: Customer Service Phone Solution
#
# Description: As part of Contact Center Simulations, the Customer Service Phone Solution includes a contact center simulation and two behavioral tests designed to measure a wide range of skills, competencies, and behavioral tendencies relevant for contact center jobs. The Contact Center Simulation provides an opportunity for candidates to interact with simulated customers in a contact center environment. Designed to measure a candidate’s ability to listen attentively to the customer, take ownership of customer issues, resolve issues, navigate to find information, and enter information accurately, the Contact Center Simulation is intended to measure how a candidate will respond in a variety of customer situations and assess the candidate’s computer skills in a contact center setting. The behavioral tests in this solution are intended to measure the candidate’s learning potential and the tendency to meet goals and work hard, even when faced with obstacles. Collectively, the assessments in this solution measure a wide range of important skills, abilities, and behaviors for entry-level contact center roles."Please note that for Simplified Chinese version the audio is available in both Mandarin and Cantonese."
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level,
# Duration: Approximate Completion Time in minutes = 30
#
# block 20. Title: Virtual Assessment and Development Centers
#
# Description: SHL’s innovative virtual assessment centers wow new hires or existing employees and show how you invest in your people. They are a highly engaging experience, inclusive and packed with predictive power to undercover potential.
#
# SHL’s virtual assessment and development center platform is packaged with features to support your candidates, assessors and center administrators.
#
# Deliver a full range of assessment center exercises, from inbox simulations and written analysis, through coaching and role-play with preparation materials and one to one live virtual interactions, to assigned or unassigned role group exercises. Exercises are available across a range of job levels and industry scenarios
#
# Want to find out more or book a demo? Visit https://www.shl.com/en/solutions/virtual/virtual-assessment-development-center/Language Availabilityfor the candidate and assessor simulation interface is shown in the list below.Language Availabilityfor the live interactions interface (Smart Interview Live) is currently:  English US, Japanese, Simplified Chinese, Spanish, Portuguese, Brazilian Portuguese, French, Canadian French, Italian, Dutch, Latin American Spanish, Romanian, Indonesian, German, Greek.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Director, Entry-Level, Executive, Front Line Manager, General Population, Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor,
# Duration: Approximate Completion Time in minutes = N/A
#
# block 21. Title: Verify - Verbal Ability - Next Generation
#
# Description: The Verbal Ability test measures the ability to read written passages and comprehend the text, interpret tone and author intent, identify main ideas, and predict author responses. Sample tasks for jobs that may require verbal ability include, but are not limited to: working with reports, correspondence, instructions, and research information. The Verbal Ability test, due to its adaptive nature, is appropriate for all job levels and roles.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: General Population, Graduate, Executive, Director, Entry-Level, Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Front Line Manager,
# Duration: Approximate Completion Time in minutes = 15 minutes
#
# block 22. Title: OPQ Universal Competency Report 2.0
#
# Description: This OPQ (Occupational Personality Questionnaire) report is based on the Universal Competency framework.  It graphically outlines how an individual's typical way of behaving is likely to impact on competencies.  It provides a graphical scale for each competency and summarises aspects of personality which contribute (positively or negatively) to each competency.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Graduate, Manager, Mid-Professional, Professional Individual Contributor, Supervisor, Director, Executive, Front Line Manager, General Population,
# Duration:
#
# block 23. Title: Graduate + 8.0 Job Focused Assessment
#
# Description: The Graduate + 8.0 Job Focused Assessment is a short, targeted, globally applicable assessment which includes a short cognitive ability measure. It helps you identify graduates with the highest potential to contribute and succeed, as well as providing actionable feedback to help you onboard new hires.It is designed for professional level positions appropriate for recent college graduates and is available as part of SHL’s Graduate Solution.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Graduate,
# Duration: Approximate Completion Time in minutes = 30 minutes
#
# block 24. Title: Split Screen Typing Test - Form 1
#
# Description: This test measures speed and accuracy in typing text presented on the computer screen. In this assessment, the text original is displayed directly above the area in which the test taker must enter the response. The test taker will not need a printed original for the evaluation. This test calculates a score based on the total number of keystrokes, time taken, and number of errors made when typing six passages. This Split Screen Typing Test uses the following method to determine the Net Words Per Minute score: Net Words Per Minute = ((Gross Words Per Minute * Time Taken) - Total Errors) / Time Taken.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level,
# Duration: Approximate Completion Time in minutes = 6
#
# block 25. Title: Time Management (U.S.)
#
# Description: This is an adaptive test that measures the candidate's knowledge of how to use time wisely in the workplace. It is designed for the average business worker and covers the following topics: Action Plans, Controlling, Decision Making, Organizing, Planning, Scheduling, Time Usage, and Time Wasters.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Entry-Level, Front Line Manager, Manager, Mid-Professional, Professional Individual Contributor,
# Duration: Approximate Completion Time in minutes = 15 to 35
#
# block 26. Title: Interviewing and Hiring Concepts (U.S.)
#
# Description: The Interviewing and Hiring Concepts (U.S.) test measures knowledge of the interviewing  and hiring process. Designed for all employees and hiring managers, this test covers the following topics: Behavior Traits, Behavioral Interviewing, Candidate Fit, Interview Quality Control, Job Analysis, Legal Compliance, Probing Skills, Screening, Situational Interviews, and Types of Interviews.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Front Line Manager, Manager,
# Duration: Approximate Completion Time in minutes = 15 to 35
#
# block 27. Title: Professional + 7.0 Solution
#
# Description: Our Professional + 7.0 solution is designed for all non-managerial professional individual contributor positions, and includes SHL’s new innovative mobile-first ability assessment, Verify Interactive – Deductive Reasoning. Sample tasks for these jobs include, but are not limited to: gathering requirements, analyzing data, managing projects, producing products or services.Report Language Availability:English (USA).
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Mid-Professional, Professional Individual Contributor,
# Duration: Approximate Completion Time in minutes = 51
#
# block 28. Title: Graduate 7.1 Job Focused Assessment
#
# Description: The Graduate 7.1 Job Focused Assessment is designed for professional level positions appropriate for recent college graduates.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: Graduate,
# Duration: Approximate Completion Time in minutes = 19
#
# block 29. Title: AI Skills
#
# Description: The AI Skills assessment measures the skills that help candidates successfully leverage AI in their work.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level: General Population,
# Duration: Approximate Completion Time in minutes = 16
#
# block 30. Title: Business Communications
#
# Description: This test measures the candidate's knowledge of communicating in the workplace.  It measures the skills necessary to communicate effectively with coworkers at all levels and with external business contacts. Designed for the average business worker, this test includes the following topics: Electronic Communication, Employment Communication, Listening, Meetings, Nonverbal Communication, Verbal Communication, and Written Communication. This version of the test is not adaptive.
# Tags: 360-degree feedback, multi-rater feedback, performance management, employee development, competency assessment, SHL Universal Competency Framework (UCF), manager feedback, peer feedback, direct report feedback, self-assessment, leadership assessment, communication skills, interpersonal skills, impact on others, strengths and weaknesses, development opportunities, all levels, all industries, holistic view, research-driven competencies, developmental feedback
# Job Level:
# Duration: Approximate Completion Time in minutes = 35

# %%
import re
import requests
from bs4 import BeautifulSoup
import google.generativeai as genai

genai.configure(api_key=os.getenv("GEMINI_API_KEY"))
llm = genai.GenerativeModel("gemini-2.0-flash")

def is_url(text: str) -> bool:
    return text.startswith("http://") or text.startswith("https://")

def is_probable_jd(text: str) -> bool:
    # Heuristic: if the text is long, contains bullet points or JD terms, treat as JD
    return (
        len(text.split()) > 50 or (
            "responsibilities" in text.lower() or
            "qualifications" in text.lower() or
            "job description" in text.lower() or
            "apply now" in text.lower() or
            "skills required" in text.lower()
        )
    )

def extract_jd_from_url(url: str) -> str:
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(response.content, "html.parser")

        # Heuristically try to extract large content blocks
        candidates = soup.find_all(["p", "div", "section", "article"], recursive=True)
        jd_candidates = [c.get_text(strip=True, separator=" ") for c in candidates if len(c.get_text(strip=True)) > 100]
        jd_text = "\n".join(jd_candidates[:5])  # Limit to top 5 blocks
        return jd_text
    except Exception as e:
        print(f"❌ Error fetching URL content: {e}")
        return ""

def llm_extract_query_from_jd(jd_text: str) -> str:
    prompt = f"""
You are an intelligent assistant that converts job descriptions into smart search queries to find suitable assessment for this JD.

Your job is to read the JD(Job Description) below and write a concise query that captures:
- The role or domain
- Hard skills
- Soft skills or traits (like communication, collaboration)
- Any constraints like seniority level or duration
- Combine these into one smart search query

It should be sentence-like, not a list. Use natural language.
For Example:"I am hiring for Java developers who can also collaborate effectively with my business teams. Looking 
for an assessment(s) that can be completed in 40 minutes."

Return ONLY the final query string. No commentary or explanations.


Job Description:
{jd_text}
"""
    try:
        print("⏳ Calling Gemini...")
        response = llm.generate_content(prompt)
        # print("response",response)
        response_text = response.text.strip()
        print("✅ Gemini returned:\n", response_text)

        return response.text.strip()
    except Exception as e:
        print(f"❌ LLM error: {e}")
        return ""

def preprocess_input(user_input: str) -> str:
    if is_url(user_input):
        print("🌐 Detected URL input — scraping JD...")
        jd_text = extract_jd_from_url(user_input)
        if not jd_text:
            return "Could not extract job description from URL."
        return llm_extract_query_from_jd(jd_text)

    elif is_probable_jd(user_input):
        print("📄 Detected JD text — parsing with LLM...")
        return llm_extract_query_from_jd(user_input)

    else:
        print("💬 Detected simple query — using as-is.")
        return user_input.strip()

# %%
query = preprocess_input("https://www.linkedin.com/jobs/view/research-engineer-ai-at-shl-4194768899/?originalSubdomain=in")
print("🧠 Final query:", query)
# Out:
# 🌐 Detected URL input — scraping JD...
# ⏳ Calling Gemini...
# ✅ Gemini returned:
#  I'm looking for an assessment for a mid-senior level Research Engineer with experience in AI/ML, specifically NLP, computer vision, and speech processing, who is proficient in Python and ML frameworks like TensorFlow, PyTorch, and OpenAI APIs, and possesses agile and proactive thinking.
# 🧠 Final query: I'm looking for an assessment for a mid-senior level Research Engineer with experience in AI/ML, specifically NLP, computer vision, and speech processing, who is proficient in Python and ML frameworks like TensorFlow, PyTorch, and OpenAI APIs, and possesses agile and proactive thinking.
